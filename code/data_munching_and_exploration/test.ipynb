# %%
import os
import glob
import zipfile
import shutil
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta  # pip install python-dateutil

# Base directory containing all ZIP files
crime_data_base_dir = r"C:/Studie/SSML/project/police_crime_archive"
# A single target directory to collect all extracted folders
extraction_target_dir = os.path.join(crime_data_base_dir, "extracted_2013_2025")
os.makedirs(extraction_target_dir, exist_ok=True)

# 1. Helper function to list all months between start_ym and end_ym
def year_month_range(start_ym, end_ym):
    """
    Yields year-month strings (YYYY-MM) from start_ym up to and including end_ym.
    Example:
      start_ym = '2014-12', end_ym = '2015-02'
      yields '2014-12', '2015-01', '2015-02'
    """
    start_dt = datetime.strptime(start_ym, "%Y-%m")
    end_dt = datetime.strptime(end_ym, "%Y-%m")

    curr = start_dt
    while curr <= end_dt:
        yield curr.strftime("%Y-%m")
        curr += relativedelta(months=1)

# 2. Define which folders each ZIP covers via (start_ym, end_ym)
zip_ranges = {
    "2014-12.zip": ("2010-12", "2014-12"),
    "2017-11.zip": ("2014-12", "2017-11"),
    "2020-11.zip": ("2017-12", "2020-11"),
    "2022-12.zip": ("2020-01", "2022-12"),
    "2025-01.zip": ("2022-02", "2025-01"),
}

# 3. Find all ZIP files under crime_data_base_dir
zip_files = []
for root, dirs, files in os.walk(crime_data_base_dir):
    for f in files:
        if f.endswith(".zip"):
            zip_files.append(os.path.join(root, f))

extracted_folders = []

# 4. Extract only valid subfolders for each ZIP
for zip_path in zip_files:
    zip_filename = os.path.basename(zip_path)

    # If this ZIP is in zip_ranges, we know which range to extract
    if zip_filename in zip_ranges:
        start_ym, end_ym = zip_ranges[zip_filename]
        months_to_extract = list(year_month_range(start_ym, end_ym))
        # e.g. if start_ym='2014-12' and end_ym='2017-11', 
        # months_to_extract might be ['2014-12','2015-01','2015-02',...,'2017-11']
        
        print(f"\nExtracting from {zip_filename}: {start_ym} to {end_ym}")
        
        with zipfile.ZipFile(zip_path, 'r') as zf:
            zip_contents = zf.namelist()  # all files/folders in the zip

            # For each month in that range, extract that folder if present
            for ym in months_to_extract:
                # We look for files in the ZIP whose paths start with "YYYY-MM/"
                prefix = ym + "/"
                matching_files = [f for f in zip_contents if f.startswith(prefix)]

                if matching_files:
                    # We'll extract these to a subfolder in extraction_target_dir
                    target_folder = os.path.join(extraction_target_dir, ym)

                    # If that folder already exists, we remove it to overwrite
                    if os.path.exists(target_folder):
                        shutil.rmtree(target_folder)

                    # Extract matching files into that target folder
                    for fpath in matching_files:
                        # Remove the 'ym/' prefix from the path, 
                        # so it extracts into target_folder
                        relative_path = fpath[len(prefix):]

                        # Build final path on disk
                        out_path = os.path.join(target_folder, relative_path)

                        if fpath.endswith("/"):
                            # It's just a directory entry
                            os.makedirs(out_path, exist_ok=True)
                        else:
                            # Extract the file
                            os.makedirs(os.path.dirname(out_path), exist_ok=True)
                            with zf.open(fpath) as src, open(out_path, "wb") as dst:
                                dst.write(src.read())

                    extracted_folders.append(target_folder)
                    print(f" Extracted {ym} → {target_folder}")
                else:
                    # That month folder doesn't exist in this ZIP
                    pass
    else:
        print(f"\nSkipping {zip_filename}: no known date range mapping.")

# 5. Save extracted folders to CSV (optional)
output_csv = os.path.join(extraction_target_dir, "extracted_folders.csv")
df = pd.DataFrame({"folder_path": sorted(set(extracted_folders))})
df.to_csv(output_csv, index=False)

# Summary
print("\nDone!")
print(f"Total ZIPs processed: {len(zip_files)}")
print(f"Total folder paths extracted: {len(extracted_folders)}")
print(f"Unique extracted folders: {len(set(extracted_folders))}")
print(f"Folder paths saved to: {output_csv}")
# Out:
# Skipping 2013-12.zip: no known date range mapping.
#
# Skipping 2014-01.zip: no known date range mapping.
#
# Skipping 2014-02.zip: no known date range mapping.
#
# Skipping 2014-03.zip: no known date range mapping.
#
# Skipping 2014-04.zip: no known date range mapping.
#
# Skipping 2014-05.zip: no known date range mapping.
#
# Skipping 2014-06.zip: no known date range mapping.
#
# Skipping 2014-07.zip: no known date range mapping.
#
# Skipping 2014-08.zip: no known date range mapping.
#
# Skipping 2014-09.zip: no known date range mapping.
#
# Skipping 2014-10.zip: no known date range mapping.
#
# Skipping 2014-11.zip: no known date range mapping.
#
# Extracting from 2014-12.zip: 2010-12 to 2014-12
#  Extracted 2010-12 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2010-12
#  Extracted 2011-01 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-01
#  Extracted 2011-02 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-02
#  Extracted 2011-03 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-03
#  Extracted 2011-04 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-04
#  Extracted 2011-05 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-05
#  Extracted 2011-06 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-06
#  Extracted 2011-07 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-07
#  Extracted 2011-08 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-08
#  Extracted 2011-09 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-09
#  Extracted 2011-10 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-10
#  Extracted 2011-11 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-11
#  Extracted 2011-12 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2011-12
#  Extracted 2012-01 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-01
#  Extracted 2012-02 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-02
#  Extracted 2012-03 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-03
#  Extracted 2012-04 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-04
#  Extracted 2012-05 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-05
#  Extracted 2012-06 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-06
#  Extracted 2012-07 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-07
#  Extracted 2012-08 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-08
#  Extracted 2012-09 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-09
#  Extracted 2012-10 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-10
#  Extracted 2012-11 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-11
#  Extracted 2012-12 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2012-12
#  Extracted 2013-01 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-01
#  Extracted 2013-02 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-02
#  Extracted 2013-03 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-03
#  Extracted 2013-04 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-04
#  Extracted 2013-05 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-05
#  Extracted 2013-06 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-06
#  Extracted 2013-07 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-07
#  Extracted 2013-08 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-08
#  Extracted 2013-09 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-09
#  Extracted 2013-10 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-10
#  Extracted 2013-11 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-11
#  Extracted 2013-12 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2013-12
#  Extracted 2014-01 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-01
#  Extracted 2014-02 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-02
#  Extracted 2014-03 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-03
#  Extracted 2014-04 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-04
#  Extracted 2014-05 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-05
#  Extracted 2014-06 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-06
#  Extracted 2014-07 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-07
#  Extracted 2014-08 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-08
#  Extracted 2014-09 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-09
#  Extracted 2014-10 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-10
#  Extracted 2014-11 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-11
#  Extracted 2014-12 → C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\2014-12
#
# Skipping 2015-01.zip: no known date range mapping.
#
# Skipping 2015-02.zip: no known date range mapping.
#
# Skipping 2015-03.zip: no known date range mapping.
#
# Skipping 2015-04.zip: no known date range mapping.
#
# Skipping 2015-05.zip: no known date range mapping.
#
# Skipping 2015-06.zip: no known date range mapping.
#
# Skipping 2015-07.zip: no known date range mapping.
#
# Skipping 2015-08.zip: no known date range mapping.
#
# Skipping 2015-09.zip: no known date range mapping.
#
# Skipping 2015-10.zip: no known date range mapping.
#
# Skipping 2015-11.zip: no known date range mapping.
#
# Skipping 2015-12.zip: no known date range mapping.
#
# Skipping 2016-01.zip: no known date range mapping.
#
# Skipping 2016-02.zip: no known date range mapping.
#
# Skipping 2016-03.zip: no known date range mapping.
#
# Skipping 2016-04.zip: no known date range mapping.
#
# Skipping 2016-05.zip: no known date range mapping.
#
# Skipping 2016-06.zip: no known date range mapping.
#
# Skipping 2016-07.zip: no known date range mapping.
#
# Skipping 2016-08.zip: no known date range mapping.
#
# Skipping 2016-09.zip: no known date range mapping.
#
# Skipping 2016-10.zip: no known date range mapping.
#
# Skipping 2016-11.zip: no known date range mapping.
#
# Skipping 2016-12.zip: no known date range mapping.
#
# Skipping 2017-01.zip: no known date range mapping.
#
# Skipping 2017-02.zip: no known date range mapping.
#
# Skipping 2017-03.zip: no known date range mapping.
#
# Skipping 2017-04.zip: no known date range mapping.
#
# Skipping 2017-05.zip: no known date range mapping.
#
# Skipping 2017-06.zip: no known date range mapping.
#
# Skipping 2017-07.zip: no known date range mapping.
#
# Skipping 2017-08.zip: no known date range mapping.
#
# Skipping 2017-09.zip: no known date range mapping.
#
# Skipping 2017-10.zip: no known date range mapping.
#
# Skipping 2017-11.zip: no known date range mapping.
#
# Skipping 2017-12.zip: no known date range mapping.
#
# Skipping 2018-01.zip: no known date range mapping.
#
# Skipping 2018-02.zip: no known date range mapping.
#
# Skipping 2018-03.zip: no known date range mapping.
#
# Skipping 2018-04.zip: no known date range mapping.
#
# Skipping 2018-05.zip: no known date range mapping.
#
# Skipping 2018-06.zip: no known date range mapping.
#
# Skipping 2018-07.zip: no known date range mapping.
#
# Skipping 2018-08.zip: no known date range mapping.
#
# Skipping 2018-09.zip: no known date range mapping.
#
# Skipping 2018-10.zip: no known date range mapping.
#
# Skipping 2018-11.zip: no known date range mapping.
#
# Skipping 2018-12.zip: no known date range mapping.
#
# Skipping 2019-01.zip: no known date range mapping.
#
# Skipping 2019-02.zip: no known date range mapping.
#
# Skipping 2019-03.zip: no known date range mapping.
#
# Skipping 2019-04.zip: no known date range mapping.
#
# Skipping 2019-05.zip: no known date range mapping.
#
# Skipping 2019-06.zip: no known date range mapping.
#
# Skipping 2019-07.zip: no known date range mapping.
#
# Skipping 2019-08.zip: no known date range mapping.
#
# Skipping 2019-09.zip: no known date range mapping.
#
# Skipping 2019-10.zip: no known date range mapping.
#
# Skipping 2019-11.zip: no known date range mapping.
#
# Skipping 2019-12.zip: no known date range mapping.
#
# Skipping 2020-01.zip: no known date range mapping.
#
# Skipping 2020-02.zip: no known date range mapping.
#
# Skipping 2020-03.zip: no known date range mapping.
#
# Skipping 2020-04.zip: no known date range mapping.
#
# Skipping 2020-05.zip: no known date range mapping.
#
# Skipping 2020-06.zip: no known date range mapping.
#
# Skipping 2020-07.zip: no known date range mapping.
#
# Skipping 2020-08.zip: no known date range mapping.
#
# Skipping 2020-09.zip: no known date range mapping.
#
# Skipping 2020-10.zip: no known date range mapping.
#
# Skipping 2020-11.zip: no known date range mapping.
#
# Skipping 2020-12.zip: no known date range mapping.
#
# Skipping 2021-01.zip: no known date range mapping.
#
# Skipping 2021-02.zip: no known date range mapping.
#
# Skipping 2021-03.zip: no known date range mapping.
#
# Skipping 2021-04.zip: no known date range mapping.
#
# Skipping 2021-05.zip: no known date range mapping.
#
# Skipping 2021-06.zip: no known date range mapping.
#
# Skipping 2021-07.zip: no known date range mapping.
#
# Skipping 2021-08.zip: no known date range mapping.
#
# Skipping 2021-09.zip: no known date range mapping.
#
# Skipping 2021-10.zip: no known date range mapping.
#
# Skipping 2021-11.zip: no known date range mapping.
#
# Skipping 2021-12.zip: no known date range mapping.
#
# Skipping 2022-01.zip: no known date range mapping.
#
# Skipping 2022-02.zip: no known date range mapping.
#
# Skipping 2022-03.zip: no known date range mapping.
#
# Skipping 2022-04.zip: no known date range mapping.
#
# Skipping 2022-05.zip: no known date range mapping.
#
# Skipping 2022-06.zip: no known date range mapping.
#
# Skipping 2022-07.zip: no known date range mapping.
#
# Skipping 2022-08.zip: no known date range mapping.
#
# Skipping 2022-09.zip: no known date range mapping.
#
# Skipping 2022-10.zip: no known date range mapping.
#
# Skipping 2022-11.zip: no known date range mapping.
#
# Skipping 2022-12.zip: no known date range mapping.
#
# Skipping 2023-01.zip: no known date range mapping.
#
# Skipping 2023-02.zip: no known date range mapping.
#
# Skipping 2023-03.zip: no known date range mapping.
#
# Skipping 2023-04.zip: no known date range mapping.
#
# Skipping 2023-05.zip: no known date range mapping.
#
# Skipping 2023-06.zip: no known date range mapping.
#
# Skipping 2023-07.zip: no known date range mapping.
#
# Skipping 2023-08.zip: no known date range mapping.
#
# Skipping 2023-09.zip: no known date range mapping.
#
# Skipping 2023-10.zip: no known date range mapping.
#
# Skipping 2023-11.zip: no known date range mapping.
#
# Skipping 2023-12.zip: no known date range mapping.
#
# Skipping 2024-01.zip: no known date range mapping.
#
# Skipping 2024-02.zip: no known date range mapping.
#
# Skipping 2024-03.zip: no known date range mapping.
#
# Skipping 2024-04.zip: no known date range mapping.
#
# Skipping 2024-05.zip: no known date range mapping.
#
# Skipping 2024-06.zip: no known date range mapping.
#
# Skipping 2024-07.zip: no known date range mapping.
#
# Skipping 2024-08.zip: no known date range mapping.
#
# Skipping 2024-09.zip: no known date range mapping.
#
# Skipping 2024-10.zip: no known date range mapping.
#
# Skipping 2024-11.zip: no known date range mapping.
#
# Skipping 2024-12.zip: no known date range mapping.
#
# Skipping 2025-01.zip: no known date range mapping.
#
# Done!
# Total ZIPs processed: 134
# Total folder paths extracted: 49
# Unique extracted folders: 49
# Folder paths saved to: C:/Studie/SSML/project/police_crime_archive\extracted_2013_2025\extracted_folders.csv

# %%
import os
import pandas as pd

# 1) Define the root directory containing month-folders
root_dir = r"C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025"

# 2) Initialize an empty DataFrame for concatenation
combined_df = pd.DataFrame()

# 3) Iterate over each subfolder (YYYY-MM)
for folder_name in sorted(os.listdir(root_dir)):
    folder_path = os.path.join(root_dir, folder_name)
    print(fold)
    # Ensure we're processing only directories
    if os.path.isdir(folder_path):
        # Grab all CSV files within this folder
        csv_files = [
            f for f in os.listdir(folder_path)
            if f.lower().endswith('.csv')
        ]
        
        # Read each CSV and append to combined_df
        for csv_file in csv_files:
            csv_path = os.path.join(folder_path, csv_file)
            
            # Read the CSV
            df = pd.read_csv(csv_path)
            
            # Optionally, track which folder (year-month) this data originated from
            df['year_month'] = folder_name

            # Concatenate
            combined_df = pd.concat([combined_df, df], ignore_index=True)

# 4) Write the combined DataFrame to a single CSV file
output_csv = os.path.join(root_dir, "combined_data.csv")
combined_df.to_csv(output_csv, index=False)

print(f"Finished combining CSV files into: {output_csv}")
print(f"Total rows in the combined DataFrame: {len(combined_df)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 33
#      30             df['year_month'] = folder_name
#      32             # Concatenate
# ---> 33             combined_df = pd.concat([combined_df, df], ignore_index=True)
#      35 # 4) Write the combined DataFrame to a single CSV file
#      36 output_csv = os.path.join(root_dir, "combined_data.csv")
#
# File c:\Users\Gebruiker\anaconda3\envs\geospatial\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File c:\Users\Gebruiker\anaconda3\envs\geospatial\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File c:\Users\Gebruiker\anaconda3\envs\geospatial\Lib\site-packages\pandas\core\internals\concat.py:185, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     182     else:
#     183         values = concat_compat(vals, axis=1)
# --> 185     values = ensure_wrapped_if_datetimelike(values)
#     187     fastpath = blk.values.dtype == values.dtype
#     188 else:
#
# File c:\Users\Gebruiker\anaconda3\envs\geospatial\Lib\site-packages\pandas\core\construction.py:481, in ensure_wrapped_if_datetimelike(arr)
#     476         return obj.to_numpy()  # type: ignore[attr-defined]
#     478     return obj
# --> 481 def ensure_wrapped_if_datetimelike(arr):
#     482     """
#     483     Wrap datetime64 and timedelta64 ndarrays in DatetimeArray/TimedeltaArray.
#     484     """
#     485     if isinstance(arr, np.ndarray):
#
# KeyboardInterrupt:

# %%
import os
import pyarrow as pa
import pyarrow.csv as arrow_csv
import pyarrow.parquet as pq

def gather_csv_paths_by_pattern(root_dir: str, substring: str):
    """
    Recursively finds all CSV files under root_dir whose filenames contain the given substring.
    Returns a sorted list of absolute file paths.
    """
    matched_paths = []
    for folder_name in sorted(os.listdir(root_dir)):
        folder_path = os.path.join(root_dir, folder_name)
        if os.path.isdir(folder_path):
            csv_files = [
                f for f in os.listdir(folder_path)
                if f.lower().endswith(".csv") and substring in f.lower()
            ]
            for csv_file in csv_files:
                csv_path = os.path.join(folder_path, csv_file)
                matched_paths.append(csv_path)
    return sorted(matched_paths)

def infer_union_schema(csv_paths):
    """
    Reads each CSV (using default inference) and collects its schema.
    For each CSV that contains a 'Date' column, force cast that column to 
    timestamp[ns, tz=UTC]. Then unifies the list of schemas into one union schema.
    """
    schemas = []
    for path in csv_paths:
        table = arrow_csv.read_csv(path)
        # If the CSV has a 'Date' column, force it to timestamp[ns, tz=UTC]
        if "Date" in table.column_names:
            date_idx = table.column_names.index("Date")
            try:
                # Cast the Date column to ns resolution
                casted_date = table.column(date_idx).cast(pa.timestamp("ns", tz="UTC"))
                table = table.set_column(date_idx, "Date", casted_date)
            except Exception as e:
                print(f"Error casting 'Date' in {path}: {e}")
        schemas.append(table.schema)
    if not schemas:
        return None
    union_schema = pa.unify_schemas(schemas)
    return union_schema

def write_csvs_with_inferred_schema(csv_paths, union_schema, output_parquet):
    """
    Second pass: For each CSV path in csv_paths,
    - Reads the CSV with dictionary encoding enabled,
    - Adds missing columns as null arrays,
    - Drops extra columns,
    - Reorders columns to match union_schema,
    - Casts the table to union_schema,
    - And writes/appends the table to a single Parquet file.
    """
    if os.path.exists(output_parquet):
        os.remove(output_parquet)
    writer = None
    for path in csv_paths:
        table = arrow_csv.read_csv(
            path,
            convert_options=arrow_csv.ConvertOptions()
        )
        # If 'Date' is present, cast it to timestamp[ns, tz=UTC] as before
        if "Date" in table.column_names:
            date_idx = table.column_names.index("Date")
            try:
                table = table.set_column(date_idx, "Date", table.column(date_idx).cast(pa.timestamp("ns", tz="UTC")))
            except Exception as e:
                print(f"Error casting 'Date' in {path}: {e}")

        # 1) Add missing columns as null arrays based on union_schema
        needed_cols = [f.name for f in union_schema]
        current_cols = table.column_names
        for field in union_schema:
            if field.name not in current_cols:
                null_arr = pa.array([None] * table.num_rows, type=field.type)
                table = table.append_column(field.name, null_arr)

        # 2) Drop columns not in union_schema
        keep_indices = [i for i, cname in enumerate(table.column_names) if cname in needed_cols]
        table = table.select(keep_indices)

        # 3) Reorder columns to match union_schema exactly
        reorder_indices = []
        for field in union_schema:
            reorder_indices.append(table.column_names.index(field.name))
        table = table.select(reorder_indices)

        # 4) Cast table to union_schema for consistency
        table = table.cast(union_schema)

        # 5) Write the table incrementally using ParquetWriter
        if writer is None:
            writer = pq.ParquetWriter(output_parquet, schema=union_schema)
        else:
            if not table.schema.equals(writer.schema, check_metadata=False):
                table = table.cast(writer.schema)
        writer.write_table(table)
        print(f"Appended {table.num_rows} rows from {os.path.basename(path)} to {output_parquet}")
    if writer is not None:
        writer.close()
        print(f"\nWrote {output_parquet} with data from {len(csv_paths)} CSVs.")
    else:
        print("No CSVs to write.")

def process_csv_type(root_dir: str, substring: str, output_parquet: str):
    """
    For a given CSV type (determined by the substring in the filename):
    1. Gather CSV paths,
    2. Infer the union schema across these CSVs (forcing the 'Date' column type),
    3. Read each CSV again, unify its columns, cast to the union schema, and write incrementally to one Parquet file.
    """
    csv_paths = gather_csv_paths_by_pattern(root_dir, substring)
    if not csv_paths:
        print(f"No files matched substring '{substring}'. Nothing to do.")
        return
    union_schema = infer_union_schema(csv_paths)
    if not union_schema:
        print(f"Could not infer schema for substring '{substring}'. No CSV data?")
        return
    write_csvs_with_inferred_schema(csv_paths, union_schema, output_parquet)

# -----------------------------------------------------------------------------
if __name__ == "__main__":
    # Define the root directory containing subfolders (e.g., year-month folders)
    root_dir = r"C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025"

    # Define patterns and corresponding output Parquet filenames.
    # This will process CSVs whose filenames contain:
    #   '-street', '-stop-and-search', and '-outcomes'
    patterns = [
       # ("-street", "combined_street.parquet"),
        ("-stop-and-search", "combined_stop_and_search.parquet"),
        ("-outcomes", "combined_outcomes.parquet"),
    ]

    for pattern_substring, out_name in patterns:
        out_path = os.path.join(root_dir, out_name)
        print(f"\n=== Processing CSV type: '{pattern_substring}' ===")
        process_csv_type(root_dir, pattern_substring, out_path)
# Out:
# === Processing CSV type: '-stop-and-search' ===
# Appended 627 rows from 2015-01-avon-and-somerset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 488 rows from 2015-01-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 554 rows from 2015-01-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 360 rows from 2015-01-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1012 rows from 2015-01-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 108 rows from 2015-01-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1316 rows from 2015-01-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 247 rows from 2015-01-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 218 rows from 2015-01-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 400 rows from 2015-01-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 628 rows from 2015-01-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 238 rows from 2015-01-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 534 rows from 2015-01-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 282 rows from 2015-01-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 431 rows from 2015-01-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 329 rows from 2015-01-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 903 rows from 2015-01-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 246 rows from 2015-01-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 662 rows from 2015-01-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1420 rows from 2015-01-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1805 rows from 2015-01-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 187 rows from 2015-01-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 538 rows from 2015-02-avon-and-somerset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 455 rows from 2015-02-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 538 rows from 2015-02-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 351 rows from 2015-02-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1031 rows from 2015-02-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 84 rows from 2015-02-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 994 rows from 2015-02-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 155 rows from 2015-02-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 191 rows from 2015-02-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 334 rows from 2015-02-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 578 rows from 2015-02-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 152 rows from 2015-02-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 398 rows from 2015-02-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 256 rows from 2015-02-northamptonshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 243 rows from 2015-02-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 530 rows from 2015-02-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 278 rows from 2015-02-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 757 rows from 2015-02-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 191 rows from 2015-02-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 669 rows from 2015-02-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1330 rows from 2015-02-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1555 rows from 2015-02-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 255 rows from 2015-02-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 499 rows from 2015-03-avon-and-somerset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 114 rows from 2015-03-city-of-london-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 451 rows from 2015-03-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 755 rows from 2015-03-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 459 rows from 2015-03-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 910 rows from 2015-03-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 54 rows from 2015-03-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 870 rows from 2015-03-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 575 rows from 2015-03-hertfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 191 rows from 2015-03-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 213 rows from 2015-03-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 489 rows from 2015-03-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 546 rows from 2015-03-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 146 rows from 2015-03-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 506 rows from 2015-03-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 230 rows from 2015-03-northamptonshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 918 rows from 2015-03-northumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 225 rows from 2015-03-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 446 rows from 2015-03-south-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 362 rows from 2015-03-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 274 rows from 2015-03-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 664 rows from 2015-03-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 900 rows from 2015-03-sussex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 228 rows from 2015-03-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 730 rows from 2015-03-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1579 rows from 2015-03-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1498 rows from 2015-03-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 258 rows from 2015-03-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 601 rows from 2015-04-avon-and-somerset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 198 rows from 2015-04-bedfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 362 rows from 2015-04-btp-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 421 rows from 2015-04-cheshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 166 rows from 2015-04-city-of-london-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 507 rows from 2015-04-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 27 rows from 2015-04-cumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 403 rows from 2015-04-derbyshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 503 rows from 2015-04-devon-and-cornwall-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 515 rows from 2015-04-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 511 rows from 2015-04-durham-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 359 rows from 2015-04-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 206 rows from 2015-04-essex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 137 rows from 2015-04-gloucestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 736 rows from 2015-04-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 130 rows from 2015-04-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 781 rows from 2015-04-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 498 rows from 2015-04-hertfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 123 rows from 2015-04-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 617 rows from 2015-04-kent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 467 rows from 2015-04-lancashire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 158 rows from 2015-04-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 365 rows from 2015-04-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 747 rows from 2015-04-merseyside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 11126 rows from 2015-04-metropolitan-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 551 rows from 2015-04-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 221 rows from 2015-04-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 384 rows from 2015-04-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 134 rows from 2015-04-northamptonshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 642 rows from 2015-04-northumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 203 rows from 2015-04-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 765 rows from 2015-04-south-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 424 rows from 2015-04-south-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 365 rows from 2015-04-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 223 rows from 2015-04-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 624 rows from 2015-04-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 909 rows from 2015-04-sussex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 905 rows from 2015-04-thames-valley-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 183 rows from 2015-04-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 695 rows from 2015-04-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1371 rows from 2015-04-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1132 rows from 2015-04-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 207 rows from 2015-04-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 158 rows from 2015-05-bedfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 330 rows from 2015-05-btp-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 505 rows from 2015-05-cheshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 110 rows from 2015-05-city-of-london-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 435 rows from 2015-05-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 131 rows from 2015-05-cumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 342 rows from 2015-05-derbyshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 594 rows from 2015-05-devon-and-cornwall-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 412 rows from 2015-05-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 588 rows from 2015-05-durham-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 488 rows from 2015-05-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 272 rows from 2015-05-essex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 189 rows from 2015-05-gloucestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 744 rows from 2015-05-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 130 rows from 2015-05-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 805 rows from 2015-05-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 486 rows from 2015-05-hertfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 113 rows from 2015-05-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 630 rows from 2015-05-kent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 404 rows from 2015-05-lancashire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 162 rows from 2015-05-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 788 rows from 2015-05-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 658 rows from 2015-05-merseyside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 11363 rows from 2015-05-metropolitan-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 510 rows from 2015-05-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 229 rows from 2015-05-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 444 rows from 2015-05-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 205 rows from 2015-05-northamptonshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 649 rows from 2015-05-northumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 248 rows from 2015-05-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 693 rows from 2015-05-south-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 423 rows from 2015-05-south-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 387 rows from 2015-05-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 279 rows from 2015-05-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 693 rows from 2015-05-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 841 rows from 2015-05-sussex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 975 rows from 2015-05-thames-valley-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 261 rows from 2015-05-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 803 rows from 2015-05-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1442 rows from 2015-05-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1314 rows from 2015-05-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 246 rows from 2015-05-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 135 rows from 2015-06-bedfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 317 rows from 2015-06-btp-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 513 rows from 2015-06-cheshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 107 rows from 2015-06-city-of-london-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 396 rows from 2015-06-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 249 rows from 2015-06-cumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 324 rows from 2015-06-derbyshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 594 rows from 2015-06-devon-and-cornwall-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 432 rows from 2015-06-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 486 rows from 2015-06-durham-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 400 rows from 2015-06-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 188 rows from 2015-06-essex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 170 rows from 2015-06-gloucestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 713 rows from 2015-06-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 129 rows from 2015-06-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1093 rows from 2015-06-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 616 rows from 2015-06-hertfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 59 rows from 2015-06-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 599 rows from 2015-06-kent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 423 rows from 2015-06-lancashire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 110 rows from 2015-06-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 399 rows from 2015-06-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 688 rows from 2015-06-merseyside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 11951 rows from 2015-06-metropolitan-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 568 rows from 2015-06-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 230 rows from 2015-06-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 480 rows from 2015-06-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 150 rows from 2015-06-northamptonshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 657 rows from 2015-06-northumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 166 rows from 2015-06-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 699 rows from 2015-06-south-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 344 rows from 2015-06-south-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 384 rows from 2015-06-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 247 rows from 2015-06-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 606 rows from 2015-06-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 905 rows from 2015-06-sussex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 986 rows from 2015-06-thames-valley-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 227 rows from 2015-06-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 718 rows from 2015-06-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1336 rows from 2015-06-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1159 rows from 2015-06-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 354 rows from 2015-06-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 552 rows from 2015-07-avon-and-somerset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 107 rows from 2015-07-bedfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 352 rows from 2015-07-btp-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 534 rows from 2015-07-cheshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 132 rows from 2015-07-city-of-london-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 281 rows from 2015-07-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 335 rows from 2015-07-cumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 339 rows from 2015-07-derbyshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 584 rows from 2015-07-devon-and-cornwall-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 526 rows from 2015-07-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 441 rows from 2015-07-durham-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 313 rows from 2015-07-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 192 rows from 2015-07-essex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 181 rows from 2015-07-gloucestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 575 rows from 2015-07-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 115 rows from 2015-07-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 890 rows from 2015-07-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 582 rows from 2015-07-hertfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 79 rows from 2015-07-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 525 rows from 2015-07-kent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 492 rows from 2015-07-lancashire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 148 rows from 2015-07-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 349 rows from 2015-07-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 879 rows from 2015-07-merseyside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 12832 rows from 2015-07-metropolitan-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 588 rows from 2015-07-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 228 rows from 2015-07-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 418 rows from 2015-07-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 169 rows from 2015-07-northamptonshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 705 rows from 2015-07-northumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 165 rows from 2015-07-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 614 rows from 2015-07-south-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 344 rows from 2015-07-south-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 332 rows from 2015-07-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 285 rows from 2015-07-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 517 rows from 2015-07-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 806 rows from 2015-07-sussex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1136 rows from 2015-07-thames-valley-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 249 rows from 2015-07-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 721 rows from 2015-07-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1356 rows from 2015-07-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1270 rows from 2015-07-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 253 rows from 2015-07-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 133 rows from 2015-08-bedfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 322 rows from 2015-08-btp-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 252 rows from 2015-08-cambridgeshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 572 rows from 2015-08-cheshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 150 rows from 2015-08-city-of-london-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 205 rows from 2015-08-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 387 rows from 2015-08-cumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 351 rows from 2015-08-derbyshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 510 rows from 2015-08-devon-and-cornwall-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 493 rows from 2015-08-dorset-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 359 rows from 2015-08-durham-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 279 rows from 2015-08-dyfed-powys-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 174 rows from 2015-08-essex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 215 rows from 2015-08-gloucestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 422 rows from 2015-08-greater-manchester-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 155 rows from 2015-08-gwent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1439 rows from 2015-08-hampshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 633 rows from 2015-08-hertfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 71 rows from 2015-08-humberside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 587 rows from 2015-08-kent-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 443 rows from 2015-08-lancashire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 174 rows from 2015-08-leicestershire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 279 rows from 2015-08-lincolnshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 907 rows from 2015-08-merseyside-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 12128 rows from 2015-08-metropolitan-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 487 rows from 2015-08-norfolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 242 rows from 2015-08-north-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 500 rows from 2015-08-north-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 165 rows from 2015-08-northamptonshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 543 rows from 2015-08-northumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 155 rows from 2015-08-nottinghamshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 344 rows from 2015-08-south-wales-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 309 rows from 2015-08-south-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 435 rows from 2015-08-staffordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 229 rows from 2015-08-suffolk-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 520 rows from 2015-08-surrey-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 725 rows from 2015-08-sussex-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1149 rows from 2015-08-thames-valley-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 340 rows from 2015-08-warwickshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 766 rows from 2015-08-west-mercia-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1191 rows from 2015-08-west-midlands-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 1084 rows from 2015-08-west-yorkshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 220 rows from 2015-08-wiltshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 181 rows from 2015-09-bedfordshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 244 rows from 2015-09-btp-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 215 rows from 2015-09-cambridgeshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 454 rows from 2015-09-cheshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 140 rows from 2015-09-city-of-london-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 169 rows from 2015-09-cleveland-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 474 rows from 2015-09-cumbria-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# Appended 318 rows from 2015-09-derbyshire-stop-and-search.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_stop_and_search.parquet
# ...
# Appended 7207 rows from 2024-11-humberside-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 13692 rows from 2024-11-kent-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11086 rows from 2024-11-lancashire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8052 rows from 2024-11-leicestershire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7356 rows from 2024-11-lincolnshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11569 rows from 2024-11-merseyside-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 90962 rows from 2024-11-metropolitan-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5948 rows from 2024-11-norfolk-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4279 rows from 2024-11-north-wales-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4938 rows from 2024-11-northamptonshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8785 rows from 2024-11-northumbria-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8566 rows from 2024-11-nottinghamshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 9165 rows from 2024-11-south-wales-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 13140 rows from 2024-11-south-yorkshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7405 rows from 2024-11-staffordshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4265 rows from 2024-11-suffolk-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 6779 rows from 2024-11-surrey-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11321 rows from 2024-11-sussex-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 14395 rows from 2024-11-thames-valley-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3825 rows from 2024-11-warwickshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7334 rows from 2024-11-west-mercia-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 27587 rows from 2024-11-west-midlands-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 25225 rows from 2024-11-west-yorkshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3316 rows from 2024-11-wiltshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8745 rows from 2024-12-avon-and-somerset-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4742 rows from 2024-12-bedfordshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5059 rows from 2024-12-cambridgeshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4879 rows from 2024-12-cheshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 690 rows from 2024-12-city-of-london-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5873 rows from 2024-12-cleveland-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3040 rows from 2024-12-cumbria-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7189 rows from 2024-12-derbyshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 9564 rows from 2024-12-devon-and-cornwall-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4412 rows from 2024-12-dorset-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5223 rows from 2024-12-durham-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 2879 rows from 2024-12-dyfed-powys-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 10500 rows from 2024-12-essex-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3494 rows from 2024-12-gloucestershire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5822 rows from 2024-12-gwent-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 12932 rows from 2024-12-hampshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7072 rows from 2024-12-hertfordshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 6941 rows from 2024-12-humberside-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 12630 rows from 2024-12-kent-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11091 rows from 2024-12-lancashire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7749 rows from 2024-12-leicestershire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7326 rows from 2024-12-lincolnshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11256 rows from 2024-12-merseyside-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 80489 rows from 2024-12-metropolitan-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5521 rows from 2024-12-norfolk-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4348 rows from 2024-12-north-wales-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4960 rows from 2024-12-northamptonshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7806 rows from 2024-12-northumbria-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8057 rows from 2024-12-nottinghamshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8757 rows from 2024-12-south-wales-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11932 rows from 2024-12-south-yorkshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7042 rows from 2024-12-staffordshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3845 rows from 2024-12-suffolk-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 6439 rows from 2024-12-surrey-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 12823 rows from 2024-12-sussex-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 13995 rows from 2024-12-thames-valley-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3413 rows from 2024-12-warwickshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 6496 rows from 2024-12-west-mercia-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 26514 rows from 2024-12-west-midlands-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 23131 rows from 2024-12-west-yorkshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3207 rows from 2024-12-wiltshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8689 rows from 2025-01-avon-and-somerset-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4348 rows from 2025-01-bedfordshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5464 rows from 2025-01-cambridgeshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 6539 rows from 2025-01-cheshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 760 rows from 2025-01-city-of-london-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5740 rows from 2025-01-cleveland-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 2939 rows from 2025-01-cumbria-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7236 rows from 2025-01-derbyshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11280 rows from 2025-01-devon-and-cornwall-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3850 rows from 2025-01-dorset-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5310 rows from 2025-01-durham-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 2372 rows from 2025-01-dyfed-powys-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11871 rows from 2025-01-essex-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3393 rows from 2025-01-gloucestershire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 6344 rows from 2025-01-gwent-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 12370 rows from 2025-01-hampshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8420 rows from 2025-01-hertfordshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7005 rows from 2025-01-humberside-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 14468 rows from 2025-01-kent-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11277 rows from 2025-01-lancashire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7914 rows from 2025-01-leicestershire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 9278 rows from 2025-01-lincolnshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 11247 rows from 2025-01-merseyside-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 85917 rows from 2025-01-metropolitan-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 5713 rows from 2025-01-norfolk-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4466 rows from 2025-01-north-wales-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4925 rows from 2025-01-northamptonshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8101 rows from 2025-01-northumbria-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8396 rows from 2025-01-nottinghamshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8774 rows from 2025-01-south-wales-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 12040 rows from 2025-01-south-yorkshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 8635 rows from 2025-01-staffordshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3919 rows from 2025-01-suffolk-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 6426 rows from 2025-01-surrey-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 16094 rows from 2025-01-thames-valley-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 4430 rows from 2025-01-warwickshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 7267 rows from 2025-01-west-mercia-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 25431 rows from 2025-01-west-midlands-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 22031 rows from 2025-01-west-yorkshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
# Appended 3789 rows from 2025-01-wiltshire-outcomes.csv to C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet
#
# Wrote C:/Studie/SSML/project/police_crime_archive/extracted_2013_2025\combined_outcomes.parquet with data from 6676 CSVs.

# %%
import os
import pyarrow as pa
import pyarrow.dataset as ds
import geopandas as gpd
import pandas as pd

def chunked_parquet_to_gpkg(parquet_file, gpkg_file, layer_name, chunksize=1_000_000):
    """
    Streams the Parquet in batches, building partial GeoDataFrames,
    writing each chunk to a TEMP GPKG, then merges at the end.
    
    Args:
        parquet_file (str): Path to your Parquet file.
        gpkg_file (str): Path to the final GeoPackage to create.
        layer_name (str): Layer name within the GeoPackage.
        chunksize (int): Number of rows (approx) per chunk. 
                         Adjust to fit your memory constraints.
    """
    # 1) Build a PyArrow Dataset from the Parquet file
    dataset = ds.dataset(parquet_file, format="parquet")

    # We'll gather partial GPKGs in a list for merging
    temp_files = []
    chunk_idx = 0

    # 2) Read in batches using to_batches
    for record_batch in dataset.to_batches(batch_size=chunksize):
        # Convert record_batch -> a small PyArrow Table -> Pandas
        table = pa.Table.from_batches([record_batch])
        df = table.to_pandas()

        # 3) Create geometry column from (Longitude, Latitude)
        gdf = gpd.GeoDataFrame(
            df,
            geometry=gpd.points_from_xy(df['Longitude'], df['Latitude']),
            crs="EPSG:4326"
        )

        # 4) Write chunk to a temporary GPKG
        temp_gpkg = f"{gpkg_file}_temp_{chunk_idx}.gpkg"
        gdf.to_file(temp_gpkg, layer=layer_name, driver="GPKG")
        temp_files.append(temp_gpkg)

        print(f"Wrote chunk {chunk_idx} with {len(gdf)} rows to {temp_gpkg}")
        chunk_idx += 1

    # 5) Merge partial GPKGs if needed
    # NOTE: This step can be memory-heavy if all chunks combined are large.
    #       If your data is huge, consider merging with an external tool
    #       or storing in a DB (e.g., SpatiaLite/PostGIS) instead.
    if temp_files:
        merged_gdf = None
        for i, temp_path in enumerate(temp_files):
            chunk_gdf = gpd.read_file(temp_path, layer=layer_name)
            if merged_gdf is None:
                merged_gdf = chunk_gdf
            else:
                merged_gdf = gpd.GeoDataFrame(
                    pd.concat([merged_gdf, chunk_gdf], ignore_index=True),
                    crs=chunk_gdf.crs
                )
        
        # Finally, write merged result to the final GPKG
        merged_gdf.to_file(gpkg_file, layer=layer_name, driver="GPKG")
        print(f"\nFinal GPKG with {len(merged_gdf)} rows: {gpkg_file}")

        # Clean up temporary chunk files
        for f in temp_files:
            os.remove(f)
    else:
        print("No data to write (no chunks).")



# Usage: chunked approach
street_parquet = r"C:\Studie\SSML\project\police_crime_archive\extracted_2013_2025\combined_street.parquet"
gpkg_path = r"crime_data.gpkg"
chunked_parquet_to_gpkg(street_parquet, gpkg_path, layer_name="street_data")
# Out:
# Wrote chunk 0 with 12201 rows to crime_data.gpkg_temp_0.gpkg
# Wrote chunk 1 with 5393 rows to crime_data.gpkg_temp_1.gpkg
# Wrote chunk 2 with 1470 rows to crime_data.gpkg_temp_2.gpkg
# Wrote chunk 3 with 5916 rows to crime_data.gpkg_temp_3.gpkg
# Wrote chunk 4 with 4363 rows to crime_data.gpkg_temp_4.gpkg
# Wrote chunk 5 with 635 rows to crime_data.gpkg_temp_5.gpkg
# Wrote chunk 6 with 6195 rows to crime_data.gpkg_temp_6.gpkg
# Wrote chunk 7 with 4083 rows to crime_data.gpkg_temp_7.gpkg
# Wrote chunk 8 with 8316 rows to crime_data.gpkg_temp_8.gpkg
# Wrote chunk 9 with 9829 rows to crime_data.gpkg_temp_9.gpkg
# Wrote chunk 10 with 6190 rows to crime_data.gpkg_temp_10.gpkg
# Wrote chunk 11 with 2119 rows to crime_data.gpkg_temp_11.gpkg
# Wrote chunk 12 with 3330 rows to crime_data.gpkg_temp_12.gpkg
# Wrote chunk 13 with 11736 rows to crime_data.gpkg_temp_13.gpkg
# Wrote chunk 14 with 4581 rows to crime_data.gpkg_temp_14.gpkg
# Wrote chunk 15 with 25968 rows to crime_data.gpkg_temp_15.gpkg
# Wrote chunk 16 with 6258 rows to crime_data.gpkg_temp_16.gpkg
# Wrote chunk 17 with 14347 rows to crime_data.gpkg_temp_17.gpkg
# Wrote chunk 18 with 8843 rows to crime_data.gpkg_temp_18.gpkg
# Wrote chunk 19 with 6976 rows to crime_data.gpkg_temp_19.gpkg
# Wrote chunk 20 with 12811 rows to crime_data.gpkg_temp_20.gpkg
# Wrote chunk 21 with 15013 rows to crime_data.gpkg_temp_21.gpkg
# Wrote chunk 22 with 7339 rows to crime_data.gpkg_temp_22.gpkg
# Wrote chunk 23 with 4999 rows to crime_data.gpkg_temp_23.gpkg
# Wrote chunk 24 with 11194 rows to crime_data.gpkg_temp_24.gpkg
# Wrote chunk 25 with 92442 rows to crime_data.gpkg_temp_25.gpkg
# Wrote chunk 26 with 6077 rows to crime_data.gpkg_temp_26.gpkg
# Wrote chunk 27 with 5335 rows to crime_data.gpkg_temp_27.gpkg
# Wrote chunk 28 with 5439 rows to crime_data.gpkg_temp_28.gpkg
# Wrote chunk 29 with 5949 rows to crime_data.gpkg_temp_29.gpkg
# Wrote chunk 30 with 12072 rows to crime_data.gpkg_temp_30.gpkg
# Wrote chunk 31 with 9478 rows to crime_data.gpkg_temp_31.gpkg
# Wrote chunk 32 with 11473 rows to crime_data.gpkg_temp_32.gpkg
# Wrote chunk 33 with 13405 rows to crime_data.gpkg_temp_33.gpkg
# Wrote chunk 34 with 6942 rows to crime_data.gpkg_temp_34.gpkg
# Wrote chunk 35 with 5631 rows to crime_data.gpkg_temp_35.gpkg
# Wrote chunk 36 with 8861 rows to crime_data.gpkg_temp_36.gpkg
# Wrote chunk 37 with 12988 rows to crime_data.gpkg_temp_37.gpkg
# Wrote chunk 38 with 16071 rows to crime_data.gpkg_temp_38.gpkg
# Wrote chunk 39 with 3958 rows to crime_data.gpkg_temp_39.gpkg
# Wrote chunk 40 with 9643 rows to crime_data.gpkg_temp_40.gpkg
# Wrote chunk 41 with 22838 rows to crime_data.gpkg_temp_41.gpkg
# Wrote chunk 42 with 21296 rows to crime_data.gpkg_temp_42.gpkg
# Wrote chunk 43 with 4338 rows to crime_data.gpkg_temp_43.gpkg
# Wrote chunk 44 with 13781 rows to crime_data.gpkg_temp_44.gpkg
# Wrote chunk 45 with 5862 rows to crime_data.gpkg_temp_45.gpkg
# Wrote chunk 46 with 1755 rows to crime_data.gpkg_temp_46.gpkg
# Wrote chunk 47 with 6682 rows to crime_data.gpkg_temp_47.gpkg
# Wrote chunk 48 with 4837 rows to crime_data.gpkg_temp_48.gpkg
# Wrote chunk 49 with 696 rows to crime_data.gpkg_temp_49.gpkg
# Wrote chunk 50 with 7256 rows to crime_data.gpkg_temp_50.gpkg
# Wrote chunk 51 with 4116 rows to crime_data.gpkg_temp_51.gpkg
# Wrote chunk 52 with 9424 rows to crime_data.gpkg_temp_52.gpkg
# Wrote chunk 53 with 10220 rows to crime_data.gpkg_temp_53.gpkg
# Wrote chunk 54 with 3187 rows to crime_data.gpkg_temp_54.gpkg
# Wrote chunk 55 with 6358 rows to crime_data.gpkg_temp_55.gpkg
# Wrote chunk 56 with 3636 rows to crime_data.gpkg_temp_56.gpkg
# Wrote chunk 57 with 12565 rows to crime_data.gpkg_temp_57.gpkg
# Wrote chunk 58 with 4934 rows to crime_data.gpkg_temp_58.gpkg
# Wrote chunk 59 with 29267 rows to crime_data.gpkg_temp_59.gpkg
# Wrote chunk 60 with 6544 rows to crime_data.gpkg_temp_60.gpkg
# Wrote chunk 61 with 15767 rows to crime_data.gpkg_temp_61.gpkg
# Wrote chunk 62 with 9097 rows to crime_data.gpkg_temp_62.gpkg
# Wrote chunk 63 with 8949 rows to crime_data.gpkg_temp_63.gpkg
# Wrote chunk 64 with 13249 rows to crime_data.gpkg_temp_64.gpkg
# Wrote chunk 65 with 16041 rows to crime_data.gpkg_temp_65.gpkg
# Wrote chunk 66 with 7939 rows to crime_data.gpkg_temp_66.gpkg
# Wrote chunk 67 with 6290 rows to crime_data.gpkg_temp_67.gpkg
# Wrote chunk 68 with 12188 rows to crime_data.gpkg_temp_68.gpkg
# Wrote chunk 69 with 99099 rows to crime_data.gpkg_temp_69.gpkg
# Wrote chunk 70 with 6678 rows to crime_data.gpkg_temp_70.gpkg
# Wrote chunk 71 with 5177 rows to crime_data.gpkg_temp_71.gpkg
# Wrote chunk 72 with 6261 rows to crime_data.gpkg_temp_72.gpkg
# Wrote chunk 73 with 6641 rows to crime_data.gpkg_temp_73.gpkg
# Wrote chunk 74 with 13282 rows to crime_data.gpkg_temp_74.gpkg
# Wrote chunk 75 with 10782 rows to crime_data.gpkg_temp_75.gpkg
# Wrote chunk 76 with 13082 rows to crime_data.gpkg_temp_76.gpkg
# Wrote chunk 77 with 15676 rows to crime_data.gpkg_temp_77.gpkg
# Wrote chunk 78 with 7057 rows to crime_data.gpkg_temp_78.gpkg
# Wrote chunk 79 with 6044 rows to crime_data.gpkg_temp_79.gpkg
# Wrote chunk 80 with 8920 rows to crime_data.gpkg_temp_80.gpkg
# Wrote chunk 81 with 11303 rows to crime_data.gpkg_temp_81.gpkg
# Wrote chunk 82 with 14545 rows to crime_data.gpkg_temp_82.gpkg
# Wrote chunk 83 with 4393 rows to crime_data.gpkg_temp_83.gpkg
# Wrote chunk 84 with 10749 rows to crime_data.gpkg_temp_84.gpkg
# Wrote chunk 85 with 25515 rows to crime_data.gpkg_temp_85.gpkg
# Wrote chunk 86 with 24287 rows to crime_data.gpkg_temp_86.gpkg
# Wrote chunk 87 with 4510 rows to crime_data.gpkg_temp_87.gpkg
# Wrote chunk 88 with 13998 rows to crime_data.gpkg_temp_88.gpkg
# Wrote chunk 89 with 5864 rows to crime_data.gpkg_temp_89.gpkg
# Wrote chunk 90 with 1683 rows to crime_data.gpkg_temp_90.gpkg
# Wrote chunk 91 with 6481 rows to crime_data.gpkg_temp_91.gpkg
# Wrote chunk 92 with 4725 rows to crime_data.gpkg_temp_92.gpkg
# Wrote chunk 93 with 678 rows to crime_data.gpkg_temp_93.gpkg
# Wrote chunk 94 with 7351 rows to crime_data.gpkg_temp_94.gpkg
# Wrote chunk 95 with 4313 rows to crime_data.gpkg_temp_95.gpkg
# Wrote chunk 96 with 9239 rows to crime_data.gpkg_temp_96.gpkg
# Wrote chunk 97 with 10170 rows to crime_data.gpkg_temp_97.gpkg
# Wrote chunk 98 with 6647 rows to crime_data.gpkg_temp_98.gpkg
# Wrote chunk 99 with 6377 rows to crime_data.gpkg_temp_99.gpkg
# Wrote chunk 100 with 3720 rows to crime_data.gpkg_temp_100.gpkg
# Wrote chunk 101 with 12683 rows to crime_data.gpkg_temp_101.gpkg
# Wrote chunk 102 with 5163 rows to crime_data.gpkg_temp_102.gpkg
# Wrote chunk 103 with 28319 rows to crime_data.gpkg_temp_103.gpkg
# Wrote chunk 104 with 5349 rows to crime_data.gpkg_temp_104.gpkg
# Wrote chunk 105 with 15548 rows to crime_data.gpkg_temp_105.gpkg
# Wrote chunk 106 with 9241 rows to crime_data.gpkg_temp_106.gpkg
# Wrote chunk 107 with 8565 rows to crime_data.gpkg_temp_107.gpkg
# Wrote chunk 108 with 13138 rows to crime_data.gpkg_temp_108.gpkg
# Wrote chunk 109 with 15711 rows to crime_data.gpkg_temp_109.gpkg
# Wrote chunk 110 with 8066 rows to crime_data.gpkg_temp_110.gpkg
# Wrote chunk 111 with 6002 rows to crime_data.gpkg_temp_111.gpkg
# Wrote chunk 112 with 12404 rows to crime_data.gpkg_temp_112.gpkg
# Wrote chunk 113 with 94179 rows to crime_data.gpkg_temp_113.gpkg
# Wrote chunk 114 with 6503 rows to crime_data.gpkg_temp_114.gpkg
# Wrote chunk 115 with 5299 rows to crime_data.gpkg_temp_115.gpkg
# Wrote chunk 116 with 6108 rows to crime_data.gpkg_temp_116.gpkg
# Wrote chunk 117 with 6464 rows to crime_data.gpkg_temp_117.gpkg
# Wrote chunk 118 with 13290 rows to crime_data.gpkg_temp_118.gpkg
# Wrote chunk 119 with 10560 rows to crime_data.gpkg_temp_119.gpkg
# Wrote chunk 120 with 12692 rows to crime_data.gpkg_temp_120.gpkg
# Wrote chunk 121 with 15982 rows to crime_data.gpkg_temp_121.gpkg
# Wrote chunk 122 with 7477 rows to crime_data.gpkg_temp_122.gpkg
# Wrote chunk 123 with 6096 rows to crime_data.gpkg_temp_123.gpkg
# Wrote chunk 124 with 8639 rows to crime_data.gpkg_temp_124.gpkg
# Wrote chunk 125 with 13694 rows to crime_data.gpkg_temp_125.gpkg
# Wrote chunk 126 with 17727 rows to crime_data.gpkg_temp_126.gpkg
# Wrote chunk 127 with 4215 rows to crime_data.gpkg_temp_127.gpkg
# Wrote chunk 128 with 10850 rows to crime_data.gpkg_temp_128.gpkg
# Wrote chunk 129 with 25558 rows to crime_data.gpkg_temp_129.gpkg
# Wrote chunk 130 with 22815 rows to crime_data.gpkg_temp_130.gpkg
# Wrote chunk 131 with 4746 rows to crime_data.gpkg_temp_131.gpkg
# Wrote chunk 132 with 15259 rows to crime_data.gpkg_temp_132.gpkg
# Wrote chunk 133 with 6503 rows to crime_data.gpkg_temp_133.gpkg
# Wrote chunk 134 with 1854 rows to crime_data.gpkg_temp_134.gpkg
# Wrote chunk 135 with 7213 rows to crime_data.gpkg_temp_135.gpkg
# Wrote chunk 136 with 8802 rows to crime_data.gpkg_temp_136.gpkg
# Wrote chunk 137 with 820 rows to crime_data.gpkg_temp_137.gpkg
# Wrote chunk 138 with 8587 rows to crime_data.gpkg_temp_138.gpkg
# Wrote chunk 139 with 4592 rows to crime_data.gpkg_temp_139.gpkg
# Wrote chunk 140 with 10347 rows to crime_data.gpkg_temp_140.gpkg
# Wrote chunk 141 with 11249 rows to crime_data.gpkg_temp_141.gpkg
# Wrote chunk 142 with 7273 rows to crime_data.gpkg_temp_142.gpkg
# Wrote chunk 143 with 7378 rows to crime_data.gpkg_temp_143.gpkg
# Wrote chunk 144 with 3741 rows to crime_data.gpkg_temp_144.gpkg
# Wrote chunk 145 with 13810 rows to crime_data.gpkg_temp_145.gpkg
# Wrote chunk 146 with 5710 rows to crime_data.gpkg_temp_146.gpkg
# Wrote chunk 147 with 32842 rows to crime_data.gpkg_temp_147.gpkg
# Wrote chunk 148 with 6381 rows to crime_data.gpkg_temp_148.gpkg
# Wrote chunk 149 with 17326 rows to crime_data.gpkg_temp_149.gpkg
# Wrote chunk 150 with 9816 rows to crime_data.gpkg_temp_150.gpkg
# Wrote chunk 151 with 9757 rows to crime_data.gpkg_temp_151.gpkg
# Wrote chunk 152 with 14753 rows to crime_data.gpkg_temp_152.gpkg
# Wrote chunk 153 with 16594 rows to crime_data.gpkg_temp_153.gpkg
# Wrote chunk 154 with 9057 rows to crime_data.gpkg_temp_154.gpkg
# Wrote chunk 155 with 6754 rows to crime_data.gpkg_temp_155.gpkg
# Wrote chunk 156 with 14533 rows to crime_data.gpkg_temp_156.gpkg
# Wrote chunk 157 with 104861 rows to crime_data.gpkg_temp_157.gpkg
# Wrote chunk 158 with 7408 rows to crime_data.gpkg_temp_158.gpkg
# Wrote chunk 159 with 5789 rows to crime_data.gpkg_temp_159.gpkg
# Wrote chunk 160 with 7199 rows to crime_data.gpkg_temp_160.gpkg
# Wrote chunk 161 with 7765 rows to crime_data.gpkg_temp_161.gpkg
# Wrote chunk 162 with 15283 rows to crime_data.gpkg_temp_162.gpkg
# Wrote chunk 163 with 12130 rows to crime_data.gpkg_temp_163.gpkg
# Wrote chunk 164 with 14826 rows to crime_data.gpkg_temp_164.gpkg
# Wrote chunk 165 with 17915 rows to crime_data.gpkg_temp_165.gpkg
# Wrote chunk 166 with 9143 rows to crime_data.gpkg_temp_166.gpkg
# Wrote chunk 167 with 6719 rows to crime_data.gpkg_temp_167.gpkg
# Wrote chunk 168 with 9541 rows to crime_data.gpkg_temp_168.gpkg
# Wrote chunk 169 with 15670 rows to crime_data.gpkg_temp_169.gpkg
# Wrote chunk 170 with 18338 rows to crime_data.gpkg_temp_170.gpkg
# Wrote chunk 171 with 4665 rows to crime_data.gpkg_temp_171.gpkg
# Wrote chunk 172 with 12144 rows to crime_data.gpkg_temp_172.gpkg
# Wrote chunk 173 with 28958 rows to crime_data.gpkg_temp_173.gpkg
# Wrote chunk 174 with 25906 rows to crime_data.gpkg_temp_174.gpkg
# Wrote chunk 175 with 2772 rows to crime_data.gpkg_temp_175.gpkg
# Wrote chunk 176 with 16688 rows to crime_data.gpkg_temp_176.gpkg
# Wrote chunk 177 with 6881 rows to crime_data.gpkg_temp_177.gpkg
# Wrote chunk 178 with 1621 rows to crime_data.gpkg_temp_178.gpkg
# Wrote chunk 179 with 7902 rows to crime_data.gpkg_temp_179.gpkg
# Wrote chunk 180 with 8889 rows to crime_data.gpkg_temp_180.gpkg
# Wrote chunk 181 with 692 rows to crime_data.gpkg_temp_181.gpkg
# Wrote chunk 182 with 8335 rows to crime_data.gpkg_temp_182.gpkg
# Wrote chunk 183 with 4954 rows to crime_data.gpkg_temp_183.gpkg
# Wrote chunk 184 with 10976 rows to crime_data.gpkg_temp_184.gpkg
# Wrote chunk 185 with 13926 rows to crime_data.gpkg_temp_185.gpkg
# Wrote chunk 186 with 7495 rows to crime_data.gpkg_temp_186.gpkg
# Wrote chunk 187 with 7129 rows to crime_data.gpkg_temp_187.gpkg
# Wrote chunk 188 with 3609 rows to crime_data.gpkg_temp_188.gpkg
# Wrote chunk 189 with 14506 rows to crime_data.gpkg_temp_189.gpkg
# Wrote chunk 190 with 5950 rows to crime_data.gpkg_temp_190.gpkg
# Wrote chunk 191 with 32551 rows to crime_data.gpkg_temp_191.gpkg
# Wrote chunk 192 with 5981 rows to crime_data.gpkg_temp_192.gpkg
# Wrote chunk 193 with 19325 rows to crime_data.gpkg_temp_193.gpkg
# Wrote chunk 194 with 10098 rows to crime_data.gpkg_temp_194.gpkg
# Wrote chunk 195 with 9868 rows to crime_data.gpkg_temp_195.gpkg
# Wrote chunk 196 with 15363 rows to crime_data.gpkg_temp_196.gpkg
# Wrote chunk 197 with 20424 rows to crime_data.gpkg_temp_197.gpkg
# Wrote chunk 198 with 9049 rows to crime_data.gpkg_temp_198.gpkg
# Wrote chunk 199 with 7044 rows to crime_data.gpkg_temp_199.gpkg
# Wrote chunk 200 with 15217 rows to crime_data.gpkg_temp_200.gpkg
# Wrote chunk 201 with 107029 rows to crime_data.gpkg_temp_201.gpkg
# Wrote chunk 202 with 8066 rows to crime_data.gpkg_temp_202.gpkg
# Wrote chunk 203 with 6288 rows to crime_data.gpkg_temp_203.gpkg
# Wrote chunk 204 with 7405 rows to crime_data.gpkg_temp_204.gpkg
# Wrote chunk 205 with 8491 rows to crime_data.gpkg_temp_205.gpkg
# Wrote chunk 206 with 15490 rows to crime_data.gpkg_temp_206.gpkg
# Wrote chunk 207 with 12371 rows to crime_data.gpkg_temp_207.gpkg
# Wrote chunk 208 with 14795 rows to crime_data.gpkg_temp_208.gpkg
# Wrote chunk 209 with 18124 rows to crime_data.gpkg_temp_209.gpkg
# Wrote chunk 210 with 9144 rows to crime_data.gpkg_temp_210.gpkg
# Wrote chunk 211 with 7356 rows to crime_data.gpkg_temp_211.gpkg
# Wrote chunk 212 with 9909 rows to crime_data.gpkg_temp_212.gpkg
# Wrote chunk 213 with 16211 rows to crime_data.gpkg_temp_213.gpkg
# Wrote chunk 214 with 19564 rows to crime_data.gpkg_temp_214.gpkg
# Wrote chunk 215 with 5040 rows to crime_data.gpkg_temp_215.gpkg
# Wrote chunk 216 with 12271 rows to crime_data.gpkg_temp_216.gpkg
# Wrote chunk 217 with 31273 rows to crime_data.gpkg_temp_217.gpkg
# Wrote chunk 218 with 27347 rows to crime_data.gpkg_temp_218.gpkg
# Wrote chunk 219 with 5762 rows to crime_data.gpkg_temp_219.gpkg
# Wrote chunk 220 with 15930 rows to crime_data.gpkg_temp_220.gpkg
# Wrote chunk 221 with 6639 rows to crime_data.gpkg_temp_221.gpkg
# Wrote chunk 222 with 1751 rows to crime_data.gpkg_temp_222.gpkg
# Wrote chunk 223 with 7579 rows to crime_data.gpkg_temp_223.gpkg
# Wrote chunk 224 with 8163 rows to crime_data.gpkg_temp_224.gpkg
# Wrote chunk 225 with 769 rows to crime_data.gpkg_temp_225.gpkg
# Wrote chunk 226 with 8299 rows to crime_data.gpkg_temp_226.gpkg
# Wrote chunk 227 with 4474 rows to crime_data.gpkg_temp_227.gpkg
# Wrote chunk 228 with 10187 rows to crime_data.gpkg_temp_228.gpkg
# Wrote chunk 229 with 13300 rows to crime_data.gpkg_temp_229.gpkg
# Wrote chunk 230 with 7684 rows to crime_data.gpkg_temp_230.gpkg
# Wrote chunk 231 with 6664 rows to crime_data.gpkg_temp_231.gpkg
# Wrote chunk 232 with 5033 rows to crime_data.gpkg_temp_232.gpkg
# Wrote chunk 233 with 13390 rows to crime_data.gpkg_temp_233.gpkg
# Wrote chunk 234 with 5687 rows to crime_data.gpkg_temp_234.gpkg
# Wrote chunk 235 with 30476 rows to crime_data.gpkg_temp_235.gpkg
# Wrote chunk 236 with 5151 rows to crime_data.gpkg_temp_236.gpkg
# Wrote chunk 237 with 19280 rows to crime_data.gpkg_temp_237.gpkg
# Wrote chunk 238 with 10269 rows to crime_data.gpkg_temp_238.gpkg
# Wrote chunk 239 with 9638 rows to crime_data.gpkg_temp_239.gpkg
# Wrote chunk 240 with 14985 rows to crime_data.gpkg_temp_240.gpkg
# Wrote chunk 241 with 18052 rows to crime_data.gpkg_temp_241.gpkg
# Wrote chunk 242 with 8963 rows to crime_data.gpkg_temp_242.gpkg
# Wrote chunk 243 with 6781 rows to crime_data.gpkg_temp_243.gpkg
# Wrote chunk 244 with 13457 rows to crime_data.gpkg_temp_244.gpkg
# Wrote chunk 245 with 112448 rows to crime_data.gpkg_temp_245.gpkg
# Wrote chunk 246 with 8373 rows to crime_data.gpkg_temp_246.gpkg
# Wrote chunk 247 with 5616 rows to crime_data.gpkg_temp_247.gpkg
# Wrote chunk 248 with 6875 rows to crime_data.gpkg_temp_248.gpkg
# Wrote chunk 249 with 8279 rows to crime_data.gpkg_temp_249.gpkg
# Wrote chunk 250 with 14990 rows to crime_data.gpkg_temp_250.gpkg
# Wrote chunk 251 with 11833 rows to crime_data.gpkg_temp_251.gpkg
# Wrote chunk 252 with 11856 rows to crime_data.gpkg_temp_252.gpkg
# Wrote chunk 253 with 17088 rows to crime_data.gpkg_temp_253.gpkg
# Wrote chunk 254 with 7510 rows to crime_data.gpkg_temp_254.gpkg
# Wrote chunk 255 with 7460 rows to crime_data.gpkg_temp_255.gpkg
# Wrote chunk 256 with 10344 rows to crime_data.gpkg_temp_256.gpkg
# Wrote chunk 257 with 16128 rows to crime_data.gpkg_temp_257.gpkg
# Wrote chunk 258 with 18320 rows to crime_data.gpkg_temp_258.gpkg
# Wrote chunk 259 with 4959 rows to crime_data.gpkg_temp_259.gpkg
# Wrote chunk 260 with 11313 rows to crime_data.gpkg_temp_260.gpkg
# Wrote chunk 261 with 30000 rows to crime_data.gpkg_temp_261.gpkg
# Wrote chunk 262 with 26258 rows to crime_data.gpkg_temp_262.gpkg
# Wrote chunk 263 with 5411 rows to crime_data.gpkg_temp_263.gpkg
# Wrote chunk 264 with 16013 rows to crime_data.gpkg_temp_264.gpkg
# Wrote chunk 265 with 6600 rows to crime_data.gpkg_temp_265.gpkg
# Wrote chunk 266 with 1709 rows to crime_data.gpkg_temp_266.gpkg
# Wrote chunk 267 with 7452 rows to crime_data.gpkg_temp_267.gpkg
# Wrote chunk 268 with 8260 rows to crime_data.gpkg_temp_268.gpkg
# Wrote chunk 269 with 792 rows to crime_data.gpkg_temp_269.gpkg
# Wrote chunk 270 with 8208 rows to crime_data.gpkg_temp_270.gpkg
# Wrote chunk 271 with 4554 rows to crime_data.gpkg_temp_271.gpkg
# Wrote chunk 272 with 10444 rows to crime_data.gpkg_temp_272.gpkg
# Wrote chunk 273 with 12823 rows to crime_data.gpkg_temp_273.gpkg
# Wrote chunk 274 with 7455 rows to crime_data.gpkg_temp_274.gpkg
# Wrote chunk 275 with 6777 rows to crime_data.gpkg_temp_275.gpkg
# Wrote chunk 276 with 3959 rows to crime_data.gpkg_temp_276.gpkg
# Wrote chunk 277 with 13647 rows to crime_data.gpkg_temp_277.gpkg
# Wrote chunk 278 with 5386 rows to crime_data.gpkg_temp_278.gpkg
# Wrote chunk 279 with 29774 rows to crime_data.gpkg_temp_279.gpkg
# Wrote chunk 280 with 6810 rows to crime_data.gpkg_temp_280.gpkg
# Wrote chunk 281 with 17399 rows to crime_data.gpkg_temp_281.gpkg
# Wrote chunk 282 with 9681 rows to crime_data.gpkg_temp_282.gpkg
# Wrote chunk 283 with 9430 rows to crime_data.gpkg_temp_283.gpkg
# Wrote chunk 284 with 14232 rows to crime_data.gpkg_temp_284.gpkg
# Wrote chunk 285 with 18568 rows to crime_data.gpkg_temp_285.gpkg
# Wrote chunk 286 with 8712 rows to crime_data.gpkg_temp_286.gpkg
# Wrote chunk 287 with 6459 rows to crime_data.gpkg_temp_287.gpkg
# Wrote chunk 288 with 13068 rows to crime_data.gpkg_temp_288.gpkg
# Wrote chunk 289 with 109074 rows to crime_data.gpkg_temp_289.gpkg
# Wrote chunk 290 with 7892 rows to crime_data.gpkg_temp_290.gpkg
# Wrote chunk 291 with 5528 rows to crime_data.gpkg_temp_291.gpkg
# Wrote chunk 292 with 6777 rows to crime_data.gpkg_temp_292.gpkg
# Wrote chunk 293 with 7879 rows to crime_data.gpkg_temp_293.gpkg
# Wrote chunk 294 with 14422 rows to crime_data.gpkg_temp_294.gpkg
# Wrote chunk 295 with 12278 rows to crime_data.gpkg_temp_295.gpkg
# Wrote chunk 296 with 13409 rows to crime_data.gpkg_temp_296.gpkg
# Wrote chunk 297 with 17102 rows to crime_data.gpkg_temp_297.gpkg
# Wrote chunk 298 with 7477 rows to crime_data.gpkg_temp_298.gpkg
# Wrote chunk 299 with 7309 rows to crime_data.gpkg_temp_299.gpkg
# Wrote chunk 300 with 9870 rows to crime_data.gpkg_temp_300.gpkg
# Wrote chunk 301 with 17378 rows to crime_data.gpkg_temp_301.gpkg
# Wrote chunk 302 with 17704 rows to crime_data.gpkg_temp_302.gpkg
# Wrote chunk 303 with 4818 rows to crime_data.gpkg_temp_303.gpkg
# Wrote chunk 304 with 10849 rows to crime_data.gpkg_temp_304.gpkg
# Wrote chunk 305 with 29037 rows to crime_data.gpkg_temp_305.gpkg
# Wrote chunk 306 with 26581 rows to crime_data.gpkg_temp_306.gpkg
# Wrote chunk 307 with 5247 rows to crime_data.gpkg_temp_307.gpkg
# Wrote chunk 308 with 16987 rows to crime_data.gpkg_temp_308.gpkg
# Wrote chunk 309 with 6694 rows to crime_data.gpkg_temp_309.gpkg
# Wrote chunk 310 with 1712 rows to crime_data.gpkg_temp_310.gpkg
# Wrote chunk 311 with 7941 rows to crime_data.gpkg_temp_311.gpkg
# Wrote chunk 312 with 8894 rows to crime_data.gpkg_temp_312.gpkg
# Wrote chunk 313 with 787 rows to crime_data.gpkg_temp_313.gpkg
# Wrote chunk 314 with 8639 rows to crime_data.gpkg_temp_314.gpkg
# Wrote chunk 315 with 5055 rows to crime_data.gpkg_temp_315.gpkg
# Wrote chunk 316 with 11358 rows to crime_data.gpkg_temp_316.gpkg
# Wrote chunk 317 with 15118 rows to crime_data.gpkg_temp_317.gpkg
# Wrote chunk 318 with 8335 rows to crime_data.gpkg_temp_318.gpkg
# Wrote chunk 319 with 7159 rows to crime_data.gpkg_temp_319.gpkg
# Wrote chunk 320 with 4641 rows to crime_data.gpkg_temp_320.gpkg
# Wrote chunk 321 with 15256 rows to crime_data.gpkg_temp_321.gpkg
# Wrote chunk 322 with 5960 rows to crime_data.gpkg_temp_322.gpkg
# Wrote chunk 323 with 31621 rows to crime_data.gpkg_temp_323.gpkg
# Wrote chunk 324 with 7697 rows to crime_data.gpkg_temp_324.gpkg
# Wrote chunk 325 with 19922 rows to crime_data.gpkg_temp_325.gpkg
# Wrote chunk 326 with 10251 rows to crime_data.gpkg_temp_326.gpkg
# Wrote chunk 327 with 9330 rows to crime_data.gpkg_temp_327.gpkg
# Wrote chunk 328 with 15891 rows to crime_data.gpkg_temp_328.gpkg
# Wrote chunk 329 with 19081 rows to crime_data.gpkg_temp_329.gpkg
# Wrote chunk 330 with 8871 rows to crime_data.gpkg_temp_330.gpkg
# Wrote chunk 331 with 6837 rows to crime_data.gpkg_temp_331.gpkg
# Wrote chunk 332 with 13854 rows to crime_data.gpkg_temp_332.gpkg
# Wrote chunk 333 with 112224 rows to crime_data.gpkg_temp_333.gpkg
# Wrote chunk 334 with 8120 rows to crime_data.gpkg_temp_334.gpkg
# Wrote chunk 335 with 6760 rows to crime_data.gpkg_temp_335.gpkg
# Wrote chunk 336 with 6569 rows to crime_data.gpkg_temp_336.gpkg
# Wrote chunk 337 with 8009 rows to crime_data.gpkg_temp_337.gpkg
# Wrote chunk 338 with 15810 rows to crime_data.gpkg_temp_338.gpkg
# Wrote chunk 339 with 12714 rows to crime_data.gpkg_temp_339.gpkg
# Wrote chunk 340 with 14655 rows to crime_data.gpkg_temp_340.gpkg
# Wrote chunk 341 with 18179 rows to crime_data.gpkg_temp_341.gpkg
# Wrote chunk 342 with 7499 rows to crime_data.gpkg_temp_342.gpkg
# Wrote chunk 343 with 7806 rows to crime_data.gpkg_temp_343.gpkg
# Wrote chunk 344 with 10394 rows to crime_data.gpkg_temp_344.gpkg
# Wrote chunk 345 with 18606 rows to crime_data.gpkg_temp_345.gpkg
# Wrote chunk 346 with 19020 rows to crime_data.gpkg_temp_346.gpkg
# Wrote chunk 347 with 5151 rows to crime_data.gpkg_temp_347.gpkg
# Wrote chunk 348 with 12388 rows to crime_data.gpkg_temp_348.gpkg
# Wrote chunk 349 with 29893 rows to crime_data.gpkg_temp_349.gpkg
# Wrote chunk 350 with 27937 rows to crime_data.gpkg_temp_350.gpkg
# Wrote chunk 351 with 5927 rows to crime_data.gpkg_temp_351.gpkg
# Wrote chunk 352 with 16287 rows to crime_data.gpkg_temp_352.gpkg
# Wrote chunk 353 with 6392 rows to crime_data.gpkg_temp_353.gpkg
# Wrote chunk 354 with 1681 rows to crime_data.gpkg_temp_354.gpkg
# Wrote chunk 355 with 7630 rows to crime_data.gpkg_temp_355.gpkg
# Wrote chunk 356 with 8549 rows to crime_data.gpkg_temp_356.gpkg
# Wrote chunk 357 with 708 rows to crime_data.gpkg_temp_357.gpkg
# Wrote chunk 358 with 8539 rows to crime_data.gpkg_temp_358.gpkg
# Wrote chunk 359 with 4817 rows to crime_data.gpkg_temp_359.gpkg
# Wrote chunk 360 with 10937 rows to crime_data.gpkg_temp_360.gpkg
# Wrote chunk 361 with 14912 rows to crime_data.gpkg_temp_361.gpkg
# Wrote chunk 362 with 7894 rows to crime_data.gpkg_temp_362.gpkg
# Wrote chunk 363 with 6698 rows to crime_data.gpkg_temp_363.gpkg
# Wrote chunk 364 with 4583 rows to crime_data.gpkg_temp_364.gpkg
# Wrote chunk 365 with 15113 rows to crime_data.gpkg_temp_365.gpkg
# Wrote chunk 366 with 5798 rows to crime_data.gpkg_temp_366.gpkg
# Wrote chunk 367 with 30901 rows to crime_data.gpkg_temp_367.gpkg
# Wrote chunk 368 with 7419 rows to crime_data.gpkg_temp_368.gpkg
# Wrote chunk 369 with 19351 rows to crime_data.gpkg_temp_369.gpkg
# Wrote chunk 370 with 9645 rows to crime_data.gpkg_temp_370.gpkg
# Wrote chunk 371 with 9148 rows to crime_data.gpkg_temp_371.gpkg
# Wrote chunk 372 with 15770 rows to crime_data.gpkg_temp_372.gpkg
# Wrote chunk 373 with 19263 rows to crime_data.gpkg_temp_373.gpkg
# Wrote chunk 374 with 8795 rows to crime_data.gpkg_temp_374.gpkg
# Wrote chunk 375 with 6692 rows to crime_data.gpkg_temp_375.gpkg
# Wrote chunk 376 with 14136 rows to crime_data.gpkg_temp_376.gpkg
# Wrote chunk 377 with 108945 rows to crime_data.gpkg_temp_377.gpkg
# Wrote chunk 378 with 7969 rows to crime_data.gpkg_temp_378.gpkg
# Wrote chunk 379 with 6921 rows to crime_data.gpkg_temp_379.gpkg
# Wrote chunk 380 with 5945 rows to crime_data.gpkg_temp_380.gpkg
# Wrote chunk 381 with 8159 rows to crime_data.gpkg_temp_381.gpkg
# Wrote chunk 382 with 14667 rows to crime_data.gpkg_temp_382.gpkg
# Wrote chunk 383 with 12652 rows to crime_data.gpkg_temp_383.gpkg
# Wrote chunk 384 with 14409 rows to crime_data.gpkg_temp_384.gpkg
# Wrote chunk 385 with 17729 rows to crime_data.gpkg_temp_385.gpkg
# Wrote chunk 386 with 7981 rows to crime_data.gpkg_temp_386.gpkg
# Wrote chunk 387 with 7568 rows to crime_data.gpkg_temp_387.gpkg
# Wrote chunk 388 with 9875 rows to crime_data.gpkg_temp_388.gpkg
# Wrote chunk 389 with 18106 rows to crime_data.gpkg_temp_389.gpkg
# Wrote chunk 390 with 17970 rows to crime_data.gpkg_temp_390.gpkg
# Wrote chunk 391 with 4802 rows to crime_data.gpkg_temp_391.gpkg
# Wrote chunk 392 with 12108 rows to crime_data.gpkg_temp_392.gpkg
# Wrote chunk 393 with 28573 rows to crime_data.gpkg_temp_393.gpkg
# Wrote chunk 394 with 27932 rows to crime_data.gpkg_temp_394.gpkg
# Wrote chunk 395 with 5912 rows to crime_data.gpkg_temp_395.gpkg
# Wrote chunk 396 with 15063 rows to crime_data.gpkg_temp_396.gpkg
# Wrote chunk 397 with 5996 rows to crime_data.gpkg_temp_397.gpkg
# Wrote chunk 398 with 4468 rows to crime_data.gpkg_temp_398.gpkg
# Wrote chunk 399 with 6942 rows to crime_data.gpkg_temp_399.gpkg
# Wrote chunk 400 with 8312 rows to crime_data.gpkg_temp_400.gpkg
# Wrote chunk 401 with 722 rows to crime_data.gpkg_temp_401.gpkg
# Wrote chunk 402 with 8165 rows to crime_data.gpkg_temp_402.gpkg
# Wrote chunk 403 with 4326 rows to crime_data.gpkg_temp_403.gpkg
# Wrote chunk 404 with 10040 rows to crime_data.gpkg_temp_404.gpkg
# Wrote chunk 405 with 12753 rows to crime_data.gpkg_temp_405.gpkg
# Wrote chunk 406 with 6691 rows to crime_data.gpkg_temp_406.gpkg
# Wrote chunk 407 with 6280 rows to crime_data.gpkg_temp_407.gpkg
# Wrote chunk 408 with 3655 rows to crime_data.gpkg_temp_408.gpkg
# Wrote chunk 409 with 12990 rows to crime_data.gpkg_temp_409.gpkg
# Wrote chunk 410 with 5196 rows to crime_data.gpkg_temp_410.gpkg
# Wrote chunk 411 with 28342 rows to crime_data.gpkg_temp_411.gpkg
# Wrote chunk 412 with 6210 rows to crime_data.gpkg_temp_412.gpkg
# Wrote chunk 413 with 17486 rows to crime_data.gpkg_temp_413.gpkg
# Wrote chunk 414 with 9189 rows to crime_data.gpkg_temp_414.gpkg
# Wrote chunk 415 with 8458 rows to crime_data.gpkg_temp_415.gpkg
# Wrote chunk 416 with 13690 rows to crime_data.gpkg_temp_416.gpkg
# Wrote chunk 417 with 16250 rows to crime_data.gpkg_temp_417.gpkg
# Wrote chunk 418 with 8439 rows to crime_data.gpkg_temp_418.gpkg
# Wrote chunk 419 with 6308 rows to crime_data.gpkg_temp_419.gpkg
# Wrote chunk 420 with 11627 rows to crime_data.gpkg_temp_420.gpkg
# Wrote chunk 421 with 91264 rows to crime_data.gpkg_temp_421.gpkg
# Wrote chunk 422 with 6801 rows to crime_data.gpkg_temp_422.gpkg
# Wrote chunk 423 with 5877 rows to crime_data.gpkg_temp_423.gpkg
# Wrote chunk 424 with 6486 rows to crime_data.gpkg_temp_424.gpkg
# Wrote chunk 425 with 7183 rows to crime_data.gpkg_temp_425.gpkg
# Wrote chunk 426 with 13752 rows to crime_data.gpkg_temp_426.gpkg
# Wrote chunk 427 with 13694 rows to crime_data.gpkg_temp_427.gpkg
# Wrote chunk 428 with 11369 rows to crime_data.gpkg_temp_428.gpkg
# Wrote chunk 429 with 11875 rows to crime_data.gpkg_temp_429.gpkg
# Wrote chunk 430 with 17607 rows to crime_data.gpkg_temp_430.gpkg
# Wrote chunk 431 with 7664 rows to crime_data.gpkg_temp_431.gpkg
# Wrote chunk 432 with 6855 rows to crime_data.gpkg_temp_432.gpkg
# Wrote chunk 433 with 9372 rows to crime_data.gpkg_temp_433.gpkg
# Wrote chunk 434 with 14335 rows to crime_data.gpkg_temp_434.gpkg
# Wrote chunk 435 with 15845 rows to crime_data.gpkg_temp_435.gpkg
# Wrote chunk 436 with 4625 rows to crime_data.gpkg_temp_436.gpkg
# Wrote chunk 437 with 11105 rows to crime_data.gpkg_temp_437.gpkg
# Wrote chunk 438 with 24013 rows to crime_data.gpkg_temp_438.gpkg
# Wrote chunk 439 with 23216 rows to crime_data.gpkg_temp_439.gpkg
# Wrote chunk 440 with 5525 rows to crime_data.gpkg_temp_440.gpkg
# Wrote chunk 441 with 15740 rows to crime_data.gpkg_temp_441.gpkg
# Wrote chunk 442 with 6382 rows to crime_data.gpkg_temp_442.gpkg
# Wrote chunk 443 with 4752 rows to crime_data.gpkg_temp_443.gpkg
# Wrote chunk 444 with 7362 rows to crime_data.gpkg_temp_444.gpkg
# Wrote chunk 445 with 8908 rows to crime_data.gpkg_temp_445.gpkg
# Wrote chunk 446 with 569 rows to crime_data.gpkg_temp_446.gpkg
# Wrote chunk 447 with 8491 rows to crime_data.gpkg_temp_447.gpkg
# Wrote chunk 448 with 4809 rows to crime_data.gpkg_temp_448.gpkg
# Wrote chunk 449 with 10330 rows to crime_data.gpkg_temp_449.gpkg
# Wrote chunk 450 with 13352 rows to crime_data.gpkg_temp_450.gpkg
# Wrote chunk 451 with 6793 rows to crime_data.gpkg_temp_451.gpkg
# Wrote chunk 452 with 6659 rows to crime_data.gpkg_temp_452.gpkg
# Wrote chunk 453 with 3813 rows to crime_data.gpkg_temp_453.gpkg
# Wrote chunk 454 with 13926 rows to crime_data.gpkg_temp_454.gpkg
# Wrote chunk 455 with 5560 rows to crime_data.gpkg_temp_455.gpkg
# Wrote chunk 456 with 29963 rows to crime_data.gpkg_temp_456.gpkg
# Wrote chunk 457 with 6178 rows to crime_data.gpkg_temp_457.gpkg
# Wrote chunk 458 with 18287 rows to crime_data.gpkg_temp_458.gpkg
# Wrote chunk 459 with 9638 rows to crime_data.gpkg_temp_459.gpkg
# Wrote chunk 460 with 8014 rows to crime_data.gpkg_temp_460.gpkg
# Wrote chunk 461 with 14277 rows to crime_data.gpkg_temp_461.gpkg
# Wrote chunk 462 with 16979 rows to crime_data.gpkg_temp_462.gpkg
# Wrote chunk 463 with 8843 rows to crime_data.gpkg_temp_463.gpkg
# Wrote chunk 464 with 6354 rows to crime_data.gpkg_temp_464.gpkg
# Wrote chunk 465 with 14057 rows to crime_data.gpkg_temp_465.gpkg
# Wrote chunk 466 with 101354 rows to crime_data.gpkg_temp_466.gpkg
# Wrote chunk 467 with 6579 rows to crime_data.gpkg_temp_467.gpkg
# Wrote chunk 468 with 6309 rows to crime_data.gpkg_temp_468.gpkg
# Wrote chunk 469 with 6940 rows to crime_data.gpkg_temp_469.gpkg
# Wrote chunk 470 with 7407 rows to crime_data.gpkg_temp_470.gpkg
# Wrote chunk 471 with 14645 rows to crime_data.gpkg_temp_471.gpkg
# Wrote chunk 472 with 15151 rows to crime_data.gpkg_temp_472.gpkg
# Wrote chunk 473 with 11915 rows to crime_data.gpkg_temp_473.gpkg
# Wrote chunk 474 with 13171 rows to crime_data.gpkg_temp_474.gpkg
# Wrote chunk 475 with 18733 rows to crime_data.gpkg_temp_475.gpkg
# Wrote chunk 476 with 8161 rows to crime_data.gpkg_temp_476.gpkg
# Wrote chunk 477 with 6505 rows to crime_data.gpkg_temp_477.gpkg
# Wrote chunk 478 with 10174 rows to crime_data.gpkg_temp_478.gpkg
# Wrote chunk 479 with 14867 rows to crime_data.gpkg_temp_479.gpkg
# Wrote chunk 480 with 16900 rows to crime_data.gpkg_temp_480.gpkg
# Wrote chunk 481 with 4681 rows to crime_data.gpkg_temp_481.gpkg
# Wrote chunk 482 with 11599 rows to crime_data.gpkg_temp_482.gpkg
# Wrote chunk 483 with 24289 rows to crime_data.gpkg_temp_483.gpkg
# Wrote chunk 484 with 23590 rows to crime_data.gpkg_temp_484.gpkg
# Wrote chunk 485 with 5510 rows to crime_data.gpkg_temp_485.gpkg
# Wrote chunk 486 with 15630 rows to crime_data.gpkg_temp_486.gpkg
# Wrote chunk 487 with 5809 rows to crime_data.gpkg_temp_487.gpkg
# Wrote chunk 488 with 4585 rows to crime_data.gpkg_temp_488.gpkg
# Wrote chunk 489 with 6525 rows to crime_data.gpkg_temp_489.gpkg
# Wrote chunk 490 with 8454 rows to crime_data.gpkg_temp_490.gpkg
# Wrote chunk 491 with 668 rows to crime_data.gpkg_temp_491.gpkg
# Wrote chunk 492 with 7444 rows to crime_data.gpkg_temp_492.gpkg
# Wrote chunk 493 with 4271 rows to crime_data.gpkg_temp_493.gpkg
# Wrote chunk 494 with 9184 rows to crime_data.gpkg_temp_494.gpkg
# Wrote chunk 495 with 12175 rows to crime_data.gpkg_temp_495.gpkg
# Wrote chunk 496 with 6708 rows to crime_data.gpkg_temp_496.gpkg
# Wrote chunk 497 with 6124 rows to crime_data.gpkg_temp_497.gpkg
# Wrote chunk 498 with 3271 rows to crime_data.gpkg_temp_498.gpkg
# Wrote chunk 499 with 12522 rows to crime_data.gpkg_temp_499.gpkg
# Wrote chunk 500 with 5060 rows to crime_data.gpkg_temp_500.gpkg
# Wrote chunk 501 with 27781 rows to crime_data.gpkg_temp_501.gpkg
# Wrote chunk 502 with 5477 rows to crime_data.gpkg_temp_502.gpkg
# Wrote chunk 503 with 16261 rows to crime_data.gpkg_temp_503.gpkg
# Wrote chunk 504 with 8791 rows to crime_data.gpkg_temp_504.gpkg
# Wrote chunk 505 with 7594 rows to crime_data.gpkg_temp_505.gpkg
# Wrote chunk 506 with 12458 rows to crime_data.gpkg_temp_506.gpkg
# Wrote chunk 507 with 14870 rows to crime_data.gpkg_temp_507.gpkg
# Wrote chunk 508 with 7607 rows to crime_data.gpkg_temp_508.gpkg
# Wrote chunk 509 with 6164 rows to crime_data.gpkg_temp_509.gpkg
# Wrote chunk 510 with 12336 rows to crime_data.gpkg_temp_510.gpkg
# Wrote chunk 511 with 95642 rows to crime_data.gpkg_temp_511.gpkg
# Wrote chunk 512 with 5743 rows to crime_data.gpkg_temp_512.gpkg
# Wrote chunk 513 with 5921 rows to crime_data.gpkg_temp_513.gpkg
# Wrote chunk 514 with 6188 rows to crime_data.gpkg_temp_514.gpkg
# Wrote chunk 515 with 6574 rows to crime_data.gpkg_temp_515.gpkg
# Wrote chunk 516 with 13510 rows to crime_data.gpkg_temp_516.gpkg
# Wrote chunk 517 with 14094 rows to crime_data.gpkg_temp_517.gpkg
# Wrote chunk 518 with 10265 rows to crime_data.gpkg_temp_518.gpkg
# Wrote chunk 519 with 11864 rows to crime_data.gpkg_temp_519.gpkg
# Wrote chunk 520 with 17150 rows to crime_data.gpkg_temp_520.gpkg
# Wrote chunk 521 with 7538 rows to crime_data.gpkg_temp_521.gpkg
# Wrote chunk 522 with 6024 rows to crime_data.gpkg_temp_522.gpkg
# Wrote chunk 523 with 8951 rows to crime_data.gpkg_temp_523.gpkg
# Wrote chunk 524 with 13366 rows to crime_data.gpkg_temp_524.gpkg
# Wrote chunk 525 with 15107 rows to crime_data.gpkg_temp_525.gpkg
# Wrote chunk 526 with 4346 rows to crime_data.gpkg_temp_526.gpkg
# Wrote chunk 527 with 9890 rows to crime_data.gpkg_temp_527.gpkg
# Wrote chunk 528 with 22605 rows to crime_data.gpkg_temp_528.gpkg
# Wrote chunk 529 with 22641 rows to crime_data.gpkg_temp_529.gpkg
# Wrote chunk 530 with 5283 rows to crime_data.gpkg_temp_530.gpkg
# Wrote chunk 531 with 13252 rows to crime_data.gpkg_temp_531.gpkg
# Wrote chunk 532 with 5297 rows to crime_data.gpkg_temp_532.gpkg
# Wrote chunk 533 with 4059 rows to crime_data.gpkg_temp_533.gpkg
# Wrote chunk 534 with 6182 rows to crime_data.gpkg_temp_534.gpkg
# Wrote chunk 535 with 7529 rows to crime_data.gpkg_temp_535.gpkg
# Wrote chunk 536 with 557 rows to crime_data.gpkg_temp_536.gpkg
# Wrote chunk 537 with 6719 rows to crime_data.gpkg_temp_537.gpkg
# Wrote chunk 538 with 3753 rows to crime_data.gpkg_temp_538.gpkg
# Wrote chunk 539 with 8301 rows to crime_data.gpkg_temp_539.gpkg
# Wrote chunk 540 with 11281 rows to crime_data.gpkg_temp_540.gpkg
# Wrote chunk 541 with 6016 rows to crime_data.gpkg_temp_541.gpkg
# Wrote chunk 542 with 5299 rows to crime_data.gpkg_temp_542.gpkg
# Wrote chunk 543 with 3170 rows to crime_data.gpkg_temp_543.gpkg
# Wrote chunk 544 with 12488 rows to crime_data.gpkg_temp_544.gpkg
# Wrote chunk 545 with 4482 rows to crime_data.gpkg_temp_545.gpkg
# Wrote chunk 546 with 23911 rows to crime_data.gpkg_temp_546.gpkg
# Wrote chunk 547 with 4603 rows to crime_data.gpkg_temp_547.gpkg
# Wrote chunk 548 with 14564 rows to crime_data.gpkg_temp_548.gpkg
# Wrote chunk 549 with 8033 rows to crime_data.gpkg_temp_549.gpkg
# Wrote chunk 550 with 6623 rows to crime_data.gpkg_temp_550.gpkg
# Wrote chunk 551 with 12255 rows to crime_data.gpkg_temp_551.gpkg
# Wrote chunk 552 with 13301 rows to crime_data.gpkg_temp_552.gpkg
# Wrote chunk 553 with 6739 rows to crime_data.gpkg_temp_553.gpkg
# Wrote chunk 554 with 5383 rows to crime_data.gpkg_temp_554.gpkg
# Wrote chunk 555 with 11156 rows to crime_data.gpkg_temp_555.gpkg
# Wrote chunk 556 with 87057 rows to crime_data.gpkg_temp_556.gpkg
# Wrote chunk 557 with 5060 rows to crime_data.gpkg_temp_557.gpkg
# Wrote chunk 558 with 5289 rows to crime_data.gpkg_temp_558.gpkg
# Wrote chunk 559 with 6011 rows to crime_data.gpkg_temp_559.gpkg
# Wrote chunk 560 with 6071 rows to crime_data.gpkg_temp_560.gpkg
# Wrote chunk 561 with 12324 rows to crime_data.gpkg_temp_561.gpkg
# Wrote chunk 562 with 11497 rows to crime_data.gpkg_temp_562.gpkg
# Wrote chunk 563 with 8809 rows to crime_data.gpkg_temp_563.gpkg
# Wrote chunk 564 with 11644 rows to crime_data.gpkg_temp_564.gpkg
# Wrote chunk 565 with 15163 rows to crime_data.gpkg_temp_565.gpkg
# Wrote chunk 566 with 6550 rows to crime_data.gpkg_temp_566.gpkg
# Wrote chunk 567 with 5812 rows to crime_data.gpkg_temp_567.gpkg
# Wrote chunk 568 with 8148 rows to crime_data.gpkg_temp_568.gpkg
# Wrote chunk 569 with 12490 rows to crime_data.gpkg_temp_569.gpkg
# Wrote chunk 570 with 14037 rows to crime_data.gpkg_temp_570.gpkg
# Wrote chunk 571 with 3918 rows to crime_data.gpkg_temp_571.gpkg
# Wrote chunk 572 with 9335 rows to crime_data.gpkg_temp_572.gpkg
# Wrote chunk 573 with 20732 rows to crime_data.gpkg_temp_573.gpkg
# Wrote chunk 574 with 19953 rows to crime_data.gpkg_temp_574.gpkg
# Wrote chunk 575 with 4912 rows to crime_data.gpkg_temp_575.gpkg
# Wrote chunk 576 with 13857 rows to crime_data.gpkg_temp_576.gpkg
# Wrote chunk 577 with 5318 rows to crime_data.gpkg_temp_577.gpkg
# Wrote chunk 578 with 3999 rows to crime_data.gpkg_temp_578.gpkg
# Wrote chunk 579 with 6204 rows to crime_data.gpkg_temp_579.gpkg
# Wrote chunk 580 with 7510 rows to crime_data.gpkg_temp_580.gpkg
# Wrote chunk 581 with 625 rows to crime_data.gpkg_temp_581.gpkg
# Wrote chunk 582 with 6557 rows to crime_data.gpkg_temp_582.gpkg
# Wrote chunk 583 with 3736 rows to crime_data.gpkg_temp_583.gpkg
# Wrote chunk 584 with 8635 rows to crime_data.gpkg_temp_584.gpkg
# Wrote chunk 585 with 11309 rows to crime_data.gpkg_temp_585.gpkg
# Wrote chunk 586 with 5770 rows to crime_data.gpkg_temp_586.gpkg
# Wrote chunk 587 with 5306 rows to crime_data.gpkg_temp_587.gpkg
# Wrote chunk 588 with 3113 rows to crime_data.gpkg_temp_588.gpkg
# Wrote chunk 589 with 12768 rows to crime_data.gpkg_temp_589.gpkg
# Wrote chunk 590 with 4437 rows to crime_data.gpkg_temp_590.gpkg
# Wrote chunk 591 with 24548 rows to crime_data.gpkg_temp_591.gpkg
# Wrote chunk 592 with 4859 rows to crime_data.gpkg_temp_592.gpkg
# Wrote chunk 593 with 14968 rows to crime_data.gpkg_temp_593.gpkg
# Wrote chunk 594 with 8043 rows to crime_data.gpkg_temp_594.gpkg
# Wrote chunk 595 with 6762 rows to crime_data.gpkg_temp_595.gpkg
# Wrote chunk 596 with 12486 rows to crime_data.gpkg_temp_596.gpkg
# Wrote chunk 597 with 13294 rows to crime_data.gpkg_temp_597.gpkg
# Wrote chunk 598 with 7171 rows to crime_data.gpkg_temp_598.gpkg
# Wrote chunk 599 with 5437 rows to crime_data.gpkg_temp_599.gpkg
# Wrote chunk 600 with 11901 rows to crime_data.gpkg_temp_600.gpkg
# Wrote chunk 601 with 91032 rows to crime_data.gpkg_temp_601.gpkg
# Wrote chunk 602 with 5296 rows to crime_data.gpkg_temp_602.gpkg
# Wrote chunk 603 with 5207 rows to crime_data.gpkg_temp_603.gpkg
# Wrote chunk 604 with 5643 rows to crime_data.gpkg_temp_604.gpkg
# Wrote chunk 605 with 6425 rows to crime_data.gpkg_temp_605.gpkg
# Wrote chunk 606 with 12265 rows to crime_data.gpkg_temp_606.gpkg
# Wrote chunk 607 with 11911 rows to crime_data.gpkg_temp_607.gpkg
# Wrote chunk 608 with 9419 rows to crime_data.gpkg_temp_608.gpkg
# Wrote chunk 609 with 11239 rows to crime_data.gpkg_temp_609.gpkg
# Wrote chunk 610 with 15886 rows to crime_data.gpkg_temp_610.gpkg
# Wrote chunk 611 with 7780 rows to crime_data.gpkg_temp_611.gpkg
# Wrote chunk 612 with 5704 rows to crime_data.gpkg_temp_612.gpkg
# Wrote chunk 613 with 8385 rows to crime_data.gpkg_temp_613.gpkg
# Wrote chunk 614 with 13245 rows to crime_data.gpkg_temp_614.gpkg
# Wrote chunk 615 with 15355 rows to crime_data.gpkg_temp_615.gpkg
# Wrote chunk 616 with 3977 rows to crime_data.gpkg_temp_616.gpkg
# Wrote chunk 617 with 9453 rows to crime_data.gpkg_temp_617.gpkg
# Wrote chunk 618 with 20904 rows to crime_data.gpkg_temp_618.gpkg
# Wrote chunk 619 with 21321 rows to crime_data.gpkg_temp_619.gpkg
# Wrote chunk 620 with 3428 rows to crime_data.gpkg_temp_620.gpkg
# Wrote chunk 621 with 13454 rows to crime_data.gpkg_temp_621.gpkg
# Wrote chunk 622 with 5136 rows to crime_data.gpkg_temp_622.gpkg
# Wrote chunk 623 with 4071 rows to crime_data.gpkg_temp_623.gpkg
# Wrote chunk 624 with 5918 rows to crime_data.gpkg_temp_624.gpkg
# Wrote chunk 625 with 7251 rows to crime_data.gpkg_temp_625.gpkg
# Wrote chunk 626 with 671 rows to crime_data.gpkg_temp_626.gpkg
# Wrote chunk 627 with 6551 rows to crime_data.gpkg_temp_627.gpkg
# Wrote chunk 628 with 3763 rows to crime_data.gpkg_temp_628.gpkg
# Wrote chunk 629 with 8684 rows to crime_data.gpkg_temp_629.gpkg
# Wrote chunk 630 with 10746 rows to crime_data.gpkg_temp_630.gpkg
# Wrote chunk 631 with 5504 rows to crime_data.gpkg_temp_631.gpkg
# Wrote chunk 632 with 5230 rows to crime_data.gpkg_temp_632.gpkg
# Wrote chunk 633 with 3062 rows to crime_data.gpkg_temp_633.gpkg
# Wrote chunk 634 with 12256 rows to crime_data.gpkg_temp_634.gpkg
# Wrote chunk 635 with 4240 rows to crime_data.gpkg_temp_635.gpkg
# Wrote chunk 636 with 24223 rows to crime_data.gpkg_temp_636.gpkg
# Wrote chunk 637 with 4762 rows to crime_data.gpkg_temp_637.gpkg
# Wrote chunk 638 with 14540 rows to crime_data.gpkg_temp_638.gpkg
# Wrote chunk 639 with 8092 rows to crime_data.gpkg_temp_639.gpkg
# Wrote chunk 640 with 7106 rows to crime_data.gpkg_temp_640.gpkg
# Wrote chunk 641 with 12294 rows to crime_data.gpkg_temp_641.gpkg
# Wrote chunk 642 with 12696 rows to crime_data.gpkg_temp_642.gpkg
# Wrote chunk 643 with 7325 rows to crime_data.gpkg_temp_643.gpkg
# Wrote chunk 644 with 5341 rows to crime_data.gpkg_temp_644.gpkg
# Wrote chunk 645 with 11426 rows to crime_data.gpkg_temp_645.gpkg
# Wrote chunk 646 with 85064 rows to crime_data.gpkg_temp_646.gpkg
# Wrote chunk 647 with 5263 rows to crime_data.gpkg_temp_647.gpkg
# Wrote chunk 648 with 5285 rows to crime_data.gpkg_temp_648.gpkg
# Wrote chunk 649 with 5473 rows to crime_data.gpkg_temp_649.gpkg
# Wrote chunk 650 with 6191 rows to crime_data.gpkg_temp_650.gpkg
# Wrote chunk 651 with 12320 rows to crime_data.gpkg_temp_651.gpkg
# Wrote chunk 652 with 12379 rows to crime_data.gpkg_temp_652.gpkg
# Wrote chunk 653 with 9488 rows to crime_data.gpkg_temp_653.gpkg
# Wrote chunk 654 with 11008 rows to crime_data.gpkg_temp_654.gpkg
# Wrote chunk 655 with 16084 rows to crime_data.gpkg_temp_655.gpkg
# Wrote chunk 656 with 7154 rows to crime_data.gpkg_temp_656.gpkg
# Wrote chunk 657 with 5715 rows to crime_data.gpkg_temp_657.gpkg
# Wrote chunk 658 with 8205 rows to crime_data.gpkg_temp_658.gpkg
# Wrote chunk 659 with 11739 rows to crime_data.gpkg_temp_659.gpkg
# Wrote chunk 660 with 13986 rows to crime_data.gpkg_temp_660.gpkg
# Wrote chunk 661 with 4092 rows to crime_data.gpkg_temp_661.gpkg
# Wrote chunk 662 with 9195 rows to crime_data.gpkg_temp_662.gpkg
# Wrote chunk 663 with 20824 rows to crime_data.gpkg_temp_663.gpkg
# Wrote chunk 664 with 20596 rows to crime_data.gpkg_temp_664.gpkg
# Wrote chunk 665 with 4713 rows to crime_data.gpkg_temp_665.gpkg
# Wrote chunk 666 with 15289 rows to crime_data.gpkg_temp_666.gpkg
# Wrote chunk 667 with 5916 rows to crime_data.gpkg_temp_667.gpkg
# Wrote chunk 668 with 4513 rows to crime_data.gpkg_temp_668.gpkg
# Wrote chunk 669 with 6896 rows to crime_data.gpkg_temp_669.gpkg
# Wrote chunk 670 with 8719 rows to crime_data.gpkg_temp_670.gpkg
# Wrote chunk 671 with 735 rows to crime_data.gpkg_temp_671.gpkg
# Wrote chunk 672 with 7548 rows to crime_data.gpkg_temp_672.gpkg
# Wrote chunk 673 with 4350 rows to crime_data.gpkg_temp_673.gpkg
# Wrote chunk 674 with 10280 rows to crime_data.gpkg_temp_674.gpkg
# Wrote chunk 675 with 12634 rows to crime_data.gpkg_temp_675.gpkg
# Wrote chunk 676 with 6362 rows to crime_data.gpkg_temp_676.gpkg
# Wrote chunk 677 with 5749 rows to crime_data.gpkg_temp_677.gpkg
# Wrote chunk 678 with 3842 rows to crime_data.gpkg_temp_678.gpkg
# Wrote chunk 679 with 14083 rows to crime_data.gpkg_temp_679.gpkg
# Wrote chunk 680 with 5013 rows to crime_data.gpkg_temp_680.gpkg
# Wrote chunk 681 with 28091 rows to crime_data.gpkg_temp_681.gpkg
# Wrote chunk 682 with 5354 rows to crime_data.gpkg_temp_682.gpkg
# Wrote chunk 683 with 16387 rows to crime_data.gpkg_temp_683.gpkg
# Wrote chunk 684 with 8562 rows to crime_data.gpkg_temp_684.gpkg
# Wrote chunk 685 with 7513 rows to crime_data.gpkg_temp_685.gpkg
# Wrote chunk 686 with 13996 rows to crime_data.gpkg_temp_686.gpkg
# Wrote chunk 687 with 16689 rows to crime_data.gpkg_temp_687.gpkg
# Wrote chunk 688 with 8253 rows to crime_data.gpkg_temp_688.gpkg
# Wrote chunk 689 with 6370 rows to crime_data.gpkg_temp_689.gpkg
# Wrote chunk 690 with 13858 rows to crime_data.gpkg_temp_690.gpkg
# Wrote chunk 691 with 101527 rows to crime_data.gpkg_temp_691.gpkg
# Wrote chunk 692 with 5954 rows to crime_data.gpkg_temp_692.gpkg
# Wrote chunk 693 with 6326 rows to crime_data.gpkg_temp_693.gpkg
# Wrote chunk 694 with 6388 rows to crime_data.gpkg_temp_694.gpkg
# Wrote chunk 695 with 6953 rows to crime_data.gpkg_temp_695.gpkg
# Wrote chunk 696 with 14386 rows to crime_data.gpkg_temp_696.gpkg
# Wrote chunk 697 with 15070 rows to crime_data.gpkg_temp_697.gpkg
# Wrote chunk 698 with 10844 rows to crime_data.gpkg_temp_698.gpkg
# Wrote chunk 699 with 12511 rows to crime_data.gpkg_temp_699.gpkg
# Wrote chunk 700 with 18035 rows to crime_data.gpkg_temp_700.gpkg
# Wrote chunk 701 with 9282 rows to crime_data.gpkg_temp_701.gpkg
# Wrote chunk 702 with 5994 rows to crime_data.gpkg_temp_702.gpkg
# Wrote chunk 703 with 8794 rows to crime_data.gpkg_temp_703.gpkg
# Wrote chunk 704 with 14194 rows to crime_data.gpkg_temp_704.gpkg
# Wrote chunk 705 with 16094 rows to crime_data.gpkg_temp_705.gpkg
# Wrote chunk 706 with 4661 rows to crime_data.gpkg_temp_706.gpkg
# Wrote chunk 707 with 10767 rows to crime_data.gpkg_temp_707.gpkg
# Wrote chunk 708 with 22930 rows to crime_data.gpkg_temp_708.gpkg
# Wrote chunk 709 with 23542 rows to crime_data.gpkg_temp_709.gpkg
# Wrote chunk 710 with 5526 rows to crime_data.gpkg_temp_710.gpkg
# Wrote chunk 711 with 13874 rows to crime_data.gpkg_temp_711.gpkg
# Wrote chunk 712 with 5231 rows to crime_data.gpkg_temp_712.gpkg
# Wrote chunk 713 with 3850 rows to crime_data.gpkg_temp_713.gpkg
# Wrote chunk 714 with 6080 rows to crime_data.gpkg_temp_714.gpkg
# Wrote chunk 715 with 7597 rows to crime_data.gpkg_temp_715.gpkg
# Wrote chunk 716 with 572 rows to crime_data.gpkg_temp_716.gpkg
# Wrote chunk 717 with 6579 rows to crime_data.gpkg_temp_717.gpkg
# Wrote chunk 718 with 4207 rows to crime_data.gpkg_temp_718.gpkg
# Wrote chunk 719 with 8465 rows to crime_data.gpkg_temp_719.gpkg
# Wrote chunk 720 with 11242 rows to crime_data.gpkg_temp_720.gpkg
# Wrote chunk 721 with 5880 rows to crime_data.gpkg_temp_721.gpkg
# Wrote chunk 722 with 4797 rows to crime_data.gpkg_temp_722.gpkg
# Wrote chunk 723 with 3435 rows to crime_data.gpkg_temp_723.gpkg
# Wrote chunk 724 with 12142 rows to crime_data.gpkg_temp_724.gpkg
# Wrote chunk 725 with 4407 rows to crime_data.gpkg_temp_725.gpkg
# Wrote chunk 726 with 24920 rows to crime_data.gpkg_temp_726.gpkg
# Wrote chunk 727 with 4373 rows to crime_data.gpkg_temp_727.gpkg
# Wrote chunk 728 with 14986 rows to crime_data.gpkg_temp_728.gpkg
# Wrote chunk 729 with 7835 rows to crime_data.gpkg_temp_729.gpkg
# Wrote chunk 730 with 6911 rows to crime_data.gpkg_temp_730.gpkg
# Wrote chunk 731 with 12160 rows to crime_data.gpkg_temp_731.gpkg
# Wrote chunk 732 with 15258 rows to crime_data.gpkg_temp_732.gpkg
# Wrote chunk 733 with 7097 rows to crime_data.gpkg_temp_733.gpkg
# Wrote chunk 734 with 5512 rows to crime_data.gpkg_temp_734.gpkg
# Wrote chunk 735 with 12114 rows to crime_data.gpkg_temp_735.gpkg
# Wrote chunk 736 with 90378 rows to crime_data.gpkg_temp_736.gpkg
# Wrote chunk 737 with 5492 rows to crime_data.gpkg_temp_737.gpkg
# Wrote chunk 738 with 5422 rows to crime_data.gpkg_temp_738.gpkg
# Wrote chunk 739 with 5742 rows to crime_data.gpkg_temp_739.gpkg
# Wrote chunk 740 with 6264 rows to crime_data.gpkg_temp_740.gpkg
# Wrote chunk 741 with 12888 rows to crime_data.gpkg_temp_741.gpkg
# Wrote chunk 742 with 12414 rows to crime_data.gpkg_temp_742.gpkg
# Wrote chunk 743 with 9256 rows to crime_data.gpkg_temp_743.gpkg
# Wrote chunk 744 with 11377 rows to crime_data.gpkg_temp_744.gpkg
# Wrote chunk 745 with 13788 rows to crime_data.gpkg_temp_745.gpkg
# Wrote chunk 746 with 7572 rows to crime_data.gpkg_temp_746.gpkg
# Wrote chunk 747 with 5503 rows to crime_data.gpkg_temp_747.gpkg
# ...
# Wrote chunk 7307 with 15265 rows to crime_data.gpkg_temp_7307.gpkg
# Wrote chunk 7308 with 8612 rows to crime_data.gpkg_temp_7308.gpkg
# Wrote chunk 7309 with 4179 rows to crime_data.gpkg_temp_7309.gpkg
# Wrote chunk 7310 with 7334 rows to crime_data.gpkg_temp_7310.gpkg
# Wrote chunk 7311 with 14404 rows to crime_data.gpkg_temp_7311.gpkg
# Wrote chunk 7312 with 17246 rows to crime_data.gpkg_temp_7312.gpkg
# Wrote chunk 7313 with 4217 rows to crime_data.gpkg_temp_7313.gpkg
# Wrote chunk 7314 with 9063 rows to crime_data.gpkg_temp_7314.gpkg
# Wrote chunk 7315 with 29180 rows to crime_data.gpkg_temp_7315.gpkg
# Wrote chunk 7316 with 27714 rows to crime_data.gpkg_temp_7316.gpkg
# Wrote chunk 7317 with 4491 rows to crime_data.gpkg_temp_7317.gpkg
# Wrote chunk 7318 with 16129 rows to crime_data.gpkg_temp_7318.gpkg
# Wrote chunk 7319 with 5223 rows to crime_data.gpkg_temp_7319.gpkg
# Wrote chunk 7320 with 3311 rows to crime_data.gpkg_temp_7320.gpkg
# Wrote chunk 7321 with 6740 rows to crime_data.gpkg_temp_7321.gpkg
# Wrote chunk 7322 with 6403 rows to crime_data.gpkg_temp_7322.gpkg
# Wrote chunk 7323 with 747 rows to crime_data.gpkg_temp_7323.gpkg
# Wrote chunk 7324 with 7523 rows to crime_data.gpkg_temp_7324.gpkg
# Wrote chunk 7325 with 3335 rows to crime_data.gpkg_temp_7325.gpkg
# Wrote chunk 7326 with 8724 rows to crime_data.gpkg_temp_7326.gpkg
# Wrote chunk 7327 with 12179 rows to crime_data.gpkg_temp_7327.gpkg
# Wrote chunk 7328 with 4945 rows to crime_data.gpkg_temp_7328.gpkg
# Wrote chunk 7329 with 6086 rows to crime_data.gpkg_temp_7329.gpkg
# Wrote chunk 7330 with 3521 rows to crime_data.gpkg_temp_7330.gpkg
# Wrote chunk 7331 with 12226 rows to crime_data.gpkg_temp_7331.gpkg
# Wrote chunk 7332 with 4642 rows to crime_data.gpkg_temp_7332.gpkg
# Wrote chunk 7333 with 5923 rows to crime_data.gpkg_temp_7333.gpkg
# Wrote chunk 7334 with 14222 rows to crime_data.gpkg_temp_7334.gpkg
# Wrote chunk 7335 with 8569 rows to crime_data.gpkg_temp_7335.gpkg
# Wrote chunk 7336 with 7886 rows to crime_data.gpkg_temp_7336.gpkg
# Wrote chunk 7337 with 14255 rows to crime_data.gpkg_temp_7337.gpkg
# Wrote chunk 7338 with 15478 rows to crime_data.gpkg_temp_7338.gpkg
# Wrote chunk 7339 with 9155 rows to crime_data.gpkg_temp_7339.gpkg
# Wrote chunk 7340 with 6498 rows to crime_data.gpkg_temp_7340.gpkg
# Wrote chunk 7341 with 12415 rows to crime_data.gpkg_temp_7341.gpkg
# Wrote chunk 7342 with 93981 rows to crime_data.gpkg_temp_7342.gpkg
# Wrote chunk 7343 with 5829 rows to crime_data.gpkg_temp_7343.gpkg
# Wrote chunk 7344 with 5447 rows to crime_data.gpkg_temp_7344.gpkg
# Wrote chunk 7345 with 5114 rows to crime_data.gpkg_temp_7345.gpkg
# Wrote chunk 7346 with 6212 rows to crime_data.gpkg_temp_7346.gpkg
# Wrote chunk 7347 with 14599 rows to crime_data.gpkg_temp_7347.gpkg
# Wrote chunk 7348 with 8944 rows to crime_data.gpkg_temp_7348.gpkg
# Wrote chunk 7349 with 10300 rows to crime_data.gpkg_temp_7349.gpkg
# Wrote chunk 7350 with 14459 rows to crime_data.gpkg_temp_7350.gpkg
# Wrote chunk 7351 with 8526 rows to crime_data.gpkg_temp_7351.gpkg
# Wrote chunk 7352 with 4134 rows to crime_data.gpkg_temp_7352.gpkg
# Wrote chunk 7353 with 6704 rows to crime_data.gpkg_temp_7353.gpkg
# Wrote chunk 7354 with 12947 rows to crime_data.gpkg_temp_7354.gpkg
# Wrote chunk 7355 with 15914 rows to crime_data.gpkg_temp_7355.gpkg
# Wrote chunk 7356 with 4092 rows to crime_data.gpkg_temp_7356.gpkg
# Wrote chunk 7357 with 8207 rows to crime_data.gpkg_temp_7357.gpkg
# Wrote chunk 7358 with 28635 rows to crime_data.gpkg_temp_7358.gpkg
# Wrote chunk 7359 with 25423 rows to crime_data.gpkg_temp_7359.gpkg
# Wrote chunk 7360 with 4088 rows to crime_data.gpkg_temp_7360.gpkg
# Wrote chunk 7361 with 16960 rows to crime_data.gpkg_temp_7361.gpkg
# Wrote chunk 7362 with 5230 rows to crime_data.gpkg_temp_7362.gpkg
# Wrote chunk 7363 with 3629 rows to crime_data.gpkg_temp_7363.gpkg
# Wrote chunk 7364 with 6970 rows to crime_data.gpkg_temp_7364.gpkg
# Wrote chunk 7365 with 7146 rows to crime_data.gpkg_temp_7365.gpkg
# Wrote chunk 7366 with 901 rows to crime_data.gpkg_temp_7366.gpkg
# Wrote chunk 7367 with 7693 rows to crime_data.gpkg_temp_7367.gpkg
# Wrote chunk 7368 with 3470 rows to crime_data.gpkg_temp_7368.gpkg
# Wrote chunk 7369 with 9066 rows to crime_data.gpkg_temp_7369.gpkg
# Wrote chunk 7370 with 12866 rows to crime_data.gpkg_temp_7370.gpkg
# Wrote chunk 7371 with 5222 rows to crime_data.gpkg_temp_7371.gpkg
# Wrote chunk 7372 with 6477 rows to crime_data.gpkg_temp_7372.gpkg
# Wrote chunk 7373 with 3933 rows to crime_data.gpkg_temp_7373.gpkg
# Wrote chunk 7374 with 13646 rows to crime_data.gpkg_temp_7374.gpkg
# Wrote chunk 7375 with 4973 rows to crime_data.gpkg_temp_7375.gpkg
# Wrote chunk 7376 with 6093 rows to crime_data.gpkg_temp_7376.gpkg
# Wrote chunk 7377 with 14645 rows to crime_data.gpkg_temp_7377.gpkg
# Wrote chunk 7378 with 9354 rows to crime_data.gpkg_temp_7378.gpkg
# Wrote chunk 7379 with 8123 rows to crime_data.gpkg_temp_7379.gpkg
# Wrote chunk 7380 with 15177 rows to crime_data.gpkg_temp_7380.gpkg
# Wrote chunk 7381 with 16076 rows to crime_data.gpkg_temp_7381.gpkg
# Wrote chunk 7382 with 9172 rows to crime_data.gpkg_temp_7382.gpkg
# Wrote chunk 7383 with 5782 rows to crime_data.gpkg_temp_7383.gpkg
# Wrote chunk 7384 with 13459 rows to crime_data.gpkg_temp_7384.gpkg
# Wrote chunk 7385 with 100785 rows to crime_data.gpkg_temp_7385.gpkg
# Wrote chunk 7386 with 6082 rows to crime_data.gpkg_temp_7386.gpkg
# Wrote chunk 7387 with 5934 rows to crime_data.gpkg_temp_7387.gpkg
# Wrote chunk 7388 with 5393 rows to crime_data.gpkg_temp_7388.gpkg
# Wrote chunk 7389 with 6348 rows to crime_data.gpkg_temp_7389.gpkg
# Wrote chunk 7390 with 14984 rows to crime_data.gpkg_temp_7390.gpkg
# Wrote chunk 7391 with 8418 rows to crime_data.gpkg_temp_7391.gpkg
# Wrote chunk 7392 with 10993 rows to crime_data.gpkg_temp_7392.gpkg
# Wrote chunk 7393 with 15600 rows to crime_data.gpkg_temp_7393.gpkg
# Wrote chunk 7394 with 8538 rows to crime_data.gpkg_temp_7394.gpkg
# Wrote chunk 7395 with 4262 rows to crime_data.gpkg_temp_7395.gpkg
# Wrote chunk 7396 with 7630 rows to crime_data.gpkg_temp_7396.gpkg
# Wrote chunk 7397 with 13449 rows to crime_data.gpkg_temp_7397.gpkg
# Wrote chunk 7398 with 17472 rows to crime_data.gpkg_temp_7398.gpkg
# Wrote chunk 7399 with 4260 rows to crime_data.gpkg_temp_7399.gpkg
# Wrote chunk 7400 with 8500 rows to crime_data.gpkg_temp_7400.gpkg
# Wrote chunk 7401 with 29074 rows to crime_data.gpkg_temp_7401.gpkg
# Wrote chunk 7402 with 26430 rows to crime_data.gpkg_temp_7402.gpkg
# Wrote chunk 7403 with 4320 rows to crime_data.gpkg_temp_7403.gpkg
# Wrote chunk 7404 with 15434 rows to crime_data.gpkg_temp_7404.gpkg
# Wrote chunk 7405 with 4932 rows to crime_data.gpkg_temp_7405.gpkg
# Wrote chunk 7406 with 3545 rows to crime_data.gpkg_temp_7406.gpkg
# Wrote chunk 7407 with 6398 rows to crime_data.gpkg_temp_7407.gpkg
# Wrote chunk 7408 with 6528 rows to crime_data.gpkg_temp_7408.gpkg
# Wrote chunk 7409 with 821 rows to crime_data.gpkg_temp_7409.gpkg
# Wrote chunk 7410 with 6950 rows to crime_data.gpkg_temp_7410.gpkg
# Wrote chunk 7411 with 3392 rows to crime_data.gpkg_temp_7411.gpkg
# Wrote chunk 7412 with 6964 rows to crime_data.gpkg_temp_7412.gpkg
# Wrote chunk 7413 with 11997 rows to crime_data.gpkg_temp_7413.gpkg
# Wrote chunk 7414 with 4686 rows to crime_data.gpkg_temp_7414.gpkg
# Wrote chunk 7415 with 5954 rows to crime_data.gpkg_temp_7415.gpkg
# Wrote chunk 7416 with 3572 rows to crime_data.gpkg_temp_7416.gpkg
# Wrote chunk 7417 with 13016 rows to crime_data.gpkg_temp_7417.gpkg
# Wrote chunk 7418 with 4607 rows to crime_data.gpkg_temp_7418.gpkg
# Wrote chunk 7419 with 5930 rows to crime_data.gpkg_temp_7419.gpkg
# Wrote chunk 7420 with 14129 rows to crime_data.gpkg_temp_7420.gpkg
# Wrote chunk 7421 with 8869 rows to crime_data.gpkg_temp_7421.gpkg
# Wrote chunk 7422 with 7404 rows to crime_data.gpkg_temp_7422.gpkg
# Wrote chunk 7423 with 14221 rows to crime_data.gpkg_temp_7423.gpkg
# Wrote chunk 7424 with 14626 rows to crime_data.gpkg_temp_7424.gpkg
# Wrote chunk 7425 with 8953 rows to crime_data.gpkg_temp_7425.gpkg
# Wrote chunk 7426 with 6248 rows to crime_data.gpkg_temp_7426.gpkg
# Wrote chunk 7427 with 12551 rows to crime_data.gpkg_temp_7427.gpkg
# Wrote chunk 7428 with 98011 rows to crime_data.gpkg_temp_7428.gpkg
# Wrote chunk 7429 with 5651 rows to crime_data.gpkg_temp_7429.gpkg
# Wrote chunk 7430 with 5746 rows to crime_data.gpkg_temp_7430.gpkg
# Wrote chunk 7431 with 5896 rows to crime_data.gpkg_temp_7431.gpkg
# Wrote chunk 7432 with 14533 rows to crime_data.gpkg_temp_7432.gpkg
# Wrote chunk 7433 with 8238 rows to crime_data.gpkg_temp_7433.gpkg
# Wrote chunk 7434 with 10261 rows to crime_data.gpkg_temp_7434.gpkg
# Wrote chunk 7435 with 14963 rows to crime_data.gpkg_temp_7435.gpkg
# Wrote chunk 7436 with 7716 rows to crime_data.gpkg_temp_7436.gpkg
# Wrote chunk 7437 with 3923 rows to crime_data.gpkg_temp_7437.gpkg
# Wrote chunk 7438 with 7308 rows to crime_data.gpkg_temp_7438.gpkg
# Wrote chunk 7439 with 12626 rows to crime_data.gpkg_temp_7439.gpkg
# Wrote chunk 7440 with 16239 rows to crime_data.gpkg_temp_7440.gpkg
# Wrote chunk 7441 with 3716 rows to crime_data.gpkg_temp_7441.gpkg
# Wrote chunk 7442 with 8135 rows to crime_data.gpkg_temp_7442.gpkg
# Wrote chunk 7443 with 26571 rows to crime_data.gpkg_temp_7443.gpkg
# Wrote chunk 7444 with 25098 rows to crime_data.gpkg_temp_7444.gpkg
# Wrote chunk 7445 with 4032 rows to crime_data.gpkg_temp_7445.gpkg
# Wrote chunk 7446 with 14737 rows to crime_data.gpkg_temp_7446.gpkg
# Wrote chunk 7447 with 4997 rows to crime_data.gpkg_temp_7447.gpkg
# Wrote chunk 7448 with 3309 rows to crime_data.gpkg_temp_7448.gpkg
# Wrote chunk 7449 with 6043 rows to crime_data.gpkg_temp_7449.gpkg
# Wrote chunk 7450 with 6361 rows to crime_data.gpkg_temp_7450.gpkg
# Wrote chunk 7451 with 766 rows to crime_data.gpkg_temp_7451.gpkg
# Wrote chunk 7452 with 6096 rows to crime_data.gpkg_temp_7452.gpkg
# Wrote chunk 7453 with 3201 rows to crime_data.gpkg_temp_7453.gpkg
# Wrote chunk 7454 with 7742 rows to crime_data.gpkg_temp_7454.gpkg
# Wrote chunk 7455 with 11050 rows to crime_data.gpkg_temp_7455.gpkg
# Wrote chunk 7456 with 4328 rows to crime_data.gpkg_temp_7456.gpkg
# Wrote chunk 7457 with 5554 rows to crime_data.gpkg_temp_7457.gpkg
# Wrote chunk 7458 with 3201 rows to crime_data.gpkg_temp_7458.gpkg
# Wrote chunk 7459 with 12190 rows to crime_data.gpkg_temp_7459.gpkg
# Wrote chunk 7460 with 4264 rows to crime_data.gpkg_temp_7460.gpkg
# Wrote chunk 7461 with 5348 rows to crime_data.gpkg_temp_7461.gpkg
# Wrote chunk 7462 with 12886 rows to crime_data.gpkg_temp_7462.gpkg
# Wrote chunk 7463 with 8300 rows to crime_data.gpkg_temp_7463.gpkg
# Wrote chunk 7464 with 7137 rows to crime_data.gpkg_temp_7464.gpkg
# Wrote chunk 7465 with 13807 rows to crime_data.gpkg_temp_7465.gpkg
# Wrote chunk 7466 with 13867 rows to crime_data.gpkg_temp_7466.gpkg
# Wrote chunk 7467 with 8216 rows to crime_data.gpkg_temp_7467.gpkg
# Wrote chunk 7468 with 5235 rows to crime_data.gpkg_temp_7468.gpkg
# Wrote chunk 7469 with 11568 rows to crime_data.gpkg_temp_7469.gpkg
# Wrote chunk 7470 with 91065 rows to crime_data.gpkg_temp_7470.gpkg
# Wrote chunk 7471 with 5181 rows to crime_data.gpkg_temp_7471.gpkg
# Wrote chunk 7472 with 5200 rows to crime_data.gpkg_temp_7472.gpkg
# Wrote chunk 7473 with 5485 rows to crime_data.gpkg_temp_7473.gpkg
# Wrote chunk 7474 with 13148 rows to crime_data.gpkg_temp_7474.gpkg
# Wrote chunk 7475 with 9444 rows to crime_data.gpkg_temp_7475.gpkg
# Wrote chunk 7476 with 9384 rows to crime_data.gpkg_temp_7476.gpkg
# Wrote chunk 7477 with 13142 rows to crime_data.gpkg_temp_7477.gpkg
# Wrote chunk 7478 with 7706 rows to crime_data.gpkg_temp_7478.gpkg
# Wrote chunk 7479 with 3606 rows to crime_data.gpkg_temp_7479.gpkg
# Wrote chunk 7480 with 6681 rows to crime_data.gpkg_temp_7480.gpkg
# Wrote chunk 7481 with 11749 rows to crime_data.gpkg_temp_7481.gpkg
# Wrote chunk 7482 with 14877 rows to crime_data.gpkg_temp_7482.gpkg
# Wrote chunk 7483 with 3684 rows to crime_data.gpkg_temp_7483.gpkg
# Wrote chunk 7484 with 7757 rows to crime_data.gpkg_temp_7484.gpkg
# Wrote chunk 7485 with 25723 rows to crime_data.gpkg_temp_7485.gpkg
# Wrote chunk 7486 with 23597 rows to crime_data.gpkg_temp_7486.gpkg
# Wrote chunk 7487 with 3835 rows to crime_data.gpkg_temp_7487.gpkg
# Wrote chunk 7488 with 14828 rows to crime_data.gpkg_temp_7488.gpkg
# Wrote chunk 7489 with 4851 rows to crime_data.gpkg_temp_7489.gpkg
# Wrote chunk 7490 with 6267 rows to crime_data.gpkg_temp_7490.gpkg
# Wrote chunk 7491 with 6088 rows to crime_data.gpkg_temp_7491.gpkg
# Wrote chunk 7492 with 629 rows to crime_data.gpkg_temp_7492.gpkg
# Wrote chunk 7493 with 6494 rows to crime_data.gpkg_temp_7493.gpkg
# Wrote chunk 7494 with 2975 rows to crime_data.gpkg_temp_7494.gpkg
# Wrote chunk 7495 with 7793 rows to crime_data.gpkg_temp_7495.gpkg
# Wrote chunk 7496 with 11460 rows to crime_data.gpkg_temp_7496.gpkg
# Wrote chunk 7497 with 4156 rows to crime_data.gpkg_temp_7497.gpkg
# Wrote chunk 7498 with 5408 rows to crime_data.gpkg_temp_7498.gpkg
# Wrote chunk 7499 with 3478 rows to crime_data.gpkg_temp_7499.gpkg
# Wrote chunk 7500 with 12144 rows to crime_data.gpkg_temp_7500.gpkg
# Wrote chunk 7501 with 4485 rows to crime_data.gpkg_temp_7501.gpkg
# Wrote chunk 7502 with 5318 rows to crime_data.gpkg_temp_7502.gpkg
# Wrote chunk 7503 with 13481 rows to crime_data.gpkg_temp_7503.gpkg
# Wrote chunk 7504 with 8574 rows to crime_data.gpkg_temp_7504.gpkg
# Wrote chunk 7505 with 7226 rows to crime_data.gpkg_temp_7505.gpkg
# Wrote chunk 7506 with 14201 rows to crime_data.gpkg_temp_7506.gpkg
# Wrote chunk 7507 with 13630 rows to crime_data.gpkg_temp_7507.gpkg
# Wrote chunk 7508 with 8448 rows to crime_data.gpkg_temp_7508.gpkg
# Wrote chunk 7509 with 5184 rows to crime_data.gpkg_temp_7509.gpkg
# Wrote chunk 7510 with 11192 rows to crime_data.gpkg_temp_7510.gpkg
# Wrote chunk 7511 with 86952 rows to crime_data.gpkg_temp_7511.gpkg
# Wrote chunk 7512 with 5419 rows to crime_data.gpkg_temp_7512.gpkg
# Wrote chunk 7513 with 4726 rows to crime_data.gpkg_temp_7513.gpkg
# Wrote chunk 7514 with 5773 rows to crime_data.gpkg_temp_7514.gpkg
# Wrote chunk 7515 with 13233 rows to crime_data.gpkg_temp_7515.gpkg
# Wrote chunk 7516 with 9548 rows to crime_data.gpkg_temp_7516.gpkg
# Wrote chunk 7517 with 10215 rows to crime_data.gpkg_temp_7517.gpkg
# Wrote chunk 7518 with 13115 rows to crime_data.gpkg_temp_7518.gpkg
# Wrote chunk 7519 with 7522 rows to crime_data.gpkg_temp_7519.gpkg
# Wrote chunk 7520 with 3688 rows to crime_data.gpkg_temp_7520.gpkg
# Wrote chunk 7521 with 6255 rows to crime_data.gpkg_temp_7521.gpkg
# Wrote chunk 7522 with 14877 rows to crime_data.gpkg_temp_7522.gpkg
# Wrote chunk 7523 with 3701 rows to crime_data.gpkg_temp_7523.gpkg
# Wrote chunk 7524 with 7913 rows to crime_data.gpkg_temp_7524.gpkg
# Wrote chunk 7525 with 25601 rows to crime_data.gpkg_temp_7525.gpkg
# Wrote chunk 7526 with 23232 rows to crime_data.gpkg_temp_7526.gpkg
# Wrote chunk 7527 with 3830 rows to crime_data.gpkg_temp_7527.gpkg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 78
#      76 street_parquet = r"C:\Studie\SSML\project\police_crime_archive\extracted_2013_2025\combined_street.parquet"
#      77 gpkg_path = r"crime_data.gpkg"
# ---> 78 chunked_parquet_to_gpkg(street_parquet, gpkg_path, layer_name="street_data")
#
# Cell In[3], line 54, in chunked_parquet_to_gpkg(parquet_file, gpkg_file, layer_name, chunksize)
#      52 merged_gdf = None
#      53 for i, temp_path in enumerate(temp_files):
# ---> 54     chunk_gdf = gpd.read_file(temp_path, layer=layer_name)
#      55     if merged_gdf is None:
#      56         merged_gdf = chunk_gdf
#
# File c:\Users\Gebruiker\anaconda3\envs\geospatial\Lib\site-packages\geopandas\io\file.py:190, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     186     except Exception:
#     187         return False
# --> 190 def _read_file(
#     191     filename, bbox=None, mask=None, columns=None, rows=None, engine=None, **kwargs
#     192 ):
#     193     """
#     194     Returns a GeoDataFrame from a file or URL.
#     195
#    (...)
#     276
#     277     """
#     278     engine = _check_engine(engine, "'read_file' function")
#
# KeyboardInterrupt:

# %%
import os
import time
import logging
import pyarrow as pa
import pyarrow.dataset as ds
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

def chunked_parquet_to_gpkg(
    parquet_file,
    gpkg_file,
    layer_name,
    chunksize=1_000_000,
    x_col='Longitude',
    y_col='Latitude',
    crs="EPSG:4326"
):
    """
    Streams a large Parquet file in chunks, converts each chunk to a GeoDataFrame,
    and writes/appends it to a single GeoPackage layer.
    
    Args:
        parquet_file (str): Path to the large Parquet file.
        gpkg_file (str): Path to output GeoPackage.
        layer_name (str): The name of the layer in the GeoPackage.
        chunksize (int): Approx. number of rows per chunk.
        x_col (str): Column name for x-coordinates (longitude).
        y_col (str): Column name for y-coordinates (latitude).
        crs (str): Coordinate reference system string (e.g., "EPSG:4326").
    """
    logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
    logger = logging.getLogger(__name__)

    logger.info(f"Starting optimized chunked Parquet-to-GPKG conversion...")
    start_time = time.perf_counter()

    # Create dataset
    try:
        dataset = ds.dataset(parquet_file, format="parquet")
        total_rows = dataset.count_rows()
        logger.info(f"Total rows in dataset: {total_rows}")
    except Exception as e:
        logger.error(f"Failed to open Parquet dataset: {e}")
        return

    # Get schema information for the first chunk to ensure consistency
    try:
        # Get the first batch to determine schema
        scanner = dataset.scanner(batch_size=1)
        first_batch = next(scanner.to_batches())
        schema = first_batch.schema
        logger.info(f"Dataset schema: {schema}")
    except Exception as e:
        logger.error(f"Error accessing schema: {e}")
        return

    # Process in chunks
    chunk_idx = 0
    processed_rows = 0
    
    # Create scanner with the desired batch size
    scanner = dataset.scanner(batch_size=chunksize)
    
    # Delete existing file if it exists to avoid append issues
    if os.path.exists(gpkg_file) and chunk_idx == 0:
        try:
            if os.path.exists(gpkg_file):
                logger.info(f"Removing existing GeoPackage: {gpkg_file}")
                os.remove(gpkg_file)
        except Exception as e:
            logger.error(f"Error removing existing GeoPackage: {e}")
    
    for batch in scanner.to_batches():
        chunk_start = time.perf_counter()
        
        try:
            # Convert batch to DataFrame
            df = batch.to_pandas()
            processed_rows += len(df)
            
            # Create geometry column
            geometry = [Point(x, y) for x, y in zip(df[x_col], df[y_col])]
            
            # Create GeoDataFrame
            gdf = gpd.GeoDataFrame(df, geometry=geometry, crs=crs)
            
            # Write to GeoPackage
            if chunk_idx == 0:
                # First chunk: create new file
                gdf.to_file(gpkg_file, layer=layer_name, driver="GPKG")
                logger.info(f"Created new GeoPackage with {len(gdf)} rows in layer '{layer_name}'")
            else:
                # Subsequent chunks: append to existing layer
                gdf.to_file(gpkg_file, layer=layer_name, driver="GPKG", mode="a")
                logger.info(f"Appended {len(gdf)} rows to layer '{layer_name}'")
                
            chunk_idx += 1
            chunk_time = time.perf_counter() - chunk_start
            elapsed = time.perf_counter() - start_time
            
            # Log progress
            percent = processed_rows / total_rows * 100
            est_total_time = (elapsed / processed_rows) * total_rows
            remaining_time = est_total_time - elapsed
            
            logger.info(
                f"Chunk {chunk_idx} processed in {chunk_time:.2f}s, "
                f"{processed_rows}/{total_rows} rows ({percent:.2f}%). "
                f"Estimated remaining time: {remaining_time:.2f}s"
            )
            
        except Exception as e:
            logger.error(f"Error processing chunk {chunk_idx}: {e}")
            continue

    # Final summary
    total_elapsed = time.perf_counter() - start_time
    logger.info(f"Finished writing {chunk_idx} chunks to '{gpkg_file}' layer='{layer_name}'.")
    logger.info(f"Total rows processed: {processed_rows}")
    logger.info(f"Total time: {total_elapsed:.2f}s")
    logger.info(f"Average processing speed: {processed_rows / total_elapsed:.2f} rows/second")

# -----------------------------------------------------------------------------
if __name__ == "__main__":
    parquet_file = r"C:\Studie\SSML\project\police_crime_archive\extracted_2013_2025\combined_street.parquet"
    gpkg_file   = r"C:\Studie\SSML\project\police_crime_archive\extracted_2013_2025\crime_data_uk.gpkg"
    layer_name  = "street_data"

    # Adjust chunk size based on available memory
    chunk_size = 500_000  # Reduced for better memory management

    # Run the chunk-based conversion
    chunked_parquet_to_gpkg(
        parquet_file=parquet_file,
        gpkg_file=gpkg_file,
        layer_name=layer_name,
        chunksize=chunk_size
    )
# Out:
# 2025-03-17 20:58:18,092 [INFO] Starting optimized chunked Parquet-to-GPKG conversion...
# 2025-03-17 20:58:18,361 [INFO] Total rows in dataset: 87463152
# 2025-03-17 20:58:18,491 [INFO] Dataset schema: Crime ID: string
# Month: string
# Reported by: string
# Falls within: string
# Longitude: double
# Latitude: double
# Location: string
# LSOA code: string
# LSOA name: string
# Crime type: string
# Last outcome category: string
# Context: string
# 2025-03-17 20:58:20,002 [INFO] Created 12,201 records
# 2025-03-17 20:58:20,269 [INFO] Created new GeoPackage with 12201 rows in layer 'street_data'
# 2025-03-17 20:58:20,273 [INFO] Chunk 1 processed in 1.29s, 12201/87463152 rows (0.01%). Estimated remaining time: 15584.66s
# 2025-03-17 20:58:20,629 [INFO] Created 5,393 records
# 2025-03-17 20:58:20,654 [INFO] Appended 5393 rows to layer 'street_data'
# 2025-03-17 20:58:20,655 [INFO] Chunk 2 processed in 0.38s, 17594/87463152 rows (0.02%). Estimated remaining time: 12705.80s
# 2025-03-17 20:58:20,741 [INFO] Created 1,470 records
# 2025-03-17 20:58:20,765 [INFO] Appended 1470 rows to layer 'street_data'
# 2025-03-17 20:58:20,765 [INFO] Chunk 3 processed in 0.11s, 19064/87463152 rows (0.02%). Estimated remaining time: 12234.41s
# 2025-03-17 20:58:20,984 [INFO] Created 5,916 records
# 2025-03-17 20:58:21,011 [INFO] Appended 5916 rows to layer 'street_data'
# 2025-03-17 20:58:21,012 [INFO] Chunk 4 processed in 0.24s, 24980/87463152 rows (0.03%). Estimated remaining time: 10196.39s
# 2025-03-17 20:58:21,188 [INFO] Created 4,363 records
# 2025-03-17 20:58:21,208 [INFO] Appended 4363 rows to layer 'street_data'
# 2025-03-17 20:58:21,209 [INFO] Chunk 5 processed in 0.20s, 29343/87463152 rows (0.03%). Estimated remaining time: 9265.00s
# 2025-03-17 20:58:21,281 [INFO] Created 635 records
# 2025-03-17 20:58:21,310 [INFO] Appended 635 rows to layer 'street_data'
# 2025-03-17 20:58:21,310 [INFO] Chunk 6 processed in 0.10s, 29978/87463152 rows (0.03%). Estimated remaining time: 9366.44s
# 2025-03-17 20:58:21,523 [INFO] Created 6,195 records
# 2025-03-17 20:58:21,551 [INFO] Appended 6195 rows to layer 'street_data'
# 2025-03-17 20:58:21,553 [INFO] Chunk 7 processed in 0.24s, 36173/87463152 rows (0.04%). Estimated remaining time: 8347.78s
# 2025-03-17 20:58:21,748 [INFO] Created 4,083 records
# 2025-03-17 20:58:21,775 [INFO] Appended 4083 rows to layer 'street_data'
# 2025-03-17 20:58:21,776 [INFO] Chunk 8 processed in 0.22s, 40256/87463152 rows (0.05%). Estimated remaining time: 7983.46s
# 2025-03-17 20:58:22,075 [INFO] Created 8,316 records
# 2025-03-17 20:58:22,091 [INFO] Appended 8316 rows to layer 'street_data'
# 2025-03-17 20:58:22,091 [INFO] Chunk 9 processed in 0.32s, 48572/87463152 rows (0.06%). Estimated remaining time: 7200.23s
# 2025-03-17 20:58:22,411 [INFO] Created 9,829 records
# 2025-03-17 20:58:22,437 [INFO] Appended 9829 rows to layer 'street_data'
# 2025-03-17 20:58:22,441 [INFO] Chunk 10 processed in 0.34s, 58401/87463152 rows (0.07%). Estimated remaining time: 6498.57s
# 2025-03-17 20:59:36,572 [INFO] Created 6,190 records
# 2025-03-17 20:59:36,591 [INFO] Appended 6190 rows to layer 'street_data'
# 2025-03-17 20:59:36,592 [INFO] Chunk 11 processed in 74.15s, 64591/87463152 rows (0.07%). Estimated remaining time: 106209.59s
# 2025-03-17 20:59:36,681 [INFO] Created 2,119 records
# 2025-03-17 20:59:36,701 [INFO] Appended 2119 rows to layer 'street_data'
# 2025-03-17 20:59:36,702 [INFO] Chunk 12 processed in 0.11s, 66710/87463152 rows (0.08%). Estimated remaining time: 102977.29s
# 2025-03-17 20:59:36,803 [INFO] Created 3,330 records
# 2025-03-17 20:59:36,823 [INFO] Appended 3330 rows to layer 'street_data'
# 2025-03-17 20:59:36,823 [INFO] Chunk 13 processed in 0.12s, 70040/87463152 rows (0.08%). Estimated remaining time: 98234.08s
# 2025-03-17 20:59:37,111 [INFO] Created 11,736 records
# 2025-03-17 20:59:37,133 [INFO] Appended 11736 rows to layer 'street_data'
# 2025-03-17 20:59:37,133 [INFO] Chunk 14 processed in 0.30s, 81776/87463152 rows (0.09%). Estimated remaining time: 84452.64s
# 2025-03-17 20:59:37,283 [INFO] Created 4,581 records
# 2025-03-17 20:59:37,298 [INFO] Appended 4581 rows to layer 'street_data'
# 2025-03-17 20:59:37,299 [INFO] Chunk 15 processed in 0.16s, 86357/87463152 rows (0.10%). Estimated remaining time: 80135.47s
# 2025-03-17 20:59:37,917 [INFO] Created 25,968 records
# 2025-03-17 20:59:37,935 [INFO] Appended 25968 rows to layer 'street_data'
# 2025-03-17 20:59:37,936 [INFO] Chunk 16 processed in 0.64s, 112325/87463152 rows (0.13%). Estimated remaining time: 62086.63s
# 2025-03-17 20:59:38,101 [INFO] Created 6,258 records
# 2025-03-17 20:59:38,118 [INFO] Appended 6258 rows to layer 'street_data'
# 2025-03-17 20:59:38,119 [INFO] Chunk 17 processed in 0.18s, 118583/87463152 rows (0.14%). Estimated remaining time: 58940.07s
# 2025-03-17 20:59:38,449 [INFO] Created 14,347 records
# 2025-03-17 20:59:38,466 [INFO] Appended 14347 rows to layer 'street_data'
# 2025-03-17 20:59:38,467 [INFO] Chunk 18 processed in 0.35s, 132930/87463152 rows (0.15%). Estimated remaining time: 52798.91s
# 2025-03-17 20:59:38,695 [INFO] Created 8,843 records
# 2025-03-17 20:59:38,713 [INFO] Appended 8843 rows to layer 'street_data'
# 2025-03-17 20:59:38,713 [INFO] Chunk 19 processed in 0.25s, 141773/87463152 rows (0.16%). Estimated remaining time: 49652.85s
# 2025-03-17 20:59:38,893 [INFO] Created 6,976 records
# 2025-03-17 20:59:38,909 [INFO] Appended 6976 rows to layer 'street_data'
# 2025-03-17 20:59:38,909 [INFO] Chunk 20 processed in 0.19s, 148749/87463152 rows (0.17%). Estimated remaining time: 47434.89s
# 2025-03-17 20:59:39,213 [INFO] Created 12,811 records
# 2025-03-17 20:59:39,236 [INFO] Appended 12811 rows to layer 'street_data'
# 2025-03-17 20:59:39,236 [INFO] Chunk 21 processed in 0.33s, 161560/87463152 rows (0.18%). Estimated remaining time: 43844.77s
# 2025-03-17 20:59:39,594 [INFO] Created 15,013 records
# 2025-03-17 20:59:39,603 [INFO] Appended 15013 rows to layer 'street_data'
# 2025-03-17 20:59:39,611 [INFO] Chunk 22 processed in 0.37s, 176573/87463152 rows (0.20%). Estimated remaining time: 40294.58s
# 2025-03-17 20:59:39,812 [INFO] Created 7,339 records
# 2025-03-17 20:59:39,832 [INFO] Appended 7339 rows to layer 'street_data'
# 2025-03-17 20:59:39,833 [INFO] Chunk 23 processed in 0.22s, 183912/87463152 rows (0.21%). Estimated remaining time: 38788.46s
# 2025-03-17 20:59:39,972 [INFO] Created 4,999 records
# 2025-03-17 20:59:39,987 [INFO] Appended 4999 rows to layer 'street_data'
# 2025-03-17 20:59:39,988 [INFO] Chunk 24 processed in 0.15s, 188911/87463152 rows (0.22%). Estimated remaining time: 37831.55s
# 2025-03-17 20:59:40,255 [INFO] Created 11,194 records
# 2025-03-17 20:59:40,272 [INFO] Appended 11194 rows to layer 'street_data'
# 2025-03-17 20:59:40,272 [INFO] Chunk 25 processed in 0.29s, 200105/87463152 rows (0.23%). Estimated remaining time: 35835.47s
# 2025-03-17 20:59:42,321 [INFO] Created 92,442 records
# 2025-03-17 20:59:42,341 [INFO] Appended 92442 rows to layer 'street_data'
# 2025-03-17 20:59:42,341 [INFO] Chunk 26 processed in 2.07s, 292547/87463152 rows (0.33%). Estimated remaining time: 25103.99s
# 2025-03-17 20:59:42,511 [INFO] Created 6,077 records
# 2025-03-17 20:59:42,536 [INFO] Appended 6077 rows to layer 'street_data'
# 2025-03-17 20:59:42,536 [INFO] Chunk 27 processed in 0.19s, 298624/87463152 rows (0.34%). Estimated remaining time: 24646.78s
# 2025-03-17 20:59:42,681 [INFO] Created 5,335 records
# 2025-03-17 20:59:42,691 [INFO] Appended 5335 rows to layer 'street_data'
# 2025-03-17 20:59:42,691 [INFO] Chunk 28 processed in 0.16s, 303959/87463152 rows (0.35%). Estimated remaining time: 24258.86s
# 2025-03-17 20:59:42,841 [INFO] Created 5,439 records
# 2025-03-17 20:59:42,861 [INFO] Appended 5439 rows to layer 'street_data'
# 2025-03-17 20:59:42,861 [INFO] Chunk 29 processed in 0.16s, 309398/87463152 rows (0.35%). Estimated remaining time: 23877.03s
# 2025-03-17 20:59:43,019 [INFO] Created 5,949 records
# 2025-03-17 20:59:43,036 [INFO] Appended 5949 rows to layer 'street_data'
# 2025-03-17 20:59:43,036 [INFO] Chunk 30 processed in 0.17s, 315347/87463152 rows (0.36%). Estimated remaining time: 23472.95s
# 2025-03-17 20:59:43,321 [INFO] Created 12,072 records
# 2025-03-17 20:59:43,339 [INFO] Appended 12072 rows to layer 'street_data'
# 2025-03-17 20:59:43,341 [INFO] Chunk 31 processed in 0.30s, 327419/87463152 rows (0.37%). Estimated remaining time: 22685.31s
# 2025-03-17 20:59:43,603 [INFO] Created 9,478 records
# 2025-03-17 20:59:43,620 [INFO] Appended 9478 rows to layer 'street_data'
# 2025-03-17 20:59:43,621 [INFO] Chunk 32 processed in 0.28s, 336897/87463152 rows (0.39%). Estimated remaining time: 22117.28s
# 2025-03-17 20:59:43,892 [INFO] Created 11,473 records
# 2025-03-17 20:59:43,903 [INFO] Appended 11473 rows to layer 'street_data'
# 2025-03-17 20:59:43,911 [INFO] Chunk 33 processed in 0.29s, 348370/87463152 rows (0.40%). Estimated remaining time: 21458.49s
# 2025-03-17 20:59:44,253 [INFO] Created 13,405 records
# 2025-03-17 20:59:44,271 [INFO] Appended 13405 rows to layer 'street_data'
# 2025-03-17 20:59:44,272 [INFO] Chunk 34 processed in 0.36s, 361775/87463152 rows (0.41%). Estimated remaining time: 20747.12s
# 2025-03-17 20:59:44,446 [INFO] Created 6,942 records
# 2025-03-17 20:59:44,465 [INFO] Appended 6942 rows to layer 'street_data'
# 2025-03-17 20:59:44,465 [INFO] Chunk 35 processed in 0.19s, 368717/87463152 rows (0.42%). Estimated remaining time: 20400.77s
# 2025-03-17 20:59:44,618 [INFO] Created 5,631 records
# 2025-03-17 20:59:44,639 [INFO] Appended 5631 rows to layer 'street_data'
# 2025-03-17 20:59:44,639 [INFO] Chunk 36 processed in 0.17s, 374348/87463152 rows (0.43%). Estimated remaining time: 20132.79s
# 2025-03-17 20:59:44,867 [INFO] Created 8,861 records
# 2025-03-17 20:59:44,883 [INFO] Appended 8861 rows to layer 'street_data'
# 2025-03-17 20:59:44,883 [INFO] Chunk 37 processed in 0.24s, 383209/87463152 rows (0.44%). Estimated remaining time: 19720.79s
# 2025-03-17 20:59:45,192 [INFO] Created 12,988 records
# 2025-03-17 20:59:45,203 [INFO] Appended 12988 rows to layer 'street_data'
# 2025-03-17 20:59:45,203 [INFO] Chunk 38 processed in 0.32s, 396197/87463152 rows (0.45%). Estimated remaining time: 19142.63s
# 2025-03-17 20:59:45,581 [INFO] Created 16,071 records
# 2025-03-17 20:59:45,597 [INFO] Appended 16071 rows to layer 'street_data'
# 2025-03-17 20:59:45,598 [INFO] Chunk 39 processed in 0.39s, 412268/87463152 rows (0.47%). Estimated remaining time: 18475.57s
# 2025-03-17 20:59:45,703 [INFO] Created 3,958 records
# 2025-03-17 20:59:45,721 [INFO] Appended 3958 rows to layer 'street_data'
# 2025-03-17 20:59:45,721 [INFO] Chunk 40 processed in 0.13s, 416226/87463152 rows (0.48%). Estimated remaining time: 18326.15s
# 2025-03-17 20:59:45,986 [INFO] Created 9,643 records
# 2025-03-17 20:59:46,001 [INFO] Appended 9643 rows to layer 'street_data'
# 2025-03-17 20:59:46,002 [INFO] Chunk 41 processed in 0.27s, 425869/87463152 rows (0.49%). Estimated remaining time: 17965.26s
# 2025-03-17 20:59:46,531 [INFO] Created 22,838 records
# 2025-03-17 20:59:46,541 [INFO] Appended 22838 rows to layer 'street_data'
# 2025-03-17 20:59:46,541 [INFO] Chunk 42 processed in 0.55s, 448707/87463152 rows (0.51%). Estimated remaining time: 17152.61s
# 2025-03-17 20:59:47,033 [INFO] Created 21,296 records
# 2025-03-17 20:59:47,051 [INFO] Appended 21296 rows to layer 'street_data'
# 2025-03-17 20:59:47,054 [INFO] Chunk 43 processed in 0.50s, 470003/87463152 rows (0.54%). Estimated remaining time: 16464.72s
# 2025-03-17 20:59:47,191 [INFO] Created 4,338 records
# 2025-03-17 20:59:47,206 [INFO] Appended 4338 rows to layer 'street_data'
# 2025-03-17 20:59:47,207 [INFO] Chunk 44 processed in 0.15s, 474341/87463152 rows (0.54%). Estimated remaining time: 16341.27s
# 2025-03-17 20:59:47,535 [INFO] Created 13,781 records
# 2025-03-17 20:59:47,541 [INFO] Appended 13781 rows to layer 'street_data'
# 2025-03-17 20:59:47,551 [INFO] Chunk 45 processed in 0.34s, 488122/87463152 rows (0.56%). Estimated remaining time: 15938.84s
# 2025-03-17 20:59:47,702 [INFO] Created 5,862 records
# 2025-03-17 20:59:47,720 [INFO] Appended 5862 rows to layer 'street_data'
# 2025-03-17 20:59:47,721 [INFO] Chunk 46 processed in 0.17s, 493984/87463152 rows (0.56%). Estimated remaining time: 15778.46s
# 2025-03-17 20:59:47,817 [INFO] Created 1,755 records
# 2025-03-17 20:59:47,838 [INFO] Appended 1755 rows to layer 'street_data'
# 2025-03-17 20:59:47,839 [INFO] Chunk 47 processed in 0.12s, 495739/87463152 rows (0.57%). Estimated remaining time: 15743.00s
# 2025-03-17 20:59:48,011 [INFO] Created 6,682 records
# 2025-03-17 20:59:48,021 [INFO] Appended 6682 rows to layer 'street_data'
# 2025-03-17 20:59:48,021 [INFO] Chunk 48 processed in 0.19s, 502421/87463152 rows (0.57%). Estimated remaining time: 15565.07s
# 2025-03-17 20:59:48,161 [INFO] Created 4,837 records
# 2025-03-17 20:59:48,181 [INFO] Appended 4837 rows to layer 'street_data'
# 2025-03-17 20:59:48,181 [INFO] Chunk 49 processed in 0.15s, 507258/87463152 rows (0.58%). Estimated remaining time: 15442.23s
# 2025-03-17 20:59:48,215 [INFO] Created 696 records
# 2025-03-17 20:59:48,236 [INFO] Appended 696 rows to layer 'street_data'
# 2025-03-17 20:59:48,236 [INFO] Chunk 50 processed in 0.05s, 507954/87463152 rows (0.58%). Estimated remaining time: 15430.28s
# 2025-03-17 20:59:48,411 [INFO] Created 7,256 records
# 2025-03-17 20:59:48,421 [INFO] Appended 7256 rows to layer 'street_data'
# 2025-03-17 20:59:48,421 [INFO] Chunk 51 processed in 0.19s, 515210/87463152 rows (0.59%). Estimated remaining time: 15244.27s
# 2025-03-17 20:59:48,536 [INFO] Created 4,116 records
# 2025-03-17 20:59:48,553 [INFO] Appended 4116 rows to layer 'street_data'
# 2025-03-17 20:59:48,553 [INFO] Chunk 52 processed in 0.13s, 519326/87463152 rows (0.59%). Estimated remaining time: 15144.18s
# 2025-03-17 20:59:48,790 [INFO] Created 9,424 records
# 2025-03-17 20:59:48,803 [INFO] Appended 9424 rows to layer 'street_data'
# 2025-03-17 20:59:48,803 [INFO] Chunk 53 processed in 0.25s, 528750/87463152 rows (0.60%). Estimated remaining time: 14914.15s
# 2025-03-17 20:59:49,091 [INFO] Created 10,220 records
# 2025-03-17 20:59:49,111 [INFO] Appended 10220 rows to layer 'street_data'
# 2025-03-17 20:59:49,111 [INFO] Chunk 54 processed in 0.30s, 538970/87463152 rows (0.62%). Estimated remaining time: 14678.27s
# 2025-03-17 20:59:49,207 [INFO] Created 3,187 records
# 2025-03-17 20:59:49,221 [INFO] Appended 3187 rows to layer 'street_data'
# 2025-03-17 20:59:49,221 [INFO] Chunk 55 processed in 0.11s, 542157/87463152 rows (0.62%). Estimated remaining time: 14609.53s
# 2025-03-17 20:59:49,381 [INFO] Created 6,358 records
# 2025-03-17 20:59:49,391 [INFO] Appended 6358 rows to layer 'street_data'
# 2025-03-17 20:59:49,391 [INFO] Chunk 56 processed in 0.17s, 548515/87463152 rows (0.63%). Estimated remaining time: 14466.96s
# 2025-03-17 20:59:49,501 [INFO] Created 3,636 records
# 2025-03-17 20:59:49,520 [INFO] Appended 3636 rows to layer 'street_data'
# 2025-03-17 20:59:49,521 [INFO] Chunk 57 processed in 0.12s, 552151/87463152 rows (0.63%). Estimated remaining time: 14390.18s
# 2025-03-17 20:59:49,821 [INFO] Created 12,565 records
# 2025-03-17 20:59:49,841 [INFO] Appended 12565 rows to layer 'street_data'
# 2025-03-17 20:59:49,841 [INFO] Chunk 58 processed in 0.32s, 564716/87463152 rows (0.65%). Estimated remaining time: 14117.40s
# 2025-03-17 20:59:49,970 [INFO] Created 4,934 records
# 2025-03-17 20:59:49,987 [INFO] Appended 4934 rows to layer 'street_data'
# 2025-03-17 20:59:49,987 [INFO] Chunk 59 processed in 0.14s, 569650/87463152 rows (0.65%). Estimated remaining time: 14016.55s
# 2025-03-17 20:59:50,653 [INFO] Created 29,267 records
# 2025-03-17 20:59:50,671 [INFO] Appended 29267 rows to layer 'street_data'
# 2025-03-17 20:59:50,671 [INFO] Chunk 60 processed in 0.69s, 598917/87463152 rows (0.68%). Estimated remaining time: 13426.73s
# 2025-03-17 20:59:50,841 [INFO] Created 6,544 records
# 2025-03-17 20:59:50,861 [INFO] Appended 6544 rows to layer 'street_data'
# 2025-03-17 20:59:50,861 [INFO] Chunk 61 processed in 0.19s, 605461/87463152 rows (0.69%). Estimated remaining time: 13307.96s
# 2025-03-17 20:59:51,236 [INFO] Created 15,767 records
# 2025-03-17 20:59:51,251 [INFO] Appended 15767 rows to layer 'street_data'
# 2025-03-17 20:59:51,252 [INFO] Chunk 62 processed in 0.39s, 621228/87463152 rows (0.71%). Estimated remaining time: 13021.94s
# 2025-03-17 20:59:51,471 [INFO] Created 9,097 records
# 2025-03-17 20:59:51,491 [INFO] Appended 9097 rows to layer 'street_data'
# 2025-03-17 20:59:51,491 [INFO] Chunk 63 processed in 0.24s, 630325/87463152 rows (0.72%). Estimated remaining time: 12865.97s
# 2025-03-17 20:59:51,707 [INFO] Created 8,949 records
# 2025-03-17 20:59:51,727 [INFO] Appended 8949 rows to layer 'street_data'
# 2025-03-17 20:59:51,727 [INFO] Chunk 64 processed in 0.23s, 639274/87463152 rows (0.73%). Estimated remaining time: 12716.36s
# 2025-03-17 20:59:52,061 [INFO] Created 13,249 records
# 2025-03-17 20:59:52,081 [INFO] Appended 13249 rows to layer 'street_data'
# 2025-03-17 20:59:52,084 [INFO] Chunk 65 processed in 0.35s, 652523/87463152 rows (0.75%). Estimated remaining time: 12503.65s
# 2025-03-17 20:59:52,455 [INFO] Created 16,041 records
# 2025-03-17 20:59:52,471 [INFO] Appended 16041 rows to layer 'street_data'
# 2025-03-17 20:59:52,471 [INFO] Chunk 66 processed in 0.39s, 668564/87463152 rows (0.76%). Estimated remaining time: 12251.73s
# 2025-03-17 20:59:52,673 [INFO] Created 7,939 records
# 2025-03-17 20:59:52,690 [INFO] Appended 7939 rows to layer 'street_data'
# 2025-03-17 20:59:52,691 [INFO] Chunk 67 processed in 0.22s, 676503/87463152 rows (0.77%). Estimated remaining time: 12134.94s
# 2025-03-17 20:59:52,861 [INFO] Created 6,290 records
# 2025-03-17 20:59:52,871 [INFO] Appended 6290 rows to layer 'street_data'
# 2025-03-17 20:59:52,871 [INFO] Chunk 68 processed in 0.19s, 682793/87463152 rows (0.78%). Estimated remaining time: 12046.28s
# 2025-03-17 20:59:53,161 [INFO] Created 12,188 records
# 2025-03-17 20:59:53,181 [INFO] Appended 12188 rows to layer 'street_data'
# 2025-03-17 20:59:53,181 [INFO] Chunk 69 processed in 0.30s, 694981/87463152 rows (0.79%). Estimated remaining time: 11871.26s
# 2025-03-17 20:59:55,341 [INFO] Created 99,099 records
# 2025-03-17 20:59:55,361 [INFO] Appended 99099 rows to layer 'street_data'
# 2025-03-17 20:59:55,361 [INFO] Chunk 70 processed in 2.18s, 794080/87463152 rows (0.91%). Estimated remaining time: 10616.21s
# 2025-03-17 20:59:55,541 [INFO] Created 6,678 records
# 2025-03-17 20:59:55,552 [INFO] Appended 6678 rows to layer 'street_data'
# 2025-03-17 20:59:55,552 [INFO] Chunk 71 processed in 0.19s, 800758/87463152 rows (0.92%). Estimated remaining time: 10547.69s
# 2025-03-17 20:59:55,705 [INFO] Created 5,177 records
# 2025-03-17 20:59:55,722 [INFO] Appended 5177 rows to layer 'street_data'
# 2025-03-17 20:59:55,723 [INFO] Chunk 72 processed in 0.16s, 805935/87463152 rows (0.92%). Estimated remaining time: 10496.92s
# 2025-03-17 20:59:55,899 [INFO] Created 6,261 records
# 2025-03-17 20:59:55,915 [INFO] Appended 6261 rows to layer 'street_data'
# 2025-03-17 20:59:55,916 [INFO] Chunk 73 processed in 0.19s, 812196/87463152 rows (0.93%). Estimated remaining time: 10435.81s
# 2025-03-17 20:59:56,081 [INFO] Created 6,641 records
# 2025-03-17 20:59:56,097 [INFO] Appended 6641 rows to layer 'street_data'
# 2025-03-17 20:59:56,099 [INFO] Chunk 74 processed in 0.18s, 818837/87463152 rows (0.94%). Estimated remaining time: 10369.73s
# 2025-03-17 20:59:56,403 [INFO] Created 13,282 records
# 2025-03-17 20:59:56,419 [INFO] Appended 13282 rows to layer 'street_data'
# 2025-03-17 20:59:56,419 [INFO] Chunk 75 processed in 0.32s, 832119/87463152 rows (0.95%). Estimated remaining time: 10236.07s
# 2025-03-17 20:59:56,671 [INFO] Created 10,782 records
# 2025-03-17 20:59:56,691 [INFO] Appended 10782 rows to layer 'street_data'
# 2025-03-17 20:59:56,691 [INFO] Chunk 76 processed in 0.27s, 842901/87463152 rows (0.96%). Estimated remaining time: 10132.03s
# 2025-03-17 20:59:56,999 [INFO] Created 13,082 records
# 2025-03-17 20:59:57,016 [INFO] Appended 13082 rows to layer 'street_data'
# 2025-03-17 20:59:57,018 [INFO] Chunk 77 processed in 0.32s, 855983/87463152 rows (0.98%). Estimated remaining time: 10008.49s
# 2025-03-17 20:59:57,403 [INFO] Created 15,676 records
# 2025-03-17 20:59:57,421 [INFO] Appended 15676 rows to layer 'street_data'
# 2025-03-17 20:59:57,421 [INFO] Chunk 78 processed in 0.40s, 871659/87463152 rows (1.00%). Estimated remaining time: 9867.00s
# 2025-03-17 20:59:57,602 [INFO] Created 7,057 records
# 2025-03-17 20:59:57,621 [INFO] Appended 7057 rows to layer 'street_data'
# 2025-03-17 20:59:57,621 [INFO] Chunk 79 processed in 0.20s, 878716/87463152 rows (1.00%). Estimated remaining time: 9806.49s
# 2025-03-17 20:59:57,783 [INFO] Created 6,044 records
# 2025-03-17 20:59:57,801 [INFO] Appended 6044 rows to layer 'street_data'
# 2025-03-17 20:59:57,803 [INFO] Chunk 80 processed in 0.18s, 884760/87463152 rows (1.01%). Estimated remaining time: 9756.53s
# 2025-03-17 20:59:58,023 [INFO] Created 8,920 records
# 2025-03-17 20:59:58,041 [INFO] Appended 8920 rows to layer 'street_data'
# 2025-03-17 20:59:58,041 [INFO] Chunk 81 processed in 0.24s, 893680/87463152 rows (1.02%). Estimated remaining time: 9681.34s
# 2025-03-17 20:59:58,303 [INFO] Created 11,303 records
# 2025-03-17 20:59:58,321 [INFO] Appended 11303 rows to layer 'street_data'
# 2025-03-17 20:59:58,321 [INFO] Chunk 82 processed in 0.28s, 904983/87463152 rows (1.03%). Estimated remaining time: 9586.08s
# 2025-03-17 20:59:58,681 [INFO] Created 14,545 records
# 2025-03-17 20:59:58,699 [INFO] Appended 14545 rows to layer 'street_data'
# 2025-03-17 20:59:58,700 [INFO] Chunk 83 processed in 0.38s, 919528/87463152 rows (1.05%). Estimated remaining time: 9468.36s
# 2025-03-17 20:59:58,819 [INFO] Created 4,393 records
# 2025-03-17 20:59:58,836 [INFO] Appended 4393 rows to layer 'street_data'
# 2025-03-17 20:59:58,836 [INFO] Chunk 84 processed in 0.14s, 923921/87463152 rows (1.06%). Estimated remaining time: 9435.63s
# 2025-03-17 20:59:59,106 [INFO] Created 10,749 records
# 2025-03-17 20:59:59,124 [INFO] Appended 10749 rows to layer 'street_data'
# 2025-03-17 20:59:59,124 [INFO] Chunk 85 processed in 0.29s, 934670/87463152 rows (1.07%). Estimated remaining time: 9352.59s
# 2025-03-17 20:59:59,704 [INFO] Created 25,515 records
# 2025-03-17 20:59:59,721 [INFO] Appended 25515 rows to layer 'street_data'
# 2025-03-17 20:59:59,722 [INFO] Chunk 86 processed in 0.60s, 960185/87463152 rows (1.10%). Estimated remaining time: 9155.28s
# 2025-03-17 21:00:00,312 [INFO] Created 24,287 records
# 2025-03-17 21:00:00,329 [INFO] Appended 24287 rows to layer 'street_data'
# 2025-03-17 21:00:00,330 [INFO] Chunk 87 processed in 0.61s, 984472/87463152 rows (1.13%). Estimated remaining time: 8980.24s
# 2025-03-17 21:00:00,465 [INFO] Created 4,510 records
# 2025-03-17 21:00:00,484 [INFO] Appended 4510 rows to layer 'street_data'
# 2025-03-17 21:00:00,484 [INFO] Chunk 88 processed in 0.15s, 988982/87463152 rows (1.13%). Estimated remaining time: 8952.35s
# 2025-03-17 21:00:00,832 [INFO] Created 13,998 records
# 2025-03-17 21:00:00,851 [INFO] Appended 13998 rows to layer 'street_data'
# 2025-03-17 21:00:00,852 [INFO] Chunk 89 processed in 0.37s, 1002980/87463152 rows (1.15%). Estimated remaining time: 8857.67s
# 2025-03-17 21:00:01,022 [INFO] Created 5,864 records
# 2025-03-17 21:00:01,035 [INFO] Appended 5864 rows to layer 'street_data'
# 2025-03-17 21:00:01,035 [INFO] Chunk 90 processed in 0.18s, 1008844/87463152 rows (1.15%). Estimated remaining time: 8821.49s
# 2025-03-17 21:00:01,141 [INFO] Created 1,683 records
# 2025-03-17 21:00:01,153 [INFO] Appended 1683 rows to layer 'street_data'
# 2025-03-17 21:00:01,153 [INFO] Chunk 91 processed in 0.12s, 1010527/87463152 rows (1.16%). Estimated remaining time: 8816.92s
# 2025-03-17 21:00:01,340 [INFO] Created 6,481 records
# 2025-03-17 21:00:01,355 [INFO] Appended 6481 rows to layer 'street_data'
# 2025-03-17 21:00:01,356 [INFO] Chunk 92 processed in 0.20s, 1017008/87463152 rows (1.16%). Estimated remaining time: 8776.86s
# 2025-03-17 21:00:01,509 [INFO] Created 4,725 records
# 2025-03-17 21:00:01,525 [INFO] Appended 4725 rows to layer 'street_data'
# 2025-03-17 21:00:01,526 [INFO] Chunk 93 processed in 0.17s, 1021733/87463152 rows (1.17%). Estimated remaining time: 8750.19s
# 2025-03-17 21:00:01,567 [INFO] Created 678 records
# 2025-03-17 21:00:01,581 [INFO] Appended 678 rows to layer 'street_data'
# 2025-03-17 21:00:01,581 [INFO] Chunk 94 processed in 0.06s, 1022411/87463152 rows (1.17%). Estimated remaining time: 8749.10s
# 2025-03-17 21:00:01,761 [INFO] Created 7,351 records
# 2025-03-17 21:00:01,781 [INFO] Appended 7351 rows to layer 'street_data'
# 2025-03-17 21:00:01,781 [INFO] Chunk 95 processed in 0.20s, 1029762/87463152 rows (1.18%). Estimated remaining time: 8702.65s
# 2025-03-17 21:00:01,900 [INFO] Created 4,313 records
# 2025-03-17 21:00:01,911 [INFO] Appended 4313 rows to layer 'street_data'
# 2025-03-17 21:00:01,911 [INFO] Chunk 96 processed in 0.13s, 1034075/87463152 rows (1.18%). Estimated remaining time: 8677.18s
# 2025-03-17 21:00:02,141 [INFO] Created 9,239 records
# 2025-03-17 21:00:02,161 [INFO] Appended 9239 rows to layer 'street_data'
# 2025-03-17 21:00:02,161 [INFO] Chunk 97 processed in 0.25s, 1043314/87463152 rows (1.19%). Estimated remaining time: 8620.19s
# 2025-03-17 21:00:02,441 [INFO] Created 10,170 records
# 2025-03-17 21:00:02,453 [INFO] Appended 10170 rows to layer 'street_data'
# 2025-03-17 21:00:02,461 [INFO] Chunk 98 processed in 0.29s, 1053484/87463152 rows (1.20%). Estimated remaining time: 8560.07s
# 2025-03-17 21:00:02,652 [INFO] Created 6,647 records
# 2025-03-17 21:00:02,671 [INFO] Appended 6647 rows to layer 'street_data'
# 2025-03-17 21:00:02,671 [INFO] Chunk 99 processed in 0.21s, 1060131/87463152 rows (1.21%). Estimated remaining time: 8523.34s
# 2025-03-17 21:00:02,841 [INFO] Created 6,377 records
# 2025-03-17 21:00:02,856 [INFO] Appended 6377 rows to layer 'street_data'
# 2025-03-17 21:00:02,856 [INFO] Chunk 100 processed in 0.18s, 1066508/87463152 rows (1.22%). Estimated remaining time: 8486.41s
# 2025-03-17 21:00:02,965 [INFO] Created 3,720 records
# 2025-03-17 21:00:02,971 [INFO] Appended 3720 rows to layer 'street_data'
# 2025-03-17 21:00:02,981 [INFO] Chunk 101 processed in 0.12s, 1070228/87463152 rows (1.22%). Estimated remaining time: 8466.49s
# 2025-03-17 21:00:03,288 [INFO] Created 12,683 records
# 2025-03-17 21:00:03,305 [INFO] Appended 12683 rows to layer 'street_data'
# 2025-03-17 21:00:03,305 [INFO] Chunk 102 processed in 0.32s, 1082911/87463152 rows (1.24%). Estimated remaining time: 8391.99s
# 2025-03-17 21:00:03,453 [INFO] Created 5,163 records
# 2025-03-17 21:00:03,468 [INFO] Appended 5163 rows to layer 'street_data'
# 2025-03-17 21:00:03,469 [INFO] Chunk 103 processed in 0.16s, 1088074/87463152 rows (1.24%). Estimated remaining time: 8364.63s
# 2025-03-17 21:00:04,144 [INFO] Created 28,319 records
# 2025-03-17 21:00:04,163 [INFO] Appended 28319 rows to layer 'street_data'
# 2025-03-17 21:00:04,164 [INFO] Chunk 104 processed in 0.69s, 1116393/87463152 rows (1.28%). Estimated remaining time: 8203.50s
# 2025-03-17 21:00:04,311 [INFO] Created 5,349 records
# 2025-03-17 21:00:04,321 [INFO] Appended 5349 rows to layer 'street_data'
# 2025-03-17 21:00:04,321 [INFO] Chunk 105 processed in 0.17s, 1121742/87463152 rows (1.28%). Estimated remaining time: 8176.71s
# 2025-03-17 21:00:04,691 [INFO] Created 15,548 records
# 2025-03-17 21:00:04,711 [INFO] Appended 15548 rows to layer 'street_data'
# 2025-03-17 21:00:04,711 [INFO] Chunk 106 processed in 0.38s, 1137290/87463152 rows (1.30%). Estimated remaining time: 8092.65s
# 2025-03-17 21:00:04,946 [INFO] Created 9,241 records
# 2025-03-17 21:00:04,961 [INFO] Appended 9241 rows to layer 'street_data'
# 2025-03-17 21:00:04,961 [INFO] Chunk 107 processed in 0.25s, 1146531/87463152 rows (1.31%). Estimated remaining time: 8045.54s
# 2025-03-17 21:00:05,171 [INFO] Created 8,565 records
# 2025-03-17 21:00:05,193 [INFO] Appended 8565 rows to layer 'street_data'
# 2025-03-17 21:00:05,194 [INFO] Chunk 108 processed in 0.23s, 1155096/87463152 rows (1.32%). Estimated remaining time: 8002.08s
# 2025-03-17 21:00:05,526 [INFO] Created 13,138 records
# 2025-03-17 21:00:05,544 [INFO] Appended 13138 rows to layer 'street_data'
# 2025-03-17 21:00:05,545 [INFO] Chunk 109 processed in 0.35s, 1168234/87463152 rows (1.34%). Estimated remaining time: 7936.80s
# 2025-03-17 21:00:05,911 [INFO] Created 15,711 records
# 2025-03-17 21:00:05,926 [INFO] Appended 15711 rows to layer 'street_data'
# 2025-03-17 21:00:05,926 [INFO] Chunk 110 processed in 0.38s, 1183945/87463152 rows (1.35%). Estimated remaining time: 7858.13s
# 2025-03-17 21:00:06,155 [INFO] Created 8,066 records
# 2025-03-17 21:00:06,173 [INFO] Appended 8066 rows to layer 'street_data'
# 2025-03-17 21:00:06,173 [INFO] Chunk 111 processed in 0.24s, 1192011/87463152 rows (1.36%). Estimated remaining time: 7821.83s
# 2025-03-17 21:00:06,352 [INFO] Created 6,002 records
# 2025-03-17 21:00:06,361 [INFO] Appended 6002 rows to layer 'street_data'
# 2025-03-17 21:00:06,368 [INFO] Chunk 112 processed in 0.19s, 1198013/87463152 rows (1.37%). Estimated remaining time: 7796.12s
# 2025-03-17 21:00:06,710 [INFO] Created 12,404 records
# 2025-03-17 21:00:06,727 [INFO] Appended 12404 rows to layer 'street_data'
# 2025-03-17 21:00:06,728 [INFO] Chunk 113 processed in 0.36s, 1210417/87463152 rows (1.38%). Estimated remaining time: 7740.75s
# 2025-03-17 21:00:08,881 [INFO] Created 94,179 records
# 2025-03-17 21:00:08,899 [INFO] Appended 94179 rows to layer 'street_data'
# 2025-03-17 21:00:08,899 [INFO] Chunk 114 processed in 2.17s, 1304596/87463152 rows (1.49%). Estimated remaining time: 7317.50s
# 2025-03-17 21:00:09,081 [INFO] Created 6,503 records
# 2025-03-17 21:00:09,096 [INFO] Appended 6503 rows to layer 'street_data'
# 2025-03-17 21:00:09,097 [INFO] Chunk 115 processed in 0.20s, 1311099/87463152 rows (1.50%). Estimated remaining time: 7293.67s
# 2025-03-17 21:00:09,261 [INFO] Created 5,299 records
# 2025-03-17 21:00:09,272 [INFO] Appended 5299 rows to layer 'street_data'
# 2025-03-17 21:00:09,272 [INFO] Chunk 116 processed in 0.18s, 1316398/87463152 rows (1.51%). Estimated remaining time: 7275.82s
# 2025-03-17 21:00:09,441 [INFO] Created 6,108 records
# 2025-03-17 21:00:09,461 [INFO] Appended 6108 rows to layer 'street_data'
# 2025-03-17 21:00:09,461 [INFO] Chunk 117 processed in 0.18s, 1322506/87463152 rows (1.51%). Estimated remaining time: 7253.56s
# 2025-03-17 21:00:09,631 [INFO] Created 6,464 records
# 2025-03-17 21:00:09,641 [INFO] Appended 6464 rows to layer 'street_data'
# 2025-03-17 21:00:09,641 [INFO] Chunk 118 processed in 0.19s, 1328970/87463152 rows (1.52%). Estimated remaining time: 7229.89s
# 2025-03-17 21:00:09,961 [INFO] Created 13,290 records
# 2025-03-17 21:00:09,981 [INFO] Appended 13290 rows to layer 'street_data'
# 2025-03-17 21:00:09,981 [INFO] Chunk 119 processed in 0.33s, 1342260/87463152 rows (1.53%). Estimated remaining time: 7178.53s
# 2025-03-17 21:00:10,241 [INFO] Created 10,560 records
# 2025-03-17 21:00:10,253 [INFO] Appended 10560 rows to layer 'street_data'
# 2025-03-17 21:00:10,253 [INFO] Chunk 120 processed in 0.28s, 1352820/87463152 rows (1.55%). Estimated remaining time: 7139.19s
# 2025-03-17 21:00:10,590 [INFO] Created 12,692 records
# 2025-03-17 21:00:10,609 [INFO] Appended 12692 rows to layer 'street_data'
# 2025-03-17 21:00:10,610 [INFO] Chunk 121 processed in 0.35s, 1365512/87463152 rows (1.56%). Estimated remaining time: 7093.97s
# 2025-03-17 21:00:10,981 [INFO] Created 15,982 records
# 2025-03-17 21:00:11,000 [INFO] Appended 15982 rows to layer 'street_data'
# 2025-03-17 21:00:11,002 [INFO] Chunk 122 processed in 0.39s, 1381494/87463152 rows (1.58%). Estimated remaining time: 7035.02s
# 2025-03-17 21:00:11,201 [INFO] Created 7,477 records
# 2025-03-17 21:00:11,218 [INFO] Appended 7477 rows to layer 'street_data'
# 2025-03-17 21:00:11,219 [INFO] Chunk 123 processed in 0.22s, 1388971/87463152 rows (1.59%). Estimated remaining time: 7010.04s
# 2025-03-17 21:00:11,381 [INFO] Created 6,096 records
# 2025-03-17 21:00:11,400 [INFO] Appended 6096 rows to layer 'street_data'
# 2025-03-17 21:00:11,400 [INFO] Chunk 124 processed in 0.18s, 1395067/87463152 rows (1.60%). Estimated remaining time: 6990.10s
# 2025-03-17 21:00:11,626 [INFO] Created 8,639 records
# 2025-03-17 21:00:11,641 [INFO] Appended 8639 rows to layer 'street_data'
# 2025-03-17 21:00:11,641 [INFO] Chunk 125 processed in 0.24s, 1403706/87463152 rows (1.60%). Estimated remaining time: 6961.20s
# 2025-03-17 21:00:11,972 [INFO] Created 13,694 records
# 2025-03-17 21:00:11,989 [INFO] Appended 13694 rows to layer 'street_data'
# 2025-03-17 21:00:11,991 [INFO] Chunk 126 processed in 0.35s, 1417400/87463152 rows (1.62%). Estimated remaining time: 6913.99s
# 2025-03-17 21:00:12,449 [INFO] Created 17,727 records
# 2025-03-17 21:00:12,466 [INFO] Appended 17727 rows to layer 'street_data'
# 2025-03-17 21:00:12,466 [INFO] Chunk 127 processed in 0.47s, 1435127/87463152 rows (1.64%). Estimated remaining time: 6855.68s
# 2025-03-17 21:00:12,591 [INFO] Created 4,215 records
# 2025-03-17 21:00:12,602 [INFO] Appended 4215 rows to layer 'street_data'
# 2025-03-17 21:00:12,602 [INFO] Chunk 128 processed in 0.14s, 1439342/87463152 rows (1.65%). Estimated remaining time: 6843.79s
# 2025-03-17 21:00:12,882 [INFO] Created 10,850 records
# 2025-03-17 21:00:12,898 [INFO] Appended 10850 rows to layer 'street_data'
# 2025-03-17 21:00:12,899 [INFO] Chunk 129 processed in 0.29s, 1450192/87463152 rows (1.66%). Estimated remaining time: 6808.94s
# 2025-03-17 21:00:13,498 [INFO] Created 25,558 records
# 2025-03-17 21:00:13,511 [INFO] Appended 25558 rows to layer 'street_data'
# 2025-03-17 21:00:13,515 [INFO] Chunk 130 processed in 0.61s, 1475750/87463152 rows (1.69%). Estimated remaining time: 6724.91s
# 2025-03-17 21:00:14,021 [INFO] Created 22,815 records
# 2025-03-17 21:00:14,041 [INFO] Appended 22815 rows to layer 'street_data'
# 2025-03-17 21:00:14,041 [INFO] Chunk 131 processed in 0.53s, 1498565/87463152 rows (1.71%). Estimated remaining time: 6651.51s
# 2025-03-17 21:00:14,200 [INFO] Created 4,746 records
# 2025-03-17 21:00:14,215 [INFO] Appended 4746 rows to layer 'street_data'
# 2025-03-17 21:00:14,215 [INFO] Chunk 132 processed in 0.16s, 1503311/87463152 rows (1.72%). Estimated remaining time: 6639.58s
# 2025-03-17 21:00:14,584 [INFO] Created 15,259 records
# 2025-03-17 21:00:14,602 [INFO] Appended 15259 rows to layer 'street_data'
# 2025-03-17 21:00:14,602 [INFO] Chunk 133 processed in 0.39s, 1518570/87463152 rows (1.74%). Estimated remaining time: 6593.75s
# 2025-03-17 21:00:14,771 [INFO] Created 6,503 records
# 2025-03-17 21:00:14,788 [INFO] Appended 6503 rows to layer 'street_data'
# 2025-03-17 21:00:14,789 [INFO] Chunk 134 processed in 0.18s, 1525073/87463152 rows (1.74%). Estimated remaining time: 6575.46s
# 2025-03-17 21:00:14,899 [INFO] Created 1,854 records
# 2025-03-17 21:00:14,911 [INFO] Appended 1854 rows to layer 'street_data'
# 2025-03-17 21:00:14,911 [INFO] Chunk 135 processed in 0.13s, 1526927/87463152 rows (1.75%). Estimated remaining time: 6574.54s
# 2025-03-17 21:00:15,122 [INFO] Created 7,213 records
# 2025-03-17 21:00:15,137 [INFO] Appended 7213 rows to layer 'street_data'
# 2025-03-17 21:00:15,138 [INFO] Chunk 136 processed in 0.22s, 1534140/87463152 rows (1.75%). Estimated remaining time: 6555.48s
# 2025-03-17 21:00:15,368 [INFO] Created 8,802 records
# 2025-03-17 21:00:15,384 [INFO] Appended 8802 rows to layer 'street_data'
# 2025-03-17 21:00:15,385 [INFO] Chunk 137 processed in 0.25s, 1542942/87463152 rows (1.76%). Estimated remaining time: 6531.16s
# 2025-03-17 21:00:15,427 [INFO] Created 820 records
# 2025-03-17 21:00:15,441 [INFO] Appended 820 rows to layer 'street_data'
# 2025-03-17 21:00:15,441 [INFO] Chunk 138 processed in 0.06s, 1543762/87463152 rows (1.77%). Estimated remaining time: 6530.94s
# 2025-03-17 21:00:15,653 [INFO] Created 8,587 records
# 2025-03-17 21:00:15,671 [INFO] Appended 8587 rows to layer 'street_data'
# 2025-03-17 21:00:15,671 [INFO] Chunk 139 processed in 0.23s, 1552349/87463152 rows (1.77%). Estimated remaining time: 6507.10s
# 2025-03-17 21:00:15,825 [INFO] Created 4,592 records
# 2025-03-17 21:00:15,844 [INFO] Appended 4592 rows to layer 'street_data'
# 2025-03-17 21:00:15,845 [INFO] Chunk 140 processed in 0.17s, 1556941/87463152 rows (1.78%). Estimated remaining time: 6496.82s
# 2025-03-17 21:00:16,102 [INFO] Created 10,347 records
# 2025-03-17 21:00:16,121 [INFO] Appended 10347 rows to layer 'street_data'
# 2025-03-17 21:00:16,121 [INFO] Chunk 141 processed in 0.28s, 1567288/87463152 rows (1.79%). Estimated remaining time: 6468.48s
# 2025-03-17 21:00:16,399 [INFO] Created 11,249 records
# 2025-03-17 21:00:16,411 [INFO] Appended 11249 rows to layer 'street_data'
# 2025-03-17 21:00:16,411 [INFO] Chunk 142 processed in 0.29s, 1578537/87463152 rows (1.80%). Estimated remaining time: 6437.30s
# 2025-03-17 21:00:16,602 [INFO] Created 7,273 records
# 2025-03-17 21:00:16,621 [INFO] Appended 7273 rows to layer 'street_data'
# 2025-03-17 21:00:16,622 [INFO] Chunk 143 processed in 0.21s, 1585810/87463152 rows (1.81%). Estimated remaining time: 6418.46s
# 2025-03-17 21:00:16,811 [INFO] Created 7,378 records
# 2025-03-17 21:00:16,821 [INFO] Appended 7378 rows to layer 'street_data'
# 2025-03-17 21:00:16,821 [INFO] Chunk 144 processed in 0.21s, 1593188/87463152 rows (1.82%). Estimated remaining time: 6399.37s
# 2025-03-17 21:00:16,941 [INFO] Created 3,741 records
# 2025-03-17 21:00:16,957 [INFO] Appended 3741 rows to layer 'street_data'
# 2025-03-17 21:00:16,958 [INFO] Chunk 145 processed in 0.13s, 1596929/87463152 rows (1.83%). Estimated remaining time: 6391.02s
# 2025-03-17 21:00:17,296 [INFO] Created 13,810 records
# 2025-03-17 21:00:17,303 [INFO] Appended 13810 rows to layer 'street_data'
# 2025-03-17 21:00:17,311 [INFO] Chunk 146 processed in 0.35s, 1610739/87463152 rows (1.84%). Estimated remaining time: 6354.01s
# 2025-03-17 21:00:17,469 [INFO] Created 5,710 records
# 2025-03-17 21:00:17,488 [INFO] Appended 5710 rows to layer 'street_data'
# 2025-03-17 21:00:17,489 [INFO] Chunk 147 processed in 0.18s, 1616449/87463152 rows (1.85%). Estimated remaining time: 6340.56s
# 2025-03-17 21:00:18,313 [INFO] Created 32,842 records
# 2025-03-17 21:00:18,331 [INFO] Appended 32842 rows to layer 'street_data'
# 2025-03-17 21:00:18,333 [INFO] Chunk 148 processed in 0.84s, 1649291/87463152 rows (1.89%). Estimated remaining time: 6255.88s
# 2025-03-17 21:00:18,508 [INFO] Created 6,381 records
# 2025-03-17 21:00:18,523 [INFO] Appended 6381 rows to layer 'street_data'
# 2025-03-17 21:00:18,524 [INFO] Chunk 149 processed in 0.19s, 1655672/87463152 rows (1.89%). Estimated remaining time: 6241.19s
# 2025-03-17 21:00:18,936 [INFO] Created 17,326 records
# 2025-03-17 21:00:18,952 [INFO] Appended 17326 rows to layer 'street_data'
# 2025-03-17 21:00:18,952 [INFO] Chunk 150 processed in 0.43s, 1672998/87463152 rows (1.91%). Estimated remaining time: 6197.34s
# 2025-03-17 21:00:19,202 [INFO] Created 9,816 records
# 2025-03-17 21:00:19,222 [INFO] Appended 9816 rows to layer 'street_data'
# 2025-03-17 21:00:19,222 [INFO] Chunk 151 processed in 0.27s, 1682814/87463152 rows (1.92%). Estimated remaining time: 6174.29s
# 2025-03-17 21:00:19,469 [INFO] Created 9,757 records
# 2025-03-17 21:00:19,484 [INFO] Appended 9757 rows to layer 'street_data'
# 2025-03-17 21:00:19,485 [INFO] Chunk 152 processed in 0.26s, 1692571/87463152 rows (1.94%). Estimated remaining time: 6151.22s
# 2025-03-17 21:00:19,861 [INFO] Created 14,753 records
# 2025-03-17 21:00:19,881 [INFO] Appended 14753 rows to layer 'street_data'
# 2025-03-17 21:00:19,881 [INFO] Chunk 153 processed in 0.40s, 1707324/87463152 rows (1.95%). Estimated remaining time: 6117.03s
# 2025-03-17 21:00:20,298 [INFO] Created 16,594 records
# 2025-03-17 21:00:20,311 [INFO] Appended 16594 rows to layer 'street_data'
# 2025-03-17 21:00:20,311 [INFO] Chunk 154 processed in 0.43s, 1723918/87463152 rows (1.97%). Estimated remaining time: 6078.42s
# 2025-03-17 21:00:20,544 [INFO] Created 9,057 records
# 2025-03-17 21:00:20,561 [INFO] Appended 9057 rows to layer 'street_data'
# 2025-03-17 21:00:20,561 [INFO] Chunk 155 processed in 0.25s, 1732975/87463152 rows (1.98%). Estimated remaining time: 6058.26s
# 2025-03-17 21:00:20,761 [INFO] Created 6,754 records
# 2025-03-17 21:00:20,777 [INFO] Appended 6754 rows to layer 'street_data'
# 2025-03-17 21:00:20,778 [INFO] Chunk 156 processed in 0.21s, 1739729/87463152 rows (1.99%). Estimated remaining time: 6044.87s
# 2025-03-17 21:00:21,129 [INFO] Created 14,533 records
# 2025-03-17 21:00:21,144 [INFO] Appended 14533 rows to layer 'street_data'
# 2025-03-17 21:00:21,145 [INFO] Chunk 157 processed in 0.37s, 1754262/87463152 rows (2.01%). Estimated remaining time: 6011.71s
# 2025-03-17 21:00:23,892 [INFO] Created 104,861 records
# 2025-03-17 21:00:23,917 [INFO] Appended 104861 rows to layer 'street_data'
# 2025-03-17 21:00:23,918 [INFO] Chunk 158 processed in 2.77s, 1859123/87463152 rows (2.13%). Estimated remaining time: 5793.37s
# 2025-03-17 21:00:24,161 [INFO] Created 7,408 records
# 2025-03-17 21:00:24,181 [INFO] Appended 7408 rows to layer 'street_data'
# 2025-03-17 21:00:24,185 [INFO] Chunk 159 processed in 0.27s, 1866531/87463152 rows (2.13%). Estimated remaining time: 5782.12s
# 2025-03-17 21:00:24,371 [INFO] Created 5,789 records
# 2025-03-17 21:00:24,396 [INFO] Appended 5789 rows to layer 'street_data'
# 2025-03-17 21:00:24,396 [INFO] Chunk 160 processed in 0.21s, 1872320/87463152 rows (2.14%). Estimated remaining time: 5773.57s
# 2025-03-17 21:00:24,623 [INFO] Created 7,199 records
# 2025-03-17 21:00:24,641 [INFO] Appended 7199 rows to layer 'street_data'
# 2025-03-17 21:00:24,641 [INFO] Chunk 161 processed in 0.25s, 1879519/87463152 rows (2.15%). Estimated remaining time: 5762.18s
# 2025-03-17 21:00:24,912 [INFO] Created 7,765 records
# 2025-03-17 21:00:24,928 [INFO] Appended 7765 rows to layer 'street_data'
# 2025-03-17 21:00:24,929 [INFO] Chunk 162 processed in 0.28s, 1887284/87463152 rows (2.16%). Estimated remaining time: 5750.89s
# 2025-03-17 21:00:25,372 [INFO] Created 15,283 records
# 2025-03-17 21:00:25,399 [INFO] Appended 15283 rows to layer 'street_data'
# 2025-03-17 21:00:25,400 [INFO] Chunk 163 processed in 0.47s, 1902567/87463152 rows (2.18%). Estimated remaining time: 5724.85s
# 2025-03-17 21:00:25,771 [INFO] Created 12,130 records
# 2025-03-17 21:00:25,789 [INFO] Appended 12130 rows to layer 'street_data'
# 2025-03-17 21:00:25,789 [INFO] Chunk 164 processed in 0.39s, 1914697/87463152 rows (2.19%). Estimated remaining time: 5705.20s
# 2025-03-17 21:00:26,242 [INFO] Created 14,826 records
# 2025-03-17 21:00:26,261 [INFO] Appended 14826 rows to layer 'street_data'
# 2025-03-17 21:00:26,268 [INFO] Chunk 165 processed in 0.48s, 1929523/87463152 rows (2.21%). Estimated remaining time: 5681.60s
# 2025-03-17 21:00:26,793 [INFO] Created 17,915 records
# 2025-03-17 21:00:26,812 [INFO] Appended 17915 rows to layer 'street_data'
# 2025-03-17 21:00:26,813 [INFO] Chunk 166 processed in 0.54s, 1947438/87463152 rows (2.23%). Estimated remaining time: 5652.09s
# 2025-03-17 21:00:27,097 [INFO] Created 9,143 records
# 2025-03-17 21:00:27,111 [INFO] Appended 9143 rows to layer 'street_data'
# 2025-03-17 21:00:27,111 [INFO] Chunk 167 processed in 0.30s, 1956581/87463152 rows (2.24%). Estimated remaining time: 5638.22s
# 2025-03-17 21:00:27,324 [INFO] Created 6,719 records
# 2025-03-17 21:00:27,353 [INFO] Appended 6719 rows to layer 'street_data'
# 2025-03-17 21:00:27,353 [INFO] Chunk 168 processed in 0.24s, 1963300/87463152 rows (2.24%). Estimated remaining time: 5628.94s
# 2025-03-17 21:00:27,661 [INFO] Created 9,541 records
# 2025-03-17 21:00:27,681 [INFO] Appended 9541 rows to layer 'street_data'
# 2025-03-17 21:00:27,681 [INFO] Chunk 169 processed in 0.33s, 1972841/87463152 rows (2.26%). Estimated remaining time: 5615.51s
# 2025-03-17 21:00:28,131 [INFO] Created 15,670 records
# 2025-03-17 21:00:28,141 [INFO] Appended 15670 rows to layer 'street_data'
# 2025-03-17 21:00:28,150 [INFO] Chunk 170 processed in 0.46s, 1988511/87463152 rows (2.27%). Estimated remaining time: 5590.14s
# 2025-03-17 21:00:28,721 [INFO] Created 18,338 records
# 2025-03-17 21:00:28,741 [INFO] Appended 18338 rows to layer 'street_data'
# 2025-03-17 21:00:28,741 [INFO] Chunk 171 processed in 0.59s, 2006849/87463152 rows (2.29%). Estimated remaining time: 5563.18s
# 2025-03-17 21:00:28,902 [INFO] Created 4,665 records
# 2025-03-17 21:00:28,923 [INFO] Appended 4665 rows to layer 'street_data'
# 2025-03-17 21:00:28,923 [INFO] Chunk 172 processed in 0.18s, 2011514/87463152 rows (2.30%). Estimated remaining time: 5557.61s
# 2025-03-17 21:00:29,241 [INFO] Created 12,144 records
# 2025-03-17 21:00:29,254 [INFO] Appended 12144 rows to layer 'street_data'
# 2025-03-17 21:00:29,261 [INFO] Chunk 173 processed in 0.34s, 2023658/87463152 rows (2.31%). Estimated remaining time: 5537.68s
# 2025-03-17 21:00:29,972 [INFO] Created 28,958 records
# 2025-03-17 21:00:29,995 [INFO] Appended 28958 rows to layer 'street_data'
# 2025-03-17 21:00:29,996 [INFO] Chunk 174 processed in 0.73s, 2052616/87463152 rows (2.35%). Estimated remaining time: 5488.30s
# 2025-03-17 21:00:30,612 [INFO] Created 25,906 records
# 2025-03-17 21:00:30,629 [INFO] Appended 25906 rows to layer 'street_data'
# 2025-03-17 21:00:30,629 [INFO] Chunk 175 processed in 0.63s, 2078522/87463152 rows (2.38%). Estimated remaining time: 5444.29s
# 2025-03-17 21:00:30,721 [INFO] Created 2,772 records
# 2025-03-17 21:00:30,735 [INFO] Appended 2772 rows to layer 'street_data'
# 2025-03-17 21:00:30,735 [INFO] Chunk 176 processed in 0.11s, 2081294/87463152 rows (2.38%). Estimated remaining time: 5441.31s
# 2025-03-17 21:00:31,141 [INFO] Created 16,688 records
# 2025-03-17 21:00:31,157 [INFO] Appended 16688 rows to layer 'street_data'
# 2025-03-17 21:00:31,157 [INFO] Chunk 177 processed in 0.42s, 2097982/87463152 rows (2.40%). Estimated remaining time: 5414.14s
# 2025-03-17 21:00:31,361 [INFO] Created 6,881 records
# 2025-03-17 21:00:31,375 [INFO] Appended 6881 rows to layer 'street_data'
# 2025-03-17 21:00:31,375 [INFO] Chunk 178 processed in 0.22s, 2104863/87463152 rows (2.41%). Estimated remaining time: 5404.83s
# 2025-03-17 21:00:31,488 [INFO] Created 1,621 records
# 2025-03-17 21:00:31,502 [INFO] Appended 1621 rows to layer 'street_data'
# 2025-03-17 21:00:31,502 [INFO] Chunk 179 processed in 0.13s, 2106484/87463152 rows (2.41%). Estimated remaining time: 5405.74s
# 2025-03-17 21:00:31,714 [INFO] Created 7,902 records
# 2025-03-17 21:00:31,731 [INFO] Appended 7902 rows to layer 'street_data'
# 2025-03-17 21:00:31,731 [INFO] Chunk 180 processed in 0.23s, 2114386/87463152 rows (2.42%). Estimated remaining time: 5394.22s
# 2025-03-17 21:00:31,981 [INFO] Created 8,889 records
# 2025-03-17 21:00:31,991 [INFO] Appended 8889 rows to layer 'street_data'
# 2025-03-17 21:00:31,991 [INFO] Chunk 181 processed in 0.26s, 2123275/87463152 rows (2.43%). Estimated remaining time: 5381.75s
# 2025-03-17 21:00:32,043 [INFO] Created 692 records
# 2025-03-17 21:00:32,057 [INFO] Appended 692 rows to layer 'street_data'
# 2025-03-17 21:00:32,057 [INFO] Chunk 182 processed in 0.06s, 2123967/87463152 rows (2.43%). Estimated remaining time: 5382.38s
# 2025-03-17 21:00:32,281 [INFO] Created 8,335 records
# 2025-03-17 21:00:32,301 [INFO] Appended 8335 rows to layer 'street_data'
# 2025-03-17 21:00:32,302 [INFO] Chunk 183 processed in 0.24s, 2132302/87463152 rows (2.44%). Estimated remaining time: 5370.56s
# 2025-03-17 21:00:32,459 [INFO] Created 4,954 records
# 2025-03-17 21:00:32,479 [INFO] Appended 4954 rows to layer 'street_data'
# 2025-03-17 21:00:32,480 [INFO] Chunk 184 processed in 0.18s, 2137256/87463152 rows (2.44%). Estimated remaining time: 5364.91s
# 2025-03-17 21:00:32,761 [INFO] Created 10,976 records
# 2025-03-17 21:00:32,771 [INFO] Appended 10976 rows to layer 'street_data'
# 2025-03-17 21:00:32,771 [INFO] Chunk 185 processed in 0.30s, 2148232/87463152 rows (2.46%). Estimated remaining time: 5348.67s
# 2025-03-17 21:00:33,116 [INFO] Created 13,926 records
# 2025-03-17 21:00:33,136 [INFO] Appended 13926 rows to layer 'street_data'
# 2025-03-17 21:00:33,137 [INFO] Chunk 186 processed in 0.36s, 2162158/87463152 rows (2.47%). Estimated remaining time: 5327.49s
# 2025-03-17 21:00:33,341 [INFO] Created 7,495 records
# 2025-03-17 21:00:33,355 [INFO] Appended 7495 rows to layer 'street_data'
# 2025-03-17 21:00:33,355 [INFO] Chunk 187 processed in 0.22s, 2169653/87463152 rows (2.48%). Estimated remaining time: 5317.27s
# 2025-03-17 21:00:33,546 [INFO] Created 7,129 records
# 2025-03-17 21:00:33,563 [INFO] Appended 7129 rows to layer 'street_data'
# ...
# 2025-03-17 22:10:19,544 [INFO] Created 8,216 records
# 2025-03-17 22:10:19,561 [INFO] Appended 8216 rows to layer 'street_data'
# 2025-03-17 22:10:19,561 [INFO] Chunk 7468 processed in 0.53s, 86761175/87463152 rows (99.20%). Estimated remaining time: 34.96s
# 2025-03-17 22:10:19,889 [INFO] Created 5,235 records
# 2025-03-17 22:10:19,900 [INFO] Appended 5235 rows to layer 'street_data'
# 2025-03-17 22:10:19,900 [INFO] Chunk 7469 processed in 0.34s, 86766410/87463152 rows (99.20%). Estimated remaining time: 34.70s
# 2025-03-17 22:10:20,580 [INFO] Created 11,568 records
# 2025-03-17 22:10:20,596 [INFO] Appended 11568 rows to layer 'street_data'
# 2025-03-17 22:10:20,596 [INFO] Chunk 7470 processed in 0.69s, 86777978/87463152 rows (99.22%). Estimated remaining time: 34.13s
# 2025-03-17 22:10:25,055 [INFO] Created 91,065 records
# 2025-03-17 22:10:25,079 [INFO] Appended 91065 rows to layer 'street_data'
# 2025-03-17 22:10:25,079 [INFO] Chunk 7471 processed in 4.48s, 86869043/87463152 rows (99.32%). Estimated remaining time: 29.59s
# 2025-03-17 22:10:25,450 [INFO] Created 5,181 records
# 2025-03-17 22:10:25,469 [INFO] Appended 5181 rows to layer 'street_data'
# 2025-03-17 22:10:25,469 [INFO] Chunk 7472 processed in 0.39s, 86874224/87463152 rows (99.33%). Estimated remaining time: 29.34s
# 2025-03-17 22:10:25,811 [INFO] Created 5,200 records
# 2025-03-17 22:10:25,830 [INFO] Appended 5200 rows to layer 'street_data'
# 2025-03-17 22:10:25,831 [INFO] Chunk 7473 processed in 0.36s, 86879424/87463152 rows (99.33%). Estimated remaining time: 29.08s
# 2025-03-17 22:10:26,225 [INFO] Created 5,485 records
# 2025-03-17 22:10:26,239 [INFO] Appended 5485 rows to layer 'street_data'
# 2025-03-17 22:10:26,239 [INFO] Chunk 7474 processed in 0.41s, 86884909/87463152 rows (99.34%). Estimated remaining time: 28.80s
# 2025-03-17 22:10:26,937 [INFO] Created 13,148 records
# 2025-03-17 22:10:26,954 [INFO] Appended 13148 rows to layer 'street_data'
# 2025-03-17 22:10:26,954 [INFO] Chunk 7475 processed in 0.71s, 86898057/87463152 rows (99.35%). Estimated remaining time: 28.15s
# 2025-03-17 22:10:27,510 [INFO] Created 9,444 records
# 2025-03-17 22:10:27,530 [INFO] Appended 9444 rows to layer 'street_data'
# 2025-03-17 22:10:27,530 [INFO] Chunk 7476 processed in 0.58s, 86907501/87463152 rows (99.36%). Estimated remaining time: 27.68s
# 2025-03-17 22:10:28,109 [INFO] Created 9,384 records
# 2025-03-17 22:10:28,120 [INFO] Appended 9384 rows to layer 'street_data'
# 2025-03-17 22:10:28,120 [INFO] Chunk 7477 processed in 0.59s, 86916885/87463152 rows (99.38%). Estimated remaining time: 27.21s
# 2025-03-17 22:10:28,852 [INFO] Created 13,142 records
# 2025-03-17 22:10:28,863 [INFO] Appended 13142 rows to layer 'street_data'
# 2025-03-17 22:10:28,863 [INFO] Chunk 7478 processed in 0.74s, 86930027/87463152 rows (99.39%). Estimated remaining time: 26.56s
# 2025-03-17 22:10:29,373 [INFO] Created 7,706 records
# 2025-03-17 22:10:29,390 [INFO] Appended 7706 rows to layer 'street_data'
# 2025-03-17 22:10:29,390 [INFO] Chunk 7479 processed in 0.52s, 86937733/87463152 rows (99.40%). Estimated remaining time: 26.18s
# 2025-03-17 22:10:29,680 [INFO] Created 3,606 records
# 2025-03-17 22:10:29,694 [INFO] Appended 3606 rows to layer 'street_data'
# 2025-03-17 22:10:29,694 [INFO] Chunk 7480 processed in 0.31s, 86941339/87463152 rows (99.40%). Estimated remaining time: 26.00s
# 2025-03-17 22:10:30,140 [INFO] Created 6,681 records
# 2025-03-17 22:10:30,149 [INFO] Appended 6681 rows to layer 'street_data'
# 2025-03-17 22:10:30,149 [INFO] Chunk 7481 processed in 0.46s, 86948020/87463152 rows (99.41%). Estimated remaining time: 25.67s
# 2025-03-17 22:10:30,890 [INFO] Created 11,749 records
# 2025-03-17 22:10:30,910 [INFO] Appended 11749 rows to layer 'street_data'
# 2025-03-17 22:10:30,910 [INFO] Chunk 7482 processed in 0.75s, 86959769/87463152 rows (99.42%). Estimated remaining time: 25.08s
# 2025-03-17 22:10:31,738 [INFO] Created 14,877 records
# 2025-03-17 22:10:31,749 [INFO] Appended 14877 rows to layer 'street_data'
# 2025-03-17 22:10:31,749 [INFO] Chunk 7483 processed in 0.84s, 86974646/87463152 rows (99.44%). Estimated remaining time: 24.34s
# 2025-03-17 22:10:31,978 [INFO] Created 3,684 records
# 2025-03-17 22:10:31,996 [INFO] Appended 3684 rows to layer 'street_data'
# 2025-03-17 22:10:31,997 [INFO] Chunk 7484 processed in 0.24s, 86978330/87463152 rows (99.45%). Estimated remaining time: 24.16s
# 2025-03-17 22:10:32,549 [INFO] Created 7,757 records
# 2025-03-17 22:10:32,569 [INFO] Appended 7757 rows to layer 'street_data'
# 2025-03-17 22:10:32,569 [INFO] Chunk 7485 processed in 0.58s, 86986087/87463152 rows (99.45%). Estimated remaining time: 23.77s
# 2025-03-17 22:10:33,946 [INFO] Created 25,723 records
# 2025-03-17 22:10:33,962 [INFO] Appended 25723 rows to layer 'street_data'
# 2025-03-17 22:10:33,962 [INFO] Chunk 7486 processed in 1.39s, 87011810/87463152 rows (99.48%). Estimated remaining time: 22.49s
# 2025-03-17 22:10:35,040 [INFO] Created 23,597 records
# 2025-03-17 22:10:35,050 [INFO] Appended 23597 rows to layer 'street_data'
# 2025-03-17 22:10:35,060 [INFO] Chunk 7487 processed in 1.09s, 87035407/87463152 rows (99.51%). Estimated remaining time: 21.31s
# 2025-03-17 22:10:35,369 [INFO] Created 3,835 records
# 2025-03-17 22:10:35,385 [INFO] Appended 3835 rows to layer 'street_data'
# 2025-03-17 22:10:35,385 [INFO] Chunk 7488 processed in 0.32s, 87039242/87463152 rows (99.52%). Estimated remaining time: 21.12s
# 2025-03-17 22:10:36,194 [INFO] Created 14,828 records
# 2025-03-17 22:10:36,213 [INFO] Appended 14828 rows to layer 'street_data'
# 2025-03-17 22:10:36,213 [INFO] Chunk 7489 processed in 0.83s, 87054070/87463152 rows (99.53%). Estimated remaining time: 20.39s
# 2025-03-17 22:10:36,498 [INFO] Created 4,851 records
# 2025-03-17 22:10:36,514 [INFO] Appended 4851 rows to layer 'street_data'
# 2025-03-17 22:10:36,515 [INFO] Chunk 7490 processed in 0.30s, 87058921/87463152 rows (99.54%). Estimated remaining time: 20.14s
# 2025-03-17 22:10:36,930 [INFO] Created 6,267 records
# 2025-03-17 22:10:36,944 [INFO] Appended 6267 rows to layer 'street_data'
# 2025-03-17 22:10:36,944 [INFO] Chunk 7491 processed in 0.43s, 87065188/87463152 rows (99.54%). Estimated remaining time: 19.83s
# 2025-03-17 22:10:37,361 [INFO] Created 6,088 records
# 2025-03-17 22:10:37,380 [INFO] Appended 6088 rows to layer 'street_data'
# 2025-03-17 22:10:37,380 [INFO] Chunk 7492 processed in 0.44s, 87071276/87463152 rows (99.55%). Estimated remaining time: 19.53s
# 2025-03-17 22:10:37,445 [INFO] Created 629 records
# 2025-03-17 22:10:37,461 [INFO] Appended 629 rows to layer 'street_data'
# 2025-03-17 22:10:37,461 [INFO] Chunk 7493 processed in 0.08s, 87071905/87463152 rows (99.55%). Estimated remaining time: 19.50s
# 2025-03-17 22:10:37,886 [INFO] Created 6,494 records
# 2025-03-17 22:10:37,900 [INFO] Appended 6494 rows to layer 'street_data'
# 2025-03-17 22:10:37,900 [INFO] Chunk 7494 processed in 0.43s, 87078399/87463152 rows (99.56%). Estimated remaining time: 19.18s
# 2025-03-17 22:10:38,130 [INFO] Created 2,975 records
# 2025-03-17 22:10:38,149 [INFO] Appended 2975 rows to layer 'street_data'
# 2025-03-17 22:10:38,149 [INFO] Chunk 7495 processed in 0.25s, 87081374/87463152 rows (99.56%). Estimated remaining time: 19.03s
# 2025-03-17 22:10:38,633 [INFO] Created 7,793 records
# 2025-03-17 22:10:38,650 [INFO] Appended 7793 rows to layer 'street_data'
# 2025-03-17 22:10:38,650 [INFO] Chunk 7496 processed in 0.50s, 87089167/87463152 rows (99.57%). Estimated remaining time: 18.64s
# 2025-03-17 22:10:39,385 [INFO] Created 11,460 records
# 2025-03-17 22:10:39,400 [INFO] Appended 11460 rows to layer 'street_data'
# 2025-03-17 22:10:39,400 [INFO] Chunk 7497 processed in 0.75s, 87100627/87463152 rows (99.59%). Estimated remaining time: 18.07s
# 2025-03-17 22:10:39,699 [INFO] Created 4,156 records
# 2025-03-17 22:10:39,716 [INFO] Appended 4156 rows to layer 'street_data'
# 2025-03-17 22:10:39,717 [INFO] Chunk 7498 processed in 0.31s, 87104783/87463152 rows (99.59%). Estimated remaining time: 17.86s
# 2025-03-17 22:10:40,000 [INFO] Created 5,408 records
# 2025-03-17 22:10:40,020 [INFO] Appended 5408 rows to layer 'street_data'
# 2025-03-17 22:10:40,020 [INFO] Chunk 7499 processed in 0.31s, 87110191/87463152 rows (99.60%). Estimated remaining time: 17.59s
# 2025-03-17 22:10:40,280 [INFO] Created 3,478 records
# 2025-03-17 22:10:40,294 [INFO] Appended 3478 rows to layer 'street_data'
# 2025-03-17 22:10:40,294 [INFO] Chunk 7500 processed in 0.27s, 87113669/87463152 rows (99.60%). Estimated remaining time: 17.42s
# 2025-03-17 22:10:41,100 [INFO] Created 12,144 records
# 2025-03-17 22:10:41,114 [INFO] Appended 12144 rows to layer 'street_data'
# 2025-03-17 22:10:41,114 [INFO] Chunk 7501 processed in 0.82s, 87125813/87463152 rows (99.61%). Estimated remaining time: 16.82s
# 2025-03-17 22:10:41,394 [INFO] Created 4,485 records
# 2025-03-17 22:10:41,409 [INFO] Appended 4485 rows to layer 'street_data'
# 2025-03-17 22:10:41,409 [INFO] Chunk 7502 processed in 0.30s, 87130298/87463152 rows (99.62%). Estimated remaining time: 16.59s
# 2025-03-17 22:10:41,812 [INFO] Created 5,318 records
# 2025-03-17 22:10:41,831 [INFO] Appended 5318 rows to layer 'street_data'
# 2025-03-17 22:10:41,832 [INFO] Chunk 7503 processed in 0.42s, 87135616/87463152 rows (99.63%). Estimated remaining time: 16.33s
# 2025-03-17 22:10:42,640 [INFO] Created 13,481 records
# 2025-03-17 22:10:42,650 [INFO] Appended 13481 rows to layer 'street_data'
# 2025-03-17 22:10:42,650 [INFO] Chunk 7504 processed in 0.82s, 87149097/87463152 rows (99.64%). Estimated remaining time: 15.66s
# 2025-03-17 22:10:43,254 [INFO] Created 8,574 records
# 2025-03-17 22:10:43,269 [INFO] Appended 8574 rows to layer 'street_data'
# 2025-03-17 22:10:43,270 [INFO] Chunk 7505 processed in 0.61s, 87157671/87463152 rows (99.65%). Estimated remaining time: 15.23s
# 2025-03-17 22:10:43,729 [INFO] Created 7,226 records
# 2025-03-17 22:10:43,749 [INFO] Appended 7226 rows to layer 'street_data'
# 2025-03-17 22:10:43,749 [INFO] Chunk 7506 processed in 0.48s, 87164897/87463152 rows (99.66%). Estimated remaining time: 14.87s
# 2025-03-17 22:10:44,728 [INFO] Created 14,201 records
# 2025-03-17 22:10:44,744 [INFO] Appended 14201 rows to layer 'street_data'
# 2025-03-17 22:10:44,744 [INFO] Chunk 7507 processed in 0.99s, 87179098/87463152 rows (99.68%). Estimated remaining time: 14.16s
# 2025-03-17 22:10:45,589 [INFO] Created 13,630 records
# 2025-03-17 22:10:45,600 [INFO] Appended 13630 rows to layer 'street_data'
# 2025-03-17 22:10:45,600 [INFO] Chunk 7508 processed in 0.86s, 87192728/87463152 rows (99.69%). Estimated remaining time: 13.48s
# 2025-03-17 22:10:46,096 [INFO] Created 8,448 records
# 2025-03-17 22:10:46,111 [INFO] Appended 8448 rows to layer 'street_data'
# 2025-03-17 22:10:46,111 [INFO] Chunk 7509 processed in 0.51s, 87201176/87463152 rows (99.70%). Estimated remaining time: 13.06s
# 2025-03-17 22:10:46,442 [INFO] Created 5,184 records
# 2025-03-17 22:10:46,461 [INFO] Appended 5184 rows to layer 'street_data'
# 2025-03-17 22:10:46,461 [INFO] Chunk 7510 processed in 0.35s, 87206360/87463152 rows (99.71%). Estimated remaining time: 12.80s
# 2025-03-17 22:10:47,133 [INFO] Created 11,192 records
# 2025-03-17 22:10:47,148 [INFO] Appended 11192 rows to layer 'street_data'
# 2025-03-17 22:10:47,150 [INFO] Chunk 7511 processed in 0.69s, 87217552/87463152 rows (99.72%). Estimated remaining time: 12.25s
# 2025-03-17 22:10:51,528 [INFO] Created 86,952 records
# 2025-03-17 22:10:51,543 [INFO] Appended 86952 rows to layer 'street_data'
# 2025-03-17 22:10:51,543 [INFO] Chunk 7512 processed in 4.39s, 87304504/87463152 rows (99.82%). Estimated remaining time: 7.91s
# 2025-03-17 22:10:51,899 [INFO] Created 5,419 records
# 2025-03-17 22:10:51,910 [INFO] Appended 5419 rows to layer 'street_data'
# 2025-03-17 22:10:51,919 [INFO] Chunk 7513 processed in 0.37s, 87309923/87463152 rows (99.82%). Estimated remaining time: 7.64s
# 2025-03-17 22:10:52,262 [INFO] Created 4,726 records
# 2025-03-17 22:10:52,269 [INFO] Appended 4726 rows to layer 'street_data'
# 2025-03-17 22:10:52,269 [INFO] Chunk 7514 processed in 0.36s, 87314649/87463152 rows (99.83%). Estimated remaining time: 7.41s
# 2025-03-17 22:10:52,641 [INFO] Created 5,773 records
# 2025-03-17 22:10:52,660 [INFO] Appended 5773 rows to layer 'street_data'
# 2025-03-17 22:10:52,660 [INFO] Chunk 7515 processed in 0.38s, 87320422/87463152 rows (99.84%). Estimated remaining time: 7.12s
# 2025-03-17 22:10:53,295 [INFO] Created 13,233 records
# 2025-03-17 22:10:53,310 [INFO] Appended 13233 rows to layer 'street_data'
# 2025-03-17 22:10:53,312 [INFO] Chunk 7516 processed in 0.65s, 87333655/87463152 rows (99.85%). Estimated remaining time: 6.46s
# 2025-03-17 22:10:53,849 [INFO] Created 9,548 records
# 2025-03-17 22:10:53,866 [INFO] Appended 9548 rows to layer 'street_data'
# 2025-03-17 22:10:53,866 [INFO] Chunk 7517 processed in 0.55s, 87343203/87463152 rows (99.86%). Estimated remaining time: 5.98s
# 2025-03-17 22:10:54,542 [INFO] Created 10,215 records
# 2025-03-17 22:10:54,559 [INFO] Appended 10215 rows to layer 'street_data'
# 2025-03-17 22:10:54,559 [INFO] Chunk 7518 processed in 0.69s, 87353418/87463152 rows (99.87%). Estimated remaining time: 5.47s
# 2025-03-17 22:10:55,382 [INFO] Created 13,115 records
# 2025-03-17 22:10:55,402 [INFO] Appended 13115 rows to layer 'street_data'
# 2025-03-17 22:10:55,403 [INFO] Chunk 7519 processed in 0.84s, 87366533/87463152 rows (99.89%). Estimated remaining time: 4.82s
# 2025-03-17 22:10:55,879 [INFO] Created 7,522 records
# 2025-03-17 22:10:55,893 [INFO] Appended 7522 rows to layer 'street_data'
# 2025-03-17 22:10:55,900 [INFO] Chunk 7520 processed in 0.50s, 87374055/87463152 rows (99.90%). Estimated remaining time: 4.44s
# 2025-03-17 22:10:56,190 [INFO] Created 3,688 records
# 2025-03-17 22:10:56,199 [INFO] Appended 3688 rows to layer 'street_data'
# 2025-03-17 22:10:56,199 [INFO] Chunk 7521 processed in 0.30s, 87377743/87463152 rows (99.90%). Estimated remaining time: 4.26s
# 2025-03-17 22:10:56,619 [INFO] Created 6,255 records
# 2025-03-17 22:10:56,630 [INFO] Appended 6255 rows to layer 'street_data'
# 2025-03-17 22:10:56,630 [INFO] Chunk 7522 processed in 0.43s, 87383998/87463152 rows (99.91%). Estimated remaining time: 3.95s
# 2025-03-17 22:10:57,413 [INFO] Created 14,877 records
# 2025-03-17 22:10:57,427 [INFO] Appended 14877 rows to layer 'street_data'
# 2025-03-17 22:10:57,430 [INFO] Chunk 7523 processed in 0.79s, 87398875/87463152 rows (99.93%). Estimated remaining time: 3.21s
# 2025-03-17 22:10:57,668 [INFO] Created 3,701 records
# 2025-03-17 22:10:57,686 [INFO] Appended 3701 rows to layer 'street_data'
# 2025-03-17 22:10:57,686 [INFO] Chunk 7524 processed in 0.26s, 87402576/87463152 rows (99.93%). Estimated remaining time: 3.02s
# 2025-03-17 22:10:58,224 [INFO] Created 7,913 records
# 2025-03-17 22:10:58,240 [INFO] Appended 7913 rows to layer 'street_data'
# 2025-03-17 22:10:58,240 [INFO] Chunk 7525 processed in 0.55s, 87410489/87463152 rows (99.94%). Estimated remaining time: 2.63s
# 2025-03-17 22:10:59,604 [INFO] Created 25,601 records
# 2025-03-17 22:10:59,624 [INFO] Appended 25601 rows to layer 'street_data'
# 2025-03-17 22:10:59,625 [INFO] Chunk 7526 processed in 1.38s, 87436090/87463152 rows (99.97%). Estimated remaining time: 1.35s
# 2025-03-17 22:11:00,700 [INFO] Created 23,232 records
# 2025-03-17 22:11:00,713 [INFO] Appended 23232 rows to layer 'street_data'
# 2025-03-17 22:11:00,713 [INFO] Chunk 7527 processed in 1.09s, 87459322/87463152 rows (100.00%). Estimated remaining time: 0.19s
# 2025-03-17 22:11:00,988 [INFO] Created 3,830 records
# 2025-03-17 22:11:01,001 [INFO] Appended 3830 rows to layer 'street_data'
# 2025-03-17 22:11:01,001 [INFO] Chunk 7528 processed in 0.29s, 87463152/87463152 rows (100.00%). Estimated remaining time: 0.00s
# 2025-03-17 22:11:01,021 [INFO] Finished writing 7528 chunks to 'C:\Studie\SSML\project\police_crime_archive\extracted_2013_2025\crime_data_uk.gpkg' layer='street_data'.
# 2025-03-17 22:11:01,021 [INFO] Total rows processed: 87463152
# 2025-03-17 22:11:01,021 [INFO] Total time: 4362.92s
# 2025-03-17 22:11:01,023 [INFO] Average processing speed: 20046.92 rows/second
